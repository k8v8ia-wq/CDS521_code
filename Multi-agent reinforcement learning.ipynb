# %% [markdown]
# ## DQN

# %%
import pygame
import numpy as np
import time
import math
import sys
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import matplotlib.pyplot as plt

print("=" * 60)
print("Multi-Agent Environment - Pursuit Evasion Game with DQN")
print("=" * 60)

# Initialize pygame
pygame.init()

# Set up window
WIDTH, HEIGHT = 1200, 800
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Multi-Agent Environment - Pursuit Evasion Game with DQN")

# Color definitions
BACKGROUND = (240, 240, 240)
RED = (255, 80, 80)  # Adversary
BLUE = (80, 80, 255)  # Cooperator
GREEN = (80, 180, 80)  # Landmark
YELLOW = (255, 200, 0)  # Highlight
PURPLE = (180, 80, 200)  # Interaction effect
ORANGE = (255, 150, 50)  # Warning
BLACK = (40, 40, 40)
GRAY = (200, 200, 200)
LIGHT_GRAY = (220, 220, 220)  # For finer grid
WHITE = (255, 255, 255)
DARK_RED = (180, 0, 0)  # DQN agent highlight

# Fonts
font_large = pygame.font.Font(None, 32)
font_medium = pygame.font.Font(None, 24)
font_small = pygame.font.Font(None, 18)

# Environment parameters
SCALE = 180
CENTER_X = WIDTH // 3
CENTER_Y = HEIGHT // 2

# Size parameters
AGENT_RADIUS = 8
LANDMARK_RADIUS = 6
DANGER_THRESHOLD = 0.4
TARGET_THRESHOLD = 0.08
CAPTURE_THRESHOLD = 0.15

# UI parameters
INFO_PANEL_WIDTH = 400
INFO_PANEL_HEIGHT = 600
INFO_PANEL_MARGIN = 20
MINIMAP_HEIGHT = 150

# Movement speeds - adjusted for better visualization
COOPERATOR_SPEED = 0.018  # Significantly slower for more challenging gameplay
ADVERSARY_SPEED = COOPERATOR_SPEED * 1.8  # Increased ratio to make chase more intense

# DQN Parameters - adjusted for increased difficulty
BATCH_SIZE = 64 # Increased batch size for more stable learning
LEARNING_RATE = 0.0003  # Reduced learning rate for better convergence with harder gameplay
GAMMA = 0.96  # Slightly reduced discount factor to prioritize immediate rewards
EPSILON_START = 1.0
EPSILON_END = 0.02  # Slightly higher exploration rate for more challenging environment
EPSILON_DECAY = 0.996  # Slower decay to maintain exploration longer
TARGET_UPDATE = 10  # Less frequent updates for more stable target network
MEMORY_SIZE = 40000  # Increased memory capacity for more diverse experiences

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


class DQN(nn.Module):
    """Deep Q-Network for the adversary agent"""

    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, action_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return self.fc4(x)


class DQNAgent:
    """DQN Agent for the adversary"""

    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=MEMORY_SIZE)
        self.epsilon = EPSILON_START
        self.learning_step = 0

        # Neural Networks
        self.policy_net = DQN(state_size, action_size).to(device)
        self.target_net = DQN(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=LEARNING_RATE)

        # Initialize target network with policy network weights
        self.update_target_network()

        # Training statistics
        self.losses = []
        self.rewards = []
        self.episode_rewards = []
        self.average_rewards = []  # 平均回合奖励
        self.q_values = []  # Q值记录
        self.epsilons = []  # 探索率记录
        self.td_errors = []  # 时序差分误差记录
        self.action_counts = np.zeros(action_size)  # 动作分布记录

    def update_target_network(self):
        """Update the target network with policy network weights"""
        self.target_net.load_state_dict(self.policy_net.state_dict())

    def remember(self, state, action, reward, next_state, done):
        """Store experience in replay memory"""
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        """Select action using epsilon-greedy policy"""
        # Ensure state is the correct size
        if len(state) != self.state_size:
            state = state[:self.state_size]  # Truncate if too long
            if len(state) < self.state_size:
                # Pad if too short
                state = np.pad(state, (0, self.state_size - len(state)), 'constant')

        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.policy_net(state_tensor)
            # 记录平均Q值
            avg_q = q_values.mean().item()
            self.q_values.append(avg_q)

            if random.random() <= self.epsilon:
                action = random.randrange(self.action_size)
            else:
                action = np.argmax(q_values.cpu().data.numpy())

            # 记录动作分布
            self.action_counts[action] += 1
            return action

    def replay(self):
        """Train the network on a batch of experiences"""
        if len(self.memory) < BATCH_SIZE:
            return 0

        # Sample batch from memory
        batch = random.sample(self.memory, BATCH_SIZE)

        # Process states to ensure correct dimensions
        states, actions, rewards, next_states, dones = [], [], [], [], []

        for state, action, reward, next_state, done in batch:
            # Ensure state dimensions are correct
            if len(state) != self.state_size:
                state = state[:self.state_size]
                if len(state) < self.state_size:
                    state = np.pad(state, (0, self.state_size - len(state)), 'constant')

            if len(next_state) != self.state_size:
                next_state = next_state[:self.state_size]
                if len(next_state) < self.state_size:
                    next_state = np.pad(next_state, (0, self.state_size - len(next_state)), 'constant')

            states.append(state)
            actions.append(action)
            rewards.append(reward)
            next_states.append(next_state)
            dones.append(done)

        # Convert to tensors
        states = torch.FloatTensor(np.array(states)).to(device)
        actions = torch.LongTensor(actions).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        next_states = torch.FloatTensor(np.array(next_states)).to(device)
        dones = torch.BoolTensor(dones).to(device)

        # Current Q values
        current_q_values = self.policy_net(states).gather(1, actions.unsqueeze(1))

        # Next Q values from target network
        with torch.no_grad():
            next_q_values = self.target_net(next_states).max(1)[0]
            next_q_values[dones] = 0.0

        # Compute target Q values
        target_q_values = rewards + (GAMMA * next_q_values)

        # Compute TD error
        with torch.no_grad():
            td_error = target_q_values.unsqueeze(1) - current_q_values
            # 计算平均TD误差并记录
            avg_td_error = td_error.abs().mean().item()
            self.td_errors.append(avg_td_error)

        # Compute loss
        loss = F.mse_loss(current_q_values.squeeze(), target_q_values)

        # Optimize the model
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.optimizer.step()

        # Update epsilon
        self.epsilon = max(EPSILON_END, self.epsilon * EPSILON_DECAY)
        self.epsilons.append(self.epsilon)

        # Update target network periodically
        self.learning_step += 1
        if self.learning_step % TARGET_UPDATE == 0:
            self.update_target_network()

        # Store loss for tracking
        self.losses.append(loss.item())
        return loss.item()

    def save_model(self, filename):
        """Save the model weights"""
        torch.save({
            'policy_net_state_dict': self.policy_net.state_dict(),
            'target_net_state_dict': self.target_net.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'epsilon': self.epsilon,
            'memory': list(self.memory),
            'losses': self.losses,
            'episode_rewards': self.episode_rewards,
            'average_rewards': self.average_rewards,
            'q_values': self.q_values,
            'epsilons': self.epsilons,
            'td_errors': self.td_errors,
            'action_counts': self.action_counts
        }, filename)

    def load_model(self, filename):
        """Load the model weights"""
        checkpoint = torch.load(filename)
        self.policy_net.load_state_dict(checkpoint['policy_net_state_dict'])
        self.target_net.load_state_dict(checkpoint['target_net_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.epsilon = checkpoint['epsilon']
        self.memory = deque(checkpoint['memory'], maxlen=MEMORY_SIZE)
        self.losses = checkpoint['losses']
        self.episode_rewards = checkpoint['episode_rewards']
        self.average_rewards = checkpoint.get('average_rewards', [])
        self.q_values = checkpoint.get('q_values', [])
        self.epsilons = checkpoint.get('epsilons', [])
        self.td_errors = checkpoint.get('td_errors', [])
        self.action_counts = checkpoint.get('action_counts', np.zeros(self.action_size))


def create_simulation_data():
    """Create simulation data"""
    agents = [
        {'pos': [-1.0, 0.6], 'type': 'adversary', 'target_landmark': None, 'score': 0},
        {'pos': [0.3, -0.8], 'type': 'cooperator', 'target_landmark': 0, 'score': 0},
        {'pos': [0.8, 0.2], 'type': 'cooperator', 'target_landmark': 1, 'score': 0}
    ]
    landmarks = [
        {'pos': [-1.2, -1.0], 'occupied': False, 'value': 10},
        {'pos': [1.1, 1.0], 'occupied': False, 'value': 10}
    ]
    return agents, landmarks


def get_random_position():
    """Generate random position within world bounds"""
    WORLD_BOUNDS = 1.4
    x = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    y = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    return [x, y]


def get_state(adversary_pos, cooperator1_pos, cooperator2_pos, landmarks):
    """Get state representation for DQN - Fixed to 15 dimensions"""
    state = []

    # Adversary position (normalized) - 2 dimensions
    state.extend(adversary_pos)

    # Relative positions to cooperators - 4 dimensions
    state.extend([cooperator1_pos[0] - adversary_pos[0], cooperator1_pos[1] - adversary_pos[1]])
    state.extend([cooperator2_pos[0] - adversary_pos[0], cooperator2_pos[1] - adversary_pos[1]])

    # Distances to cooperators - 2 dimensions
    state.append(calculate_distance(adversary_pos, cooperator1_pos))
    state.append(calculate_distance(adversary_pos, cooperator2_pos))

    # Relative positions to landmarks - 4 dimensions (only 2 landmarks)
    for i, landmark in enumerate(landmarks[:2]):  # Ensure only 2 landmarks
        state.extend([landmark['pos'][0] - adversary_pos[0], landmark['pos'][1] - adversary_pos[1]])

    # Distances to landmarks - 2 dimensions
    for i, landmark in enumerate(landmarks[:2]):  # Ensure only 2 landmarks
        state.append(calculate_distance(adversary_pos, landmark['pos']))

    # Which cooperator is closer to landmarks (threat assessment) - 1 dimension
    coop1_min_landmark_dist = min(calculate_distance(cooperator1_pos, landmark['pos']) for landmark in landmarks)
    coop2_min_landmark_dist = min(calculate_distance(cooperator2_pos, landmark['pos']) for landmark in landmarks)

    # Use difference instead of both values to save dimensions
    threat_difference = coop1_min_landmark_dist - coop2_min_landmark_dist
    state.append(threat_difference)

    # Ensure exactly 15 dimensions
    if len(state) != 15:
        # Truncate or pad to exactly 15 dimensions
        state = state[:15]
        if len(state) < 15:
            state.extend([0] * (15 - len(state)))

    return np.array(state, dtype=np.float32)


def calculate_distance(pos1, pos2):
    """Calculate distance between two positions"""
    return math.sqrt((pos1[0] - pos2[0]) ** 2 + (pos1[1] - pos2[1]) ** 2)


def world_to_screen(pos):
    """Convert world coordinates to screen coordinates"""
    x = int(pos[0] * SCALE + CENTER_X)
    y = int(pos[1] * SCALE + CENTER_Y)
    return x, y


def draw_grid():
    """Draw grid"""
    grid_right_boundary = WIDTH - INFO_PANEL_WIDTH - 10

    # Draw dense grid lines
    dense_grid_range = 40
    for i in range(-dense_grid_range, dense_grid_range + 1):
        x = CENTER_X + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (x, 50), (x, HEIGHT - 50), 1)
        y = CENTER_Y + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (50, y), (grid_right_boundary, y), 1)

    # Draw main grid lines
    main_grid_range = 4
    for i in range(-main_grid_range, main_grid_range + 1):
        x = CENTER_X + i * SCALE
        pygame.draw.line(screen, GRAY, (x, 50), (x, HEIGHT - 50), 2)
        y = CENTER_Y + i * SCALE
        pygame.draw.line(screen, GRAY, (50, y), (grid_right_boundary, y), 2)

    # Draw axes
    pygame.draw.line(screen, BLACK, (CENTER_X, 50), (CENTER_X, HEIGHT - 50), 3)
    pygame.draw.line(screen, BLACK, (50, CENTER_Y), (grid_right_boundary, CENTER_Y), 3)

    # Draw coordinate labels
    for i in range(-main_grid_range, main_grid_range + 1):
        if i != 0:
            x = CENTER_X + i * SCALE
            label_value = i * 10
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (x - 8, CENTER_Y + 12))

            y = CENTER_Y + i * SCALE
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (CENTER_X + 12, y - 8))

    # Draw origin label
    origin_label = font_small.render("0", True, BLACK)
    screen.blit(origin_label, (CENTER_X + 5, CENTER_Y + 12))


def draw_landmark(pos, index, is_highlighted=False, is_occupied=False):
    """Draw landmark"""
    x, y = world_to_screen(pos)

    if is_occupied:
        color = PURPLE
    elif is_highlighted:
        color = YELLOW
    else:
        color = GREEN

    pygame.draw.circle(screen, color, (x, y), LANDMARK_RADIUS)
    pygame.draw.circle(screen, WHITE, (x, y), LANDMARK_RADIUS // 2)

    text = font_small.render(f"LM{index + 1}", True, BLACK)
    screen.blit(text, (x - 12, y - LANDMARK_RADIUS - 12))


def draw_agent(pos, is_adversary, agent_id, target_distance=None, is_success=False, is_danger=False,
               is_dqn_agent=False):
    """Draw agent"""
    x, y = world_to_screen(pos)

    if is_success:
        color = PURPLE
    elif is_danger:
        color = ORANGE
    elif is_dqn_agent:
        color = DARK_RED
    else:
        color = RED if is_adversary else BLUE

    radius = AGENT_RADIUS + 2 if is_adversary else AGENT_RADIUS
    pygame.draw.circle(screen, color, (x, y), radius)
    pygame.draw.circle(screen, WHITE, (x, y), radius, 2)

    # Add special indicator for DQN agent
    if is_dqn_agent:
        pygame.draw.circle(screen, YELLOW, (x, y), radius + 4, 2)

    # Agent label
    agent_type = "Adv" if is_adversary else f"C{agent_id}"
    text = font_small.render(agent_type, True, BLACK)
    screen.blit(text, (x - 8, y - radius - 10))


def draw_danger_zone(agent_pos, adversary_pos):
    """Draw danger zone"""
    if calculate_distance(agent_pos, adversary_pos) < DANGER_THRESHOLD:
        x1, y1 = world_to_screen(agent_pos)
        x2, y2 = world_to_screen(adversary_pos)
        pygame.draw.line(screen, ORANGE, (x1, y1), (x2, y2), 2)


def draw_dqn_panel(step, rewards, total_rewards, game_status, dqn_agent, current_state, current_action,
                   success_count, danger_count, capture_count, episode):
    """Draw DQN information panel"""
    panel_x = WIDTH - INFO_PANEL_WIDTH - INFO_PANEL_MARGIN
    panel_y = INFO_PANEL_MARGIN

    # Panel background
    pygame.draw.rect(screen, WHITE, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT))
    pygame.draw.rect(screen, BLACK, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT), 2)

    # Title
    title = font_large.render("DQN Pursuit Evasion", True, BLACK)
    screen.blit(title, (panel_x + 10, panel_y + 10))

    # Episode and step information
    episode_text = font_medium.render(f"Episode: {episode}", True, BLACK)
    screen.blit(episode_text, (panel_x + 10, panel_y + 50))

    step_text = font_medium.render(f"Step: {step}/300", True, BLACK)
    screen.blit(step_text, (panel_x + 150, panel_y + 50))

    # Game status
    status_text = font_medium.render(f"Status: {game_status}", True,
                                     (0, 150, 0) if "Leading" in game_status else
                                     ORANGE if "Danger" in game_status or "Captured" in game_status else
                                     (0, 150, 0) if "Success" in game_status else BLACK)
    screen.blit(status_text, (panel_x + 10, panel_y + 80))

    # DQN Agent Information
    dqn_y = panel_y + 110
    dqn_title = font_medium.render("DQN Adversary Info:", True, DARK_RED)
    screen.blit(dqn_title, (panel_x + 10, dqn_y))

    epsilon_text = font_small.render(f"Epsilon: {dqn_agent.epsilon:.3f}", True, BLACK)
    screen.blit(epsilon_text, (panel_x + 20, dqn_y + 25))

    memory_text = font_small.render(f"Memory: {len(dqn_agent.memory)}/{MEMORY_SIZE}", True, BLACK)
    screen.blit(memory_text, (panel_x + 20, dqn_y + 45))

    action_text = font_small.render(f"Action: {get_action_description(current_action)}", True, BLACK)
    screen.blit(action_text, (panel_x + 20, dqn_y + 65))

    learning_text = font_small.render(f"Learning Steps: {dqn_agent.learning_step}", True, BLACK)
    screen.blit(learning_text, (panel_x + 20, dqn_y + 85))

    avg_loss = np.mean(dqn_agent.losses[-100:]) if dqn_agent.losses else 0
    loss_text = font_small.render(f"Avg Loss: {avg_loss:.4f}", True, BLACK)
    screen.blit(loss_text, (panel_x + 20, dqn_y + 105))

    # Statistics
    stats_y = dqn_y + 135
    stats_title = font_medium.render("Statistics:", True, BLACK)
    screen.blit(stats_title, (panel_x + 10, stats_y))

    success_text = font_small.render(f"Success: {success_count}", True, (0, 150, 0))
    screen.blit(success_text, (panel_x + 20, stats_y + 30))

    danger_count_text = font_small.render(f"Danger: {danger_count}", True, ORANGE)
    screen.blit(danger_count_text, (panel_x + 20, stats_y + 50))

    capture_text = font_small.render(f"Captures: {capture_count}", True, RED)
    screen.blit(capture_text, (panel_x + 20, stats_y + 70))

    # Reward information
    rewards_y = stats_y + 110
    rewards_title = font_medium.render("Rewards:", True, BLACK)
    screen.blit(rewards_title, (panel_x + 10, rewards_y))

    agent_names = ["Adversary (DQN)", "Cooperator1", "Cooperator2"]
    for i, (name, reward, total) in enumerate(zip(agent_names, rewards, total_rewards)):
        color = DARK_RED if i == 0 else BLUE
        text = f"{name}: {reward:+.2f}"
        reward_text = font_small.render(text, True, color)
        screen.blit(reward_text, (panel_x + 20, rewards_y + 30 + i * 20))

        total_text = font_small.render(f"Total: {total:+.2f}", True, color)
        screen.blit(total_text, (panel_x + 180, rewards_y + 30 + i * 20))

    # Victory condition
    victory_y = rewards_y + 110
    adv_abs = abs(total_rewards[0])
    coop_total = total_rewards[1] + total_rewards[2]
    condition_text = font_medium.render("Victory Condition:", True, BLACK)
    screen.blit(condition_text, (panel_x + 10, victory_y))

    condition_details = font_small.render("Coop Total > Adv Abs", True, BLACK)
    screen.blit(condition_details, (panel_x + 20, victory_y + 30))

    condition_math = font_small.render(f"{coop_total:.2f} > {adv_abs:.2f}", True,
                                       (0, 150, 0) if coop_total > adv_abs else RED)
    screen.blit(condition_math, (panel_x + 20, victory_y + 50))

    # Game Legend
    legend_y = victory_y + 90
    legend_title = font_medium.render("Legend", True, BLACK)
    screen.blit(legend_title, (panel_x + 10, legend_y))

    items = [
        ("Adv (DQN)", DARK_RED, "DQN-controlled chaser"),
        ("Coop", BLUE, "Reach landmarks"),
        ("LM", GREEN, "Landmark"),
        ("Yellow", YELLOW, "Target/Highlight"),
        ("Orange", ORANGE, "Danger")
    ]

    for i, (symbol, color, desc) in enumerate(items):
        y_pos = legend_y + 30 + i * 24
        pygame.draw.circle(screen, color, (panel_x + 15, y_pos), 6)
        desc_text = font_small.render(f"{symbol}: {desc}", True, BLACK)
        screen.blit(desc_text, (panel_x + 25, y_pos - 6))


def get_action_description(action):
    """Get human-readable description of action"""
    actions_desc = {
        0: "Chase Cooperator 1",
        1: "Chase Cooperator 2",
        2: "Patrol Center",
        3: "Ambush Strategy",
        4: "Random Exploration"
    }
    return actions_desc.get(action, "Unknown Action")


def execute_action(action, adversary_pos, cooperator1_pos, cooperator2_pos):
    """Execute the selected action and return new position"""
    new_pos = adversary_pos.copy()

    if action == 0:  # Chase cooperator 1
        target_pos = cooperator1_pos
    elif action == 1:  # Chase cooperator 2
        target_pos = cooperator2_pos
    elif action == 2:  # Patrol center
        target_pos = [0, 0]
    elif action == 3:  # Ambush - move toward midpoint
        target_pos = [(cooperator1_pos[0] + cooperator2_pos[0]) / 2,
                      (cooperator1_pos[1] + cooperator2_pos[1]) / 2]
    else:  # Random exploration
        move_x = np.random.uniform(-ADVERSARY_SPEED, ADVERSARY_SPEED)
        move_y = np.random.uniform(-ADVERSARY_SPEED, ADVERSARY_SPEED)
        new_pos[0] += move_x
        new_pos[1] += move_y
        return new_pos

    # Move toward target
    direction = [target_pos[0] - adversary_pos[0],
                 target_pos[1] - adversary_pos[1]]
    dist = calculate_distance(adversary_pos, target_pos)
    if dist > 0:
        new_pos[0] += direction[0] / dist * ADVERSARY_SPEED
        new_pos[1] += direction[1] / dist * ADVERSARY_SPEED

    return new_pos


def calculate_reward(adversary_pos, cooperator1_pos, cooperator2_pos, capture_occurred, step_reward):
    """Calculate reward for DQN agent"""
    reward = step_reward

    # Check for captures
    if capture_occurred:
        reward += 15.0

    # Distance-based rewards
    dist_to_coop1 = calculate_distance(adversary_pos, cooperator1_pos)
    dist_to_coop2 = calculate_distance(adversary_pos, cooperator2_pos)

    # Reward for getting close to cooperators
    if dist_to_coop1 < 0.3:
        reward += 2.0
    elif dist_to_coop1 < 0.6:
        reward += 0.5

    if dist_to_coop2 < 0.3:
        reward += 2.0
    elif dist_to_coop2 < 0.6:
        reward += 0.5

    # Small penalty for not making progress
    reward -= 0.1

    return reward


def plot_training_progress(dqn_agent, episode):
    """Plot training progress with enhanced visualizations"""
    if not dqn_agent.losses:
        return

    plt.figure(figsize=(15, 20))

    # Plot 1: Overall Loss Trend
    plt.subplot(4, 2, 1)
    plt.plot(dqn_agent.losses)
    plt.title('Overall Loss Trend')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')
    plt.grid(True, alpha=0.3)

    # Plot 3: Episode Rewards and Average Rewards
    plt.subplot(4, 2, 2)
    if dqn_agent.episode_rewards:
        plt.plot(dqn_agent.episode_rewards, label='Total Reward per Episode')
        if hasattr(dqn_agent, 'average_rewards') and dqn_agent.average_rewards:
            plt.plot(dqn_agent.average_rewards, label='Avg Reward (10 episodes)', color='red', linewidth=2)
        plt.title('Episode Rewards')
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.legend()
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No episode rewards yet', ha='center', va='center')
        plt.axis('off')

    # Plot 4: Average Q Values
    plt.subplot(4, 2, 3)
    if hasattr(dqn_agent, 'q_values') and dqn_agent.q_values:
        # 计算移动平均Q值以减少噪声
        window_size = max(1, len(dqn_agent.q_values) // 50)
        if window_size > 0:
            smoothed_q = []
            for i in range(len(dqn_agent.q_values)):
                start_idx = max(0, i - window_size + 1)
                end_idx = i + 1
                avg = np.mean(dqn_agent.q_values[start_idx:end_idx])
                smoothed_q.append(avg)
            plt.plot(smoothed_q)
        else:
            plt.plot(dqn_agent.q_values)
        plt.title('Average Q Values')
        plt.xlabel('Training Step')
        plt.ylabel('Average Q Value')
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No Q value data available', ha='center', va='center')
        plt.axis('off')

    # Plot 7: Action Distribution
    plt.subplot(4, 2, 4)
    if hasattr(dqn_agent, 'action_counts') and np.sum(dqn_agent.action_counts) > 0:
        action_names = [get_action_description(i) for i in range(len(dqn_agent.action_counts))]
        plt.bar(range(len(dqn_agent.action_counts)), dqn_agent.action_counts)
        plt.title('Action Distribution')
        plt.xlabel('Action')
        plt.ylabel('Frequency')
        plt.xticks(range(len(dqn_agent.action_counts)), action_names, rotation=45, ha='right')
        plt.grid(True, alpha=0.3, axis='y')
    else:
        plt.text(0.5, 0.5, 'No action data available', ha='center', va='center')
        plt.axis('off')

    plt.tight_layout()

    # Save the figure
    plt.savefig(f'training_progress_episode_{episode}.png')

    # Also save a simplified version for the latest progress
    plt.figure(figsize=(10, 6))
    plt.plot(dqn_agent.losses)
    plt.title(f'Training Loss (Episode {episode})')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('latest_training_progress.png')
    plt.close('all')

    print(f"📊 Loss visualization updated and saved")


def main():
    print("✅ Pygame initialized successfully")

    # Create simulation data
    agents, landmarks = create_simulation_data()

    # Initialize DQN agent with correct state size (15)
    state_size = 15
    action_size = 5
    dqn_agent = DQNAgent(state_size, action_size)

    print("📦 Environment configured")
    print(f"   Agents: {len(agents)} (1 DQN Adversary + 2 Cooperators)")
    print(f"   Landmarks: {len(landmarks)}")
    print(f"   State size: {state_size}, Action size: {action_size}")

    print("\n🤖 DQN Configuration:")
    print(f"   Learning Rate: {LEARNING_RATE}")
    print(f"   Discount Factor: {GAMMA}")
    print(f"   Batch Size: {BATCH_SIZE}")
    print(f"   Memory Size: {MEMORY_SIZE}")
    print(f"   Epsilon: {EPSILON_START}->{EPSILON_END} (decay: {EPSILON_DECAY})")

    print("\n🎯 Game Rules:")
    print("  🔴 Adversary (DQN): Learns optimal chasing strategy")
    print("  🔵 Cooperator: Reach landmarks for positive points")
    print("  🏆 Victory: Cooperator total > |Adversary total|")
    print("  ⚠️  Press 'S' to save model, 'L' to load model")

    print("\n🎮 Starting DQN training...")
    print("💡 Press ESC to exit")
    print("-" * 50)

    running = True
    clock = pygame.time.Clock()

    # Training parameters - Increased for better learning
    max_episodes = 500  # 增加训练轮数
    max_steps = 500  # 增加每轮的步数
    episode = 0

    # World boundaries
    WORLD_BOUNDS = 1.4

    while running and episode < max_episodes:
        # Reset environment for new episode
        agents, landmarks = create_simulation_data()
        total_rewards = [0, 0, 0]
        episode_reward = 0
        step = 0
        episode_start_time = time.time()
        success_count = 0
        danger_count = 0
        capture_count = 0

        # Get initial state
        current_state = get_state(
            agents[0]['pos'],
            agents[1]['pos'],
            agents[2]['pos'],
            landmarks
        )

        for step in range(max_steps):
            # Process events
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_ESCAPE:
                        running = False
                    elif event.key == pygame.K_s:
                        # Save model
                        dqn_agent.save_model(f'dqn_model_episode_{episode}.pth')
                        print(f"💾 Model saved at episode {episode}")
                    elif event.key == pygame.K_l:
                        # Load model
                        try:
                            dqn_agent.load_model('dqn_model.pth')
                            print("📂 Model loaded successfully")
                        except:
                            print("❌ No model found to load")

            if not running:
                break

            # DQN Action selection
            current_action = dqn_agent.act(current_state)

            # Execute action
            old_adversary_pos = agents[0]['pos'].copy()
            agents[0]['pos'] = execute_action(
                current_action,
                agents[0]['pos'],
                agents[1]['pos'],
                agents[2]['pos']
            )

            # Apply boundary limits
            agents[0]['pos'][0] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, agents[0]['pos'][0]))
            agents[0]['pos'][1] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, agents[0]['pos'][1]))

            # Move cooperators
            rewards = [0, 0, 0]
            current_capture = False

            for i, agent in enumerate(agents[1:], 1):  # Cooperators only
                target_idx = agent['target_landmark']
                target_pos = landmarks[target_idx]['pos']

                # Cooperator movement logic
                target_direction = [target_pos[0] - agent['pos'][0],
                                    target_pos[1] - agent['pos'][1]]
                target_distance = calculate_distance(agent['pos'], target_pos)

                # Enhanced evasion behavior with predictive components
                avoid_direction = [0, 0]
                dist_to_adversary = calculate_distance(agent['pos'], agents[0]['pos'])

                # Calculate adversary movement direction for predictive evasion
                adv_movement_dir = [agents[0]['pos'][0] - old_adversary_pos[0],
                                    agents[0]['pos'][1] - old_adversary_pos[1]]
                adv_movement_magnitude = math.sqrt(adv_movement_dir[0] ** 2 + adv_movement_dir[1] ** 2)

                if dist_to_adversary < DANGER_THRESHOLD:
                    # Basic avoidance direction (directly away from adversary)
                    avoid_dir = [agent['pos'][0] - agents[0]['pos'][0],
                                 agent['pos'][1] - agents[0]['pos'][1]]
                    avoid_dist = calculate_distance(agent['pos'], agents[0]['pos'])

                    if avoid_dist > 0:
                        # Distance-based avoidance strength - reduced for more challenging gameplay
                        base_avoid_strength = 0.04 * (DANGER_THRESHOLD - dist_to_adversary) / DANGER_THRESHOLD

                        # Add predictive avoidance component
                        if adv_movement_magnitude > 0:
                            # Predict where adversary is moving and avoid that path
                            predicted_avoid_dir = [-adv_movement_dir[0] / adv_movement_magnitude,
                                                   -adv_movement_dir[1] / adv_movement_magnitude]
                            # Scale prediction influence based on distance (closer = more prediction influence) - reduced for more challenging gameplay
                            prediction_factor = 0.015 * (DANGER_THRESHOLD - dist_to_adversary) / DANGER_THRESHOLD
                            avoid_direction[0] += predicted_avoid_dir[0] * prediction_factor
                            avoid_direction[1] += predicted_avoid_dir[1] * prediction_factor

                        # Add base avoidance
                        avoid_direction[0] += avoid_dir[0] / avoid_dist * base_avoid_strength
                        avoid_direction[1] += avoid_dir[1] / avoid_dist * base_avoid_strength

                        # Add randomness to prevent predictable patterns - reduced randomness
                        if dist_to_adversary < DANGER_THRESHOLD * 0.7:
                            avoid_direction[0] += np.random.uniform(-0.005, 0.005)
                            avoid_direction[1] += np.random.uniform(-0.005, 0.005)

                # Combined movement
                if target_distance > 0.1:
                    agent['pos'][0] += target_direction[0] / target_distance * COOPERATOR_SPEED
                    agent['pos'][1] += target_direction[1] / target_distance * COOPERATOR_SPEED
                    agent['pos'][0] += avoid_direction[0]
                    agent['pos'][1] += avoid_direction[1]
                else:
                    agent['pos'][0] += np.random.uniform(-0.008, 0.008) + avoid_direction[0]
                agent['pos'][1] += np.random.uniform(-0.008, 0.008) + avoid_direction[1]

                # Boundary limits
                agent['pos'][0] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, agent['pos'][0]))
                agent['pos'][1] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, agent['pos'][1]))

                # Check for capture
                if calculate_distance(agents[0]['pos'], agent['pos']) < CAPTURE_THRESHOLD:
                    current_capture = True
                    capture_count += 1
                    agent['pos'] = get_random_position()

                # Cooperator rewards
                base_reward = 0
                if target_distance < TARGET_THRESHOLD * 1.5:
                    base_reward = 3.5 - (target_distance * 20)
                    if target_distance < TARGET_THRESHOLD:
                        base_reward += 8.0
                        success_count += 1
                        # Refresh landmark position when reached
                        landmarks[target_idx]['pos'] = get_random_position()
                else:
                    base_reward = 1.2 - (target_distance * 2.5)

                if dist_to_adversary < DANGER_THRESHOLD * 0.8:
                    danger_penalty = 2.5 * (DANGER_THRESHOLD * 0.8 - dist_to_adversary) / (DANGER_THRESHOLD * 0.8)
                    base_reward -= danger_penalty
                    danger_count += 1

                rewards[i] = base_reward
                agent['score'] += base_reward

            # Calculate DQN reward
            dqn_reward = calculate_reward(
                agents[0]['pos'],
                agents[1]['pos'],
                agents[2]['pos'],
                current_capture,
                rewards[0]
            )
            rewards[0] = dqn_reward
            agents[0]['score'] += dqn_reward
            episode_reward += dqn_reward

            # Get next state
            next_state = get_state(
                agents[0]['pos'],
                agents[1]['pos'],
                agents[2]['pos'],
                landmarks
            )

            # Check if episode should end
            done = (step == max_steps - 1)

            # Remember experience
            dqn_agent.remember(current_state, current_action, dqn_reward, next_state, done)

            # Train DQN
            loss = dqn_agent.replay()

            # Update total rewards for display
            for i in range(len(rewards)):
                total_rewards[i] += rewards[i]

            # Update current state
            current_state = next_state

            # Determine game status for display
            adv_abs = abs(total_rewards[0])
            coop_total = total_rewards[1] + total_rewards[2]

            if coop_total > adv_abs and coop_total > 15:
                game_status = "Cooperators Leading!"
            elif step >= max_steps - 50:
                game_status = "Ending Soon"
            elif current_capture:
                game_status = "DQN Capture!"
            else:
                game_status = f"Training - Episode {episode}"

            # Visualization
            screen.fill(BACKGROUND)
            draw_grid()

            # Draw landmarks
            for i, landmark in enumerate(landmarks):
                is_highlighted = any(agent['target_landmark'] == i for agent in agents if agent['type'] == 'cooperator')
                is_occupied = any(calculate_distance(agent['pos'], landmark['pos']) < TARGET_THRESHOLD
                                  for agent in agents if agent['type'] == 'cooperator')
                draw_landmark(landmark['pos'], i, is_highlighted, is_occupied)

            # Draw danger zones
            for agent in agents[1:]:
                draw_danger_zone(agent['pos'], agents[0]['pos'])

            # Draw agents
            for i, agent in enumerate(agents):
                is_adversary = agent['type'] == 'adversary'
                is_dqn_agent = (i == 0)

                target_distance = None
                is_success = False
                is_danger = False

                if not is_adversary:
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    target_distance = calculate_distance(agent['pos'], target_pos)
                    is_success = target_distance < TARGET_THRESHOLD

                    dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
                    if dist_to_adv < DANGER_THRESHOLD * 0.8:
                        is_danger = True

                draw_agent(agent['pos'], is_adversary, i, target_distance, is_success, is_danger, is_dqn_agent)

            # Draw DQN panel
            draw_dqn_panel(step + 1, rewards, total_rewards, game_status, dqn_agent,
                           current_state, current_action, success_count, danger_count,
                           capture_count, episode)

            pygame.display.flip()
            clock.tick(30)

            # Console output every 50 steps
            if (step + 1) % 50 == 0:
                print(f"Episode {episode}, Step {step + 1}:")
                print(f"  DQN Reward: {dqn_reward:+.2f} (Total: {total_rewards[0]:+.2f})")
                print(f"  Action: {get_action_description(current_action)}")
                print(f"  Epsilon: {dqn_agent.epsilon:.3f}")
                print(f"  Memory: {len(dqn_agent.memory)}")
                print(f"  Captures: {capture_count}")

        # End of episode
        dqn_agent.episode_rewards.append(episode_reward)
        # 计算平均回合奖励（最近10个回合）
        recent_rewards = dqn_agent.episode_rewards[-min(10, len(dqn_agent.episode_rewards)):]
        avg_reward = np.mean(recent_rewards)
        dqn_agent.average_rewards.append(avg_reward)

        print(f"\n🎯 Episode {episode} completed:")
        print(f"   Total Reward: {episode_reward:.2f}")
        print(f"   Captures: {capture_count}")
        print(f"   Successes: {success_count}")
        print(f"   Epsilon: {dqn_agent.epsilon:.4f}")
        print(f"   Memory Size: {len(dqn_agent.memory)}")
        print("-" * 40)

        # 在每个回合结束时生成所有可视化图表
        # 记录当前回合奖励
        dqn_agent.episode_rewards.append(episode_reward)

        # 计算并记录平均回合奖励
        if len(dqn_agent.episode_rewards) > 0:
            window_size = min(10, len(dqn_agent.episode_rewards))
            avg_reward = np.mean(dqn_agent.episode_rewards[-window_size:])
            dqn_agent.average_rewards.append(avg_reward)

        # 每回合进行可视化
        plot_training_progress(dqn_agent, episode)

        episode_duration = time.time() - episode_start_time
        print(
            f"📈 Episode {episode + 1}/{max_episodes} completed in {episode_duration:.2f}s - Total Reward: {episode_reward:.2f}")

        episode += 1

    # Save final model
    dqn_agent.save_model('dqn_model_final.pth')

    # Final training plot
    plot_training_progress(dqn_agent, episode)

    pygame.quit()
    print("✅ DQN training completed!")


if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback

        traceback.print_exc()
        pygame.quit()
        sys.exit()

# %% [markdown]
# ## Multi-Agent Deep Deterministic Policy Gradient

# %%
import pygame
import numpy as np
import time
import math
import sys
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
import os


import matplotlib
matplotlib.use('Agg')

print("=" * 60)
print("Multi-Agent Environment - Pursuit Evasion Game with MADDPG")
print("===== HYPERPARAMETER ADJUSTED VERSION ====")
print("=" * 60)

# Initialize pygame
pygame.init()

# Set up window
WIDTH, HEIGHT = 1200, 800
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Multi-Agent Environment - Pursuit Evasion Game with MADDPG [ADJUSTED PARAMS]")

# Color definitions
BACKGROUND = (240, 240, 240)
RED = (255, 80, 80)  # Adversary
BLUE = (80, 80, 255)  # Cooperator
GREEN = (80, 180, 80)  # Landmark
YELLOW = (255, 200, 0)  # Highlight
PURPLE = (180, 80, 200)  # Interaction effect
ORANGE = (255, 150, 50)  # Warning
BLACK = (40, 40, 40)
GRAY = (200, 200, 200)
LIGHT_GRAY = (220, 220, 220)  # For finer grid
WHITE = (255, 255, 255)
DARK_RED = (180, 0, 0)  # Adversary agent highlight

# Fonts
font_large = pygame.font.Font(None, 32)
font_medium = pygame.font.Font(None, 24)
font_small = pygame.font.Font(None, 18)

# Environment parameters
SCALE = 180
CENTER_X = WIDTH // 3
CENTER_Y = HEIGHT // 2

# Size parameters
AGENT_RADIUS = 8
LANDMARK_RADIUS = 6
DANGER_THRESHOLD = 0.4
TARGET_THRESHOLD = 0.08
CAPTURE_THRESHOLD = 0.15

# UI parameters
INFO_PANEL_WIDTH = 400
INFO_PANEL_HEIGHT = 600
INFO_PANEL_MARGIN = 20
MINIMAP_HEIGHT = 150

# Movement speeds
COOPERATOR_SPEED = 0.018
ADVERSARY_SPEED = COOPERATOR_SPEED * 1.8

# MADDPG Parameters - 🚨 
STATE_SIZE = 8 
ACTION_SIZE = 2  
BATCH_SIZE = 64  
LEARNING_RATE = 0.003  
GAMMA = 0.90  
TAU = 0.01  
MEMORY_SIZE = 50000  
TRAIN_EVERY = 4  

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# MADDPG Network Definitions
class Actor(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=128):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)
        self.tanh = nn.Tanh()
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.tanh(self.fc3(x))

class Critic(nn.Module):
    def __init__(self, full_state_size, full_action_size, hidden_size=128):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(full_state_size + full_action_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, 1)
        
    def forward(self, full_state, full_action):
        x = torch.cat([full_state, full_action], dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


class OUNoise:
    def __init__(self, size, mu=0.0, theta=0.1, sigma=0.1):  
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.reset()
        
    def reset(self):
        self.state = np.copy(self.mu)
        
    def sample(self):
        dx = self.theta * (self.mu - self.state) + self.sigma * np.random.randn(len(self.state))
        self.state += dx
        return self.state

# MADDPG Agent class
class MADDPGAgent:
    def __init__(self, state_size, action_size, num_agents, agent_index):
        self.state_size = state_size
        self.action_size = action_size
        self.num_agents = num_agents
        self.agent_index = agent_index
        
        # Actor networks
        self.actor = Actor(state_size, action_size).to(device)
        self.actor_target = Actor(state_size, action_size).to(device)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LEARNING_RATE)
        
        # Critic networks
        full_state_size = state_size * num_agents
        full_action_size = action_size * num_agents
        self.critic = Critic(full_state_size, full_action_size).to(device)
        self.critic_target = Critic(full_state_size, full_action_size).to(device)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LEARNING_RATE)
        
        # Initialize target networks with same weights
        self.soft_update(self.actor, self.actor_target, 1.0)
        self.soft_update(self.critic, self.critic_target, 1.0)
        
        # Training parameters
        self.gamma = GAMMA
        self.tau = TAU
        self.noise = OUNoise(action_size)

        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.min_epsilon = 0.1
        
        # Training statistics
        self.actor_losses = []
        self.critic_losses = []
        self.episode_rewards = []
        self.average_rewards = []
        self.q_values = []
        self.recent_actions = deque(maxlen=1000)
        self.action_counts = np.zeros(8)
        
    def act(self, state, add_noise=True):
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        action = self.actor(state_tensor).squeeze(0).detach().cpu().numpy()
        
        if add_noise:
            noise = self.noise.sample() * self.epsilon
            action += noise
            action = np.clip(action, -1, 1)
        
        self.recent_actions.append(action.copy())
        
       
        dx, dy = action
        angle = math.atan2(dy, dx)
        direction = int((angle + math.pi) / (math.pi / 4)) % 8
        self.action_counts[direction] += 1
        
        return action
    
    def decay_epsilon(self):
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
    
    def replay(self, minibatch):
        if minibatch is None or len(minibatch) == 0:
            return 0.0, 0.0
            
        batch_size = len(minibatch)
        
        states_batch = torch.FloatTensor([experience[0] for experience in minibatch]).to(device)
        actions_batch = torch.FloatTensor([experience[1] for experience in minibatch]).to(device)
        rewards_batch = torch.FloatTensor([experience[2] for experience in minibatch]).to(device)
        next_states_batch = torch.FloatTensor([experience[3] for experience in minibatch]).to(device)
        dones_batch = torch.FloatTensor([experience[4] for experience in minibatch]).to(device)
        
        rewards_batch = rewards_batch[:, self.agent_index].unsqueeze(1)
        dones_batch = dones_batch[:, self.agent_index].unsqueeze(1)
        
        # Reshape for multi-agent
        states_batch = states_batch.view(batch_size, -1)
        actions_batch = actions_batch.view(batch_size, -1)
        next_states_batch = next_states_batch.view(batch_size, -1)
        
        # Update critic
        with torch.no_grad():
            next_actions = []
            for i in range(self.num_agents):
                next_agent_state = next_states_batch[:, i*self.state_size:(i+1)*self.state_size]
                next_agent_action = self.actor_target(next_agent_state)
                next_actions.append(next_agent_action)
            next_actions_full = torch.cat(next_actions, dim=1)
            target_q = self.critic_target(next_states_batch, next_actions_full)
            target_q = rewards_batch + self.gamma * target_q * (1 - dones_batch)
        
        current_q = self.critic(states_batch, actions_batch)
        critic_loss = F.mse_loss(current_q, target_q.detach())
        
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.critic_optimizer.step()
        
        # Update actor
        current_actions = []
        for i in range(self.num_agents):
            agent_state = states_batch[:, i*self.state_size:(i+1)*self.state_size]
            if i == self.agent_index:
                agent_action = self.actor(agent_state)
            else:
                agent_action = actions_batch[:, i*self.action_size:(i+1)*self.action_size].detach()
            current_actions.append(agent_action)
        current_actions_full = torch.cat(current_actions, dim=1)
        
        actor_loss = -self.critic(states_batch, current_actions_full).mean()
        
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
        self.actor_optimizer.step()

        with torch.no_grad():
            avg_q = current_q.mean().item()
            self.q_values.append(avg_q)
        
        # Soft update target networks
        self.soft_update(self.actor, self.actor_target, self.tau)
        self.soft_update(self.critic, self.critic_target, self.tau)
        
        # Store losses
        self.actor_losses.append(actor_loss.item())
        self.critic_losses.append(critic_loss.item())
        
        return actor_loss.item(), critic_loss.item()
    
    def soft_update(self, local_model, target_model, tau):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

    def save_model(self, filename):
        """Save the model weights"""
        torch.save({
            'actor_state_dict': self.actor.state_dict(),
            'actor_target_state_dict': self.actor_target.state_dict(),
            'critic_state_dict': self.critic.state_dict(),
            'critic_target_state_dict': self.critic_target.state_dict(),
            'actor_optimizer_state_dict': self.actor_optimizer.state_dict(),
            'critic_optimizer_state_dict': self.critic_optimizer.state_dict(),
            'actor_losses': self.actor_losses,
            'critic_losses': self.critic_losses,
            'episode_rewards': self.episode_rewards,
            'average_rewards': self.average_rewards,
            'q_values': self.q_values,
            'action_counts': self.action_counts,
            'epsilon': self.epsilon, 
        }, filename)

    def load_model(self, filename):
        """Load the model weights"""
        if not os.path.exists(filename):
            print(f"❌ Error: Model file not found at {filename}")
            return
            
        try:
            checkpoint = torch.load(filename, map_location=device)
            self.actor.load_state_dict(checkpoint['actor_state_dict'])
            self.actor_target.load_state_dict(checkpoint['actor_target_state_dict'])
            self.critic.load_state_dict(checkpoint['critic_state_dict'])
            self.critic_target.load_state_dict(checkpoint['critic_target_state_dict'])
            self.actor_optimizer.load_state_dict(checkpoint['actor_optimizer_state_dict'])
            self.critic_optimizer.load_state_dict(checkpoint['critic_optimizer_state_dict'])
            self.actor_losses = checkpoint.get('actor_losses', [])
            self.critic_losses = checkpoint.get('critic_losses', [])
            self.episode_rewards = checkpoint.get('episode_rewards', [])
            self.average_rewards = checkpoint.get('average_rewards', [])
            self.q_values = checkpoint.get('q_values', [])
            self.action_counts = checkpoint.get('action_counts', np.zeros(8))
            self.epsilon = checkpoint.get('epsilon', 1.0)
            print(f"📂 Model loaded successfully from {filename}")
        except Exception as e:
            print(f"❌ Error loading model from {filename}: {e}")

def create_simulation_data():
    """Create simulation data"""
    agents = [
        {'pos': [-1.0, 0.6], 'type': 'adversary', 'target_landmark': None, 'score': 0},
        {'pos': [0.3, -0.8], 'type': 'cooperator', 'target_landmark': 0, 'score': 0},
        {'pos': [0.8, 0.2], 'type': 'cooperator', 'target_landmark': 1, 'score': 0}
    ]
    landmarks = [
        {'pos': [-1.2, -1.0], 'occupied': False, 'value': 10},
        {'pos': [1.1, 1.0], 'occupied': False, 'value': 10}
    ]
    return agents, landmarks

def get_random_position():
    """Generate random position within world bounds"""
    WORLD_BOUNDS = 1.4
    x = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    y = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    return [x, y]

def get_agent_state(agent, agents, landmarks):
    """Get state for a single agent with boundary awareness"""
    state = []
    WORLD_BOUNDS = 1.4
    
    # Agent's own position
    state.extend(agent['pos'])
    
    # Target position
    if agent['type'] == 'adversary':
        min_dist = float('inf')
        target_pos = [0, 0]
        for other_agent in agents:
            if other_agent['type'] == 'cooperator':
                dist = calculate_distance(agent['pos'], other_agent['pos'])
                if dist < min_dist:
                    min_dist = dist
                    target_pos = other_agent['pos']
        state.extend(target_pos)
    else:
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        state.extend(target_pos)
    
    # Boundary distance information
    state.extend([
        WORLD_BOUNDS - agent['pos'][0],  # Right boundary distance
        agent['pos'][0] + WORLD_BOUNDS,  # Left boundary distance
        WORLD_BOUNDS - agent['pos'][1],  # Upper boundary distance
        agent['pos'][1] + WORLD_BOUNDS   # Lower boundary distance
    ])
    
    return np.array(state, dtype=np.float32)

def get_full_state(agents, landmarks):
    """Get full state for all agents"""
    full_state = []
    for agent in agents:
        agent_state = get_agent_state(agent, agents, landmarks)
        full_state.extend(agent_state)
    return np.array(full_state, dtype=np.float32)

def calculate_distance(pos1, pos2):
    """Calculate distance between two positions"""
    return math.sqrt((pos1[0] - pos2[0]) ** 2 + (pos1[1] - pos2[1]) ** 2)

def world_to_screen(pos):
    """Convert world coordinates to screen coordinates"""
    x = int(pos[0] * SCALE + CENTER_X)
    y = int(pos[1] * SCALE + CENTER_Y)
    return x, y

def draw_grid():
    """Draw grid"""
    grid_right_boundary = WIDTH - INFO_PANEL_WIDTH - 10

    # Draw dense grid lines
    dense_grid_range = 40
    for i in range(-dense_grid_range, dense_grid_range + 1):
        x = CENTER_X + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (x, 50), (x, HEIGHT - 50), 1)
        y = CENTER_Y + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (50, y), (grid_right_boundary, y), 1)

    # Draw main grid lines
    main_grid_range = 4
    for i in range(-main_grid_range, main_grid_range + 1):
        x = CENTER_X + i * SCALE
        pygame.draw.line(screen, GRAY, (x, 50), (x, HEIGHT - 50), 2)
        y = CENTER_Y + i * SCALE
        pygame.draw.line(screen, GRAY, (50, y), (grid_right_boundary, y), 2)

    # Draw axes
    pygame.draw.line(screen, BLACK, (CENTER_X, 50), (CENTER_X, HEIGHT - 50), 3)
    pygame.draw.line(screen, BLACK, (50, CENTER_Y), (grid_right_boundary, CENTER_Y), 3)

    # Draw coordinate labels
    for i in range(-main_grid_range, main_grid_range + 1):
        if i != 0:
            x = CENTER_X + i * SCALE
            label_value = i * 10
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (x - 8, CENTER_Y + 12))

            y = CENTER_Y + i * SCALE
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (CENTER_X + 12, y - 8))

    # Draw origin label
    origin_label = font_small.render("0", True, BLACK)
    screen.blit(origin_label, (CENTER_X + 5, CENTER_Y + 12))

def draw_landmark(pos, index, is_highlighted=False, is_occupied=False):
    """Draw landmark"""
    x, y = world_to_screen(pos)

    if is_occupied:
        color = PURPLE
    elif is_highlighted:
        color = YELLOW
    else:
        color = GREEN

    pygame.draw.circle(screen, color, (x, y), LANDMARK_RADIUS)
    pygame.draw.circle(screen, WHITE, (x, y), LANDMARK_RADIUS // 2)

    text = font_small.render(f"LM{index + 1}", True, BLACK)
    screen.blit(text, (x - 12, y - LANDMARK_RADIUS - 12))

def draw_agent(pos, is_adversary, agent_id, target_distance=None, is_success=False, is_danger=False):
    """Draw agent"""
    x, y = world_to_screen(pos)

    if is_success:
        color = PURPLE
    elif is_danger:
        color = ORANGE
    else:
        color = DARK_RED if is_adversary else BLUE

    radius = AGENT_RADIUS + 2 if is_adversary else AGENT_RADIUS
    pygame.draw.circle(screen, color, (x, y), radius)
    pygame.draw.circle(screen, WHITE, (x, y), radius, 2)

    # Agent label
    agent_type = "Adv" if is_adversary else f"C{agent_id}"
    text = font_small.render(agent_type, True, BLACK)
    screen.blit(text, (x - 8, y - radius - 10))

def draw_danger_zone(agent_pos, adversary_pos):
    """Draw danger zone"""
    if calculate_distance(agent_pos, adversary_pos) < DANGER_THRESHOLD:
        x1, y1 = world_to_screen(agent_pos)
        x2, y2 = world_to_screen(adversary_pos)
        pygame.draw.line(screen, ORANGE, (x1, y1), (x2, y2), 2)

def apply_continuous_action(pos, action, speed, agent_type):
    """Apply continuous action to agent position"""
    dx, dy = action
    move_magnitude = math.sqrt(dx**2 + dy**2)
    
    if move_magnitude > 0:
        # Normalize and scale by speed
        dx = dx / move_magnitude * speed
        dy = dy / move_magnitude * speed
    else:
        dx, dy = 0, 0
    
    new_pos = [pos[0] + dx, pos[1] + dy]
    
    # Ensure new position is within bounds
    WORLD_BOUNDS = 1.4
    new_pos[0] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[0]))
    new_pos[1] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[1]))
    
    return new_pos

def calculate_rewards(agents, landmarks, capture_occurred):
    """🚨 增强的奖励函数，防止卡边界"""
    rewards = [0, 0, 0]
    WORLD_BOUNDS = 1.4
    
    adversary = agents[0]
    for i, coop in enumerate(agents[1:], 1):
        dist = calculate_distance(adversary['pos'], coop['pos'])
        
        if dist < 1.0:
            proximity_reward = (1.0 - dist) * 2.0
            rewards[0] += proximity_reward
        
        if capture_occurred and dist < CAPTURE_THRESHOLD:
            rewards[0] += 15.0
    
    for i, agent in enumerate(agents[1:], 1):
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        target_dist = calculate_distance(agent['pos'], target_pos)
        
        if target_dist < 1.0:
            progress_reward = (1.0 - target_dist) * 3.0
            rewards[i] += progress_reward
        
        if target_dist < TARGET_THRESHOLD:
            rewards[i] += 20.0
        
        dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
        if dist_to_adv < 0.4:
            danger_penalty = (0.4 - dist_to_adv) * 8.0
            rewards[i] -= danger_penalty
        
        pos = agent['pos']
        boundary_penalty = 0
        if abs(pos[0]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[0])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
        if abs(pos[1]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[1])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
            
        rewards[i] -= boundary_penalty
        
        if capture_occurred and dist_to_adv < CAPTURE_THRESHOLD:
            rewards[i] -= 15.0
    
    adv_pos = agents[0]['pos']
    adv_boundary_penalty = 0
    if abs(adv_pos[0]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[0])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    if abs(adv_pos[1]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[1])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    rewards[0] -= adv_boundary_penalty
    
    return rewards

def draw_maddpg_panel(step, rewards, total_rewards, game_status, maddpg_agents,
                     success_count, danger_count, capture_count, episode, shared_memory_size):
    """Draw MADDPG information panel"""
    panel_x = WIDTH - INFO_PANEL_WIDTH - INFO_PANEL_MARGIN
    panel_y = INFO_PANEL_MARGIN

    # Panel background
    pygame.draw.rect(screen, WHITE, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT))
    pygame.draw.rect(screen, BLACK, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT), 2)

    # Title
    title = font_large.render("MADDPG Pursuit Evasion", True, BLACK)
    screen.blit(title, (panel_x + 10, panel_y + 10))

    # Episode and step information
    episode_text = font_medium.render(f"Episode: {episode}", True, BLACK)
    screen.blit(episode_text, (panel_x + 10, panel_y + 50))

    step_text = font_medium.render(f"Step: {step}/1000", True, BLACK)
    screen.blit(step_text, (panel_x + 150, panel_y + 50))

    # Game status
    status_text = font_medium.render(f"Status: {game_status}", True,
                                     (0, 150, 0) if "Leading" in game_status else
                                     ORANGE if "Danger" in game_status or "Captured" in game_status else
                                     (0, 150, 0) if "Success" in game_status else BLACK)
    screen.blit(status_text, (panel_x + 10, panel_y + 80))

    # MADDPG Agent Information
    maddpg_y = panel_y + 110
    maddpg_title = font_medium.render("MADDPG Agents Info:", True, DARK_RED)
    screen.blit(maddpg_title, (panel_x + 10, maddpg_y))

    for i, agent in enumerate(maddpg_agents):
        agent_y = maddpg_y + 25 + i * 60
        agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
        agent_title = font_small.render(f"{agent_type}:", True, DARK_RED if i == 0 else BLUE)
        screen.blit(agent_title, (panel_x + 20, agent_y))
        
        memory_text = font_small.render(f"Shared Memory: {shared_memory_size}", True, BLACK)
        screen.blit(memory_text, (panel_x + 40, agent_y + 15))
        
        if agent.actor_losses:
            avg_actor_loss = np.mean(agent.actor_losses[-50:])
            actor_loss_text = font_small.render(f"Actor Loss: {avg_actor_loss:.4f}", True, BLACK)
            screen.blit(actor_loss_text, (panel_x + 40, agent_y + 30))

    # Statistics
    stats_y = maddpg_y + 200
    stats_title = font_medium.render("Statistics:", True, BLACK)
    screen.blit(stats_title, (panel_x + 10, stats_y))

    success_text = font_small.render(f"Success: {success_count}", True, (0, 150, 0))
    screen.blit(success_text, (panel_x + 20, stats_y + 30))

    danger_count_text = font_small.render(f"Danger: {danger_count}", True, ORANGE)
    screen.blit(danger_count_text, (panel_x + 20, stats_y + 50))

    capture_text = font_small.render(f"Captures: {capture_count}", True, RED)
    screen.blit(capture_text, (panel_x + 20, stats_y + 70))

    # Reward information
    rewards_y = stats_y + 110
    rewards_title = font_medium.render("Rewards:", True, BLACK)
    screen.blit(rewards_title, (panel_x + 10, rewards_y))

    agent_names = ["Adversary (MADDPG)", "Cooperator1 (MADDPG)", "Cooperator2 (MADDPG)"]
    for i, (name, reward, total) in enumerate(zip(agent_names, rewards, total_rewards)):
        color = DARK_RED if i == 0 else BLUE
        text = f"{name}: {reward:+.2f}"
        reward_text = font_small.render(text, True, color)
        screen.blit(reward_text, (panel_x + 20, rewards_y + 30 + i * 20))

        total_text = font_small.render(f"Total: {total:+.2f}", True, color)
        screen.blit(total_text, (panel_x + 180, rewards_y + 30 + i * 20))

    # Victory condition
    victory_y = rewards_y + 110
    adv_abs = abs(total_rewards[0])
    coop_total = total_rewards[1] + total_rewards[2]
    condition_text = font_medium.render("Victory Condition:", True, BLACK)
    screen.blit(condition_text, (panel_x + 10, victory_y))

    condition_details = font_small.render("Coop Total > Adv Abs", True, BLACK)
    screen.blit(condition_details, (panel_x + 20, victory_y + 30))

    condition_math = font_small.render(f"{coop_total:.2f} > {adv_abs:.2f}", True,
                                       (0, 150, 0) if coop_total > adv_abs else RED)
    screen.blit(condition_math, (panel_x + 20, victory_y + 50))

def plot_training_progress(maddpg_agents, episode):
    """Plot training progress with only 4 essential plots"""
    try:
        plt.figure(figsize=(16, 12))
        
        colors = ['#FF6B6B', '#4ECDC4', '#45B7D1']  # 红，青，蓝
        
        # Plot 1: Losses (Critic)
        plt.subplot(2, 2, 1)
        for i, agent in enumerate(maddpg_agents):
            agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
            
            if agent.critic_losses:
                window_size = max(1, len(agent.critic_losses) // 50)
                if window_size > 0:
                    smoothed_losses = []
                    for j in range(len(agent.critic_losses)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(agent.critic_losses[start_idx:end_idx])
                        smoothed_losses.append(avg)
                    plt.plot(smoothed_losses, label=f'{agent_type} Critic', color=colors[i], linestyle='-', alpha=0.8)

        plt.title('Critic Losses')
        plt.xlabel('Training Step')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 2: Episode Rewards 
        plt.subplot(2, 2, 2)
        for i, agent in enumerate(maddpg_agents):
            if agent.episode_rewards:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                
                if len(agent.episode_rewards) > 10:
                    window_size = min(10, len(agent.episode_rewards))
                    moving_avg = []
                    for j in range(len(agent.episode_rewards)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(agent.episode_rewards[start_idx:end_idx])
                        moving_avg.append(avg)
                    
                    plt.plot(moving_avg, label=f'{agent_type} (MA)', color=colors[i], linewidth=2)
                else:
                    plt.plot(agent.episode_rewards, label=agent_type, color=colors[i], linewidth=2)

        plt.title('Average Rewards')
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 3: Q Values
        plt.subplot(2, 2, 3)
        for i, agent in enumerate(maddpg_agents):
            if hasattr(agent, 'q_values') and agent.q_values:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                
                q_values = agent.q_values
                window_size = max(1, len(q_values) // 100)
                if window_size > 0:
                    smoothed_q = []
                    for j in range(len(q_values)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(q_values[start_idx:end_idx])
                        smoothed_q.append(avg)
                    plt.plot(smoothed_q[-1000:], label=agent_type, color=colors[i], alpha=0.8)
                else:
                    plt.plot(q_values[-1000:], label=agent_type, color=colors[i], alpha=0.8)
        
        plt.title('Q Values (Recent 1000 steps)')
        plt.xlabel('Training Step')
        plt.ylabel('Average Q Value')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 4: Action Distribution
        plt.subplot(2, 2, 4)
        
        directions = ['→', '↗', '↑', '↖', '←', '↙', '↓', '↘']
        
        bar_width = 0.25
        x_pos = np.arange(len(directions))
        
        for i, agent in enumerate(maddpg_agents):
            if hasattr(agent, 'action_counts') and np.sum(agent.action_counts) > 0:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                total_actions = np.sum(agent.action_counts)
                if total_actions > 0:
                    percentages = (agent.action_counts / total_actions) * 100
                    plt.bar(x_pos + i * bar_width, percentages, bar_width, 
                           label=agent_type, color=colors[i], alpha=0.8)
        
        plt.title('Action Distribution by Direction')
        plt.xlabel('Movement Direction')
        plt.ylabel('Percentage (%)')
        plt.xticks(x_pos + bar_width, directions)
        plt.legend()
        plt.grid(True, alpha=0.3, axis='y')
        
        plt.tight_layout()
        # 🚨 修改了文件名以进行区分
        plt.savefig(f'maddpg_HYPER_ADJUSTED_episode_{episode}.png', dpi=150, bbox_inches='tight')
        plt.close()
        
        print(f"📊 MADDPG training visualization updated - 4 essential plots saved")
    except Exception as e:
        print(f"❌ Error during plotting: {e}")


def check_training_progress(maddpg_agents, episode):
    """检查训练进度"""
    progress_indicators = []
    
    for i, agent in enumerate(maddpg_agents):
        if len(agent.episode_rewards) > 10:
            recent_rewards = agent.episode_rewards[-10:]
            avg_recent = np.mean(recent_rewards)
            avg_previous = np.mean(agent.episode_rewards[-20:-10]) if len(agent.episode_rewards) > 20 else avg_recent
            
            if avg_recent > avg_previous:
                progress_indicators.append(f"Agent{i}✓")
            else:
                progress_indicators.append(f"Agent{i}↓")
        
        if hasattr(agent, 'q_values') and len(agent.q_values) > 100:
            recent_q = agent.q_values[-100:]
            q_std = np.std(recent_q)
            if q_std < 5.0:  
                progress_indicators.append(f"Agent{i}_Q_stable")
    
    print(f"Episode {episode} Progress: {', '.join(progress_indicators)}")

def main():
    print("✅ Pygame initialized successfully")

    # Create simulation data
    agents, landmarks = create_simulation_data()

    # Initialize MADDPG agents
    maddpg_agents = []
    for i in range(NUM_AGENTS):
        agent = MADDPGAgent(STATE_SIZE, ACTION_SIZE, NUM_AGENTS, i)
        maddpg_agents.append(agent)

    shared_memory = deque(maxlen=MEMORY_SIZE)

    # Initialize TensorBoard - 🚨 修改了日志目录
    writer = SummaryWriter('runs/maddpg_pursuit_evasion_ADJUSTED')
    print("📊 TensorBoard logging enabled (Adjusted Params)")

    print("📦 Environment configured")
    print(f"   Agents: {NUM_AGENTS} (All using MADDPG)")
    print(f"   Landmarks: {len(landmarks)}")
    print(f"   State size: {STATE_SIZE}, Action size: {ACTION_SIZE}")

    print("\n🤖 MADDPG Configuration (ADJUSTED):")
    print(f"   Learning Rate: {LEARNING_RATE} (Original: 0.0003)")
    print(f"   Discount Factor: {GAMMA} (Original: 0.99)")
    print(f"   Batch Size: {BATCH_SIZE} (Original: 256)")
    print(f"   Tau: {TAU} (Original: 0.005)")
    print(f"   Memory Size: {MEMORY_SIZE}")
    print(f"   Train Every: {TRAIN_EVERY} steps")

    print("\n🎯 Game Rules:")
    print("  🔴 Adversary (MADDPG): Learns optimal chasing strategy")
    print("  🔵 Cooperators (MADDPG): Learn to reach landmarks while avoiding adversary")
    print("  🏆 Victory: Cooperator total > |Adversary total|")
    print("  ⚠️  Press 'S' to save model, 'L' to load model")

    print("\n🎮 Starting MADDPG training...")
    print("💡 Press ESC to exit")
    print("-" * 50)

    running = True
    clock = pygame.time.Clock()

    # Training parameters
    max_episodes = 500
    max_steps = 1000
    episode = 0

    # World boundaries
    WORLD_BOUNDS = 1.4

    while running and episode < max_episodes:
        # Reset environment for new episode
        agents, landmarks = create_simulation_data()
        total_rewards = [0, 0, 0]
        episode_rewards = [0, 0, 0]
        step = 0
        episode_start_time = time.time()
        success_count = 0
        danger_count = 0
        capture_count = 0
        
        last_positions = [agent['pos'].copy() for agent in agents]

        for step in range(max_steps):
            # Process events
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_ESCAPE:
                        running = False
                    elif event.key == pygame.K_s:
                        # Save models - 🚨 修改了文件名
                        for i, agent in enumerate(maddpg_agents):
                            agent.save_model(f'maddpg_HYPER_ADJUSTED_agent_{i}_episode_{episode}.pth')
                        print(f"💾 Models saved at episode {episode} (Adjusted)")
                    elif event.key == pygame.K_l:
                        # Load models
                        for i, agent in enumerate(maddpg_agents):
                            # 尝试加载一个标准名称的模型
                            agent.load_model(f'maddpg_agent_{i}.pth') 

            if not running:
                break

            # Get current full state
            current_full_state = get_full_state(agents, landmarks)
            
            # Get actions from all agents
            actions = []
            for i, agent in enumerate(agents):
                agent_state = get_agent_state(agent, agents, landmarks)
                action = maddpg_agents[i].act(agent_state, add_noise=True)
                actions.append(action)
            
            # Apply actions
            capture_occurred = False
            for i, agent in enumerate(agents):
                speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                agent['pos'] = apply_continuous_action(agent['pos'], actions[i], speed, agent['type'])
                
                # Check for capture (adversary only)
                if agent['type'] == 'adversary':
                    for j, other_agent in enumerate(agents):
                        if other_agent['type'] == 'cooperator':
                            dist = calculate_distance(agent['pos'], other_agent['pos'])
                            if dist < CAPTURE_THRESHOLD:
                                capture_occurred = True
                                capture_count += 1
                                other_agent['pos'] = get_random_position()

            # Check for success (cooperators only)
            for agent in agents:
                if agent['type'] == 'cooperator':
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    if calculate_distance(agent['pos'], target_pos) < TARGET_THRESHOLD:
                        success_count += 1
                        agent['pos'] = get_random_position()

            if step % 100 == 0 and step > 200:  
                for i, agent in enumerate(agents):
                    if random.random() < 0.2:  # 
                        random_action = np.random.uniform(-1, 1, 2)
                        speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                        agent['pos'] = apply_continuous_action(agent['pos'], random_action, speed, agent['type'])
                        print(f"🔄 Step {step}: Forced exploration for agent {i}")

            if step > 100 and step % 50 == 0:
                current_positions = [agent['pos'].copy() for agent in agents]
                position_changes = [calculate_distance(current_pos, last_pos) 
                                  for current_pos, last_pos in zip(current_positions, last_positions)]
                
                max_change = max(position_changes)
                all_near_boundary = all(
                    abs(pos[0]) > WORLD_BOUNDS * 0.8 or abs(pos[1]) > WORLD_BOUNDS * 0.8 
                    for pos in current_positions
                )
                
                if max_change < 0.02 and all_near_boundary:
                    print(f"🚨 Step {step}: Detected stuck agents, performing reset...")
                    for i in range(NUM_AGENTS):
                        agents[i]['pos'] = get_random_position()
                
                last_positions = current_positions

            # Calculate rewards
            rewards = calculate_rewards(agents, landmarks, capture_occurred)
            
            # Accumulate rewards
            for i in range(len(rewards)):
                total_rewards[i] += rewards[i]
                episode_rewards[i] += rewards[i]
                agents[i]['score'] += rewards[i]

            # Get next state
            next_full_state = get_full_state(agents, landmarks)
            
            # Check if episode should end
            done = (step == max_steps - 1)
            
            shared_memory.append((
                current_full_state.copy(), 
                np.array(actions, dtype=np.float32), 
                np.array(rewards, dtype=np.float32), 
                next_full_state.copy(), 
                np.array([done] * NUM_AGENTS, dtype=np.float32)
            ))

            if step % TRAIN_EVERY == 0 and len(shared_memory) > BATCH_SIZE:
                minibatch = random.sample(shared_memory, BATCH_SIZE)
                
                for i in range(NUM_AGENTS):
                    actor_loss, critic_loss = maddpg_agents[i].replay(minibatch)
                    
                    maddpg_agents[i].decay_epsilon()
                    
                    if actor_loss != 0 or critic_loss != 0:
                        writer.add_scalar(f'Agent_{i}/Actor_Loss', actor_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Critic_Loss', critic_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Step_Reward', rewards[i], episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Epsilon', maddpg_agents[i].epsilon, episode * max_steps + step)

            # Log team rewards to TensorBoard
            writer.add_scalar('Team/Adversary_Reward', rewards[0], episode * max_steps + step)
            writer.add_scalar('Team/Cooperator_Team_Reward', rewards[1] + rewards[2], episode * max_steps + step)
            writer.add_scalar('Statistics/Captures', capture_count, episode * max_steps + step)
            writer.add_scalar('Statistics/Successes', success_count, episode * max_steps + step)
            writer.add_scalar('Training/Shared_Memory_Size', len(shared_memory), episode * max_steps + step)

            # Determine game status for display
            adv_abs = abs(total_rewards[0])
            coop_total = total_rewards[1] + total_rewards[2]

            if coop_total > adv_abs and coop_total > 15:
                game_status = "Cooperators Leading!"
            elif step >= max_steps - 50:
                game_status = "Ending Soon"
            elif capture_occurred:
                game_status = "Adversary Capture!"
            else:
                game_status = f"Training - Episode {episode}"

            # Visualization
            screen.fill(BACKGROUND)
            draw_grid()

            # Draw landmarks
            for i, landmark in enumerate(landmarks):
                is_highlighted = any(agent['target_landmark'] == i for agent in agents if agent['type'] == 'cooperator')
                is_occupied = any(calculate_distance(agent['pos'], landmark['pos']) < TARGET_THRESHOLD
                                  for agent in agents if agent['type'] == 'cooperator')
                draw_landmark(landmark['pos'], i, is_highlighted, is_occupied)

            # Draw danger zones
            for agent in agents[1:]:
                draw_danger_zone(agent['pos'], agents[0]['pos'])

            # Draw agents
            for i, agent in enumerate(agents):
                is_adversary = agent['type'] == 'adversary'

                target_distance = None
                is_success = False
                is_danger = False

                if not is_adversary:
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    target_distance = calculate_distance(agent['pos'], target_pos)
                    is_success = target_distance < TARGET_THRESHOLD

                    dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
                    if dist_to_adv < DANGER_THRESHOLD * 0.8:
                        is_danger = True

                draw_agent(agent['pos'], is_adversary, i, target_distance, is_success, is_danger)

            # Draw MADDPG panel
            draw_maddpg_panel(step + 1, rewards, total_rewards, game_status, maddpg_agents,
                             success_count, danger_count, capture_count, episode, len(shared_memory))

            pygame.display.flip()
            clock.tick(30)

            # Console output every 50 steps
            if (step + 1) % 50 == 0:
                print(f"Episode {episode}, Step {step + 1}:")
                print(f"  Adversary Reward: {rewards[0]:+.2f} (Total: {total_rewards[0]:+.2f})")
                print(f"  Cooperator1 Reward: {rewards[1]:+.2f} (Total: {total_rewards[1]:+.2f})")
                print(f"  Cooperator2 Reward: {rewards[2]:+.2f} (Total: {total_rewards[2]:+.2f})")
                print(f"  Captures: {capture_count}, Successes: {success_count}")
                print(f"  Shared Memory: {len(shared_memory)}/{MEMORY_SIZE}")

        # End of episode
        for i, agent in enumerate(maddpg_agents):
            agent.episode_rewards.append(episode_rewards[i])
            # Calculate average episode rewards
            if len(agent.episode_rewards) > 0:
                window_size = min(10, len(agent.episode_rewards))
                avg_reward = np.mean(agent.episode_rewards[-window_size:])
                agent.average_rewards.append(avg_reward)
            
            # Log episode rewards to TensorBoard
            writer.add_scalar(f'Agent_{i}/Episode_Reward', episode_rewards[i], episode)
            writer.add_scalar(f'Agent_{i}/Average_Reward', agent.average_rewards[-1] if agent.average_rewards else 0, episode)

        print(f"\n🎯 Episode {episode} completed:")
        print(f"   Adversary Total Reward: {episode_rewards[0]:.2f}")
        print(f"   Cooperator1 Total Reward: {episode_rewards[1]:.2f}")
        print(f"   Cooperator2 Total Reward: {episode_rewards[2]:.2f}")
        print(f"   Captures: {capture_count}, Successes: {success_count}")
        print(f"   Shared Memory Size: {len(shared_memory)}")
        print(f"   Avg Epsilon: {np.mean([agent.epsilon for agent in maddpg_agents]):.3f}")
        print("-" * 40)

        check_training_progress(maddpg_agents, episode)
        
        # Plot training progress
        plot_training_progress(maddpg_agents, episode)
        
        episode_duration = time.time() - episode_start_time
        print(f"📈 Episode {episode+1}/{max_episodes} completed in {episode_duration:.2f}s")
        
        episode += 1

    # Save final models - 🚨 修改了文件名
    for i, agent in enumerate(maddpg_agents):
        agent.save_model(f'maddpg_HYPER_ADJUSTED_agent_{i}_final.pth')

    # Final training plot
    plot_training_progress(maddpg_agents, episode)

    # Close TensorBoard writer
    writer.close()

    pygame.quit()
    print("✅ MADDPG training completed! (Adjusted Params)")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
        pygame.quit()
        sys.exit()

# %% [markdown]
# ## Hyperparameter optimization

# %%
import pygame
import numpy as np
import time
import math
import sys
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
import sys

print("=" * 60)
print("Multi-Agent Environment - Pursuit Evasion Game with MADDPG")
print("=" * 60)

# Initialize pygame
pygame.init()

# Set up window
WIDTH, HEIGHT = 1200, 800
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Multi-Agent Environment - Pursuit Evasion Game with MADDPG")

# Color definitions
BACKGROUND = (240, 240, 240)
RED = (255, 80, 80)  # Adversary
BLUE = (80, 80, 255)  # Cooperator
GREEN = (80, 180, 80)  # Landmark
YELLOW = (255, 200, 0)  # Highlight
PURPLE = (180, 80, 200)  # Interaction effect
ORANGE = (255, 150, 50)  # Warning
BLACK = (40, 40, 40)
GRAY = (200, 200, 200)
LIGHT_GRAY = (220, 220, 220)  # For finer grid
WHITE = (255, 255, 255)
DARK_RED = (180, 0, 0)  # Adversary agent highlight

# Fonts
font_large = pygame.font.Font(None, 32)
font_medium = pygame.font.Font(None, 24)
font_small = pygame.font.Font(None, 18)

# Environment parameters
SCALE = 180
CENTER_X = WIDTH // 3
CENTER_Y = HEIGHT // 2

# Size parameters
AGENT_RADIUS = 8
LANDMARK_RADIUS = 6
DANGER_THRESHOLD = 0.4
TARGET_THRESHOLD = 0.08
CAPTURE_THRESHOLD = 0.15

# UI parameters
INFO_PANEL_WIDTH = 400
INFO_PANEL_HEIGHT = 600
INFO_PANEL_MARGIN = 20
MINIMAP_HEIGHT = 150

# Movement speeds
COOPERATOR_SPEED = 0.018
ADVERSARY_SPEED = COOPERATOR_SPEED * 1.8

# MADDPG Parameters 
NUM_AGENTS = 3
STATE_SIZE = 8 
ACTION_SIZE = 2  
BATCH_SIZE = 256  
LEARNING_RATE = 0.0003  
GAMMA = 0.99  
TAU = 0.005  
MEMORY_SIZE = 50000  
TRAIN_EVERY = 4  

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# MADDPG Network Definitions
class Actor(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=128):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)
        self.tanh = nn.Tanh()
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.tanh(self.fc3(x))

class Critic(nn.Module):
    def __init__(self, full_state_size, full_action_size, hidden_size=128):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(full_state_size + full_action_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, 1)
        
    def forward(self, full_state, full_action):
        x = torch.cat([full_state, full_action], dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# Ornstein-Uhlenbeck noise for exploration - 优化参数
class OUNoise:
    def __init__(self, size, mu=0.0, theta=0.1, sigma=0.1):  
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.reset()
        
    def reset(self):
        self.state = np.copy(self.mu)
        
    def sample(self):
        dx = self.theta * (self.mu - self.state) + self.sigma * np.random.randn(len(self.state))
        self.state += dx
        return self.state

# MADDPG Agent class
class MADDPGAgent:
    def __init__(self, state_size, action_size, num_agents, agent_index):
        self.state_size = state_size
        self.action_size = action_size
        self.num_agents = num_agents
        self.agent_index = agent_index
        
        # Actor networks
        self.actor = Actor(state_size, action_size).to(device)
        self.actor_target = Actor(state_size, action_size).to(device)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LEARNING_RATE)
        
        # Critic networks
        full_state_size = state_size * num_agents
        full_action_size = action_size * num_agents
        self.critic = Critic(full_state_size, full_action_size).to(device)
        self.critic_target = Critic(full_state_size, full_action_size).to(device)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LEARNING_RATE)
        
        # Initialize target networks with same weights
        self.soft_update(self.actor, self.actor_target, 1.0)
        self.soft_update(self.critic, self.critic_target, 1.0)
        
        # Training parameters
        self.gamma = GAMMA
        self.tau = TAU
        self.noise = OUNoise(action_size)
        
        # 🚨 探索衰减参数
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.min_epsilon = 0.1
        
        # Training statistics
        self.actor_losses = []
        self.critic_losses = []
        self.episode_rewards = []
        self.average_rewards = []
        self.q_values = []
        self.recent_actions = deque(maxlen=1000)
        self.action_counts = np.zeros(8)
        
    def act(self, state, add_noise=True):
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        action = self.actor(state_tensor).squeeze(0).detach().cpu().numpy()
        
        if add_noise:
            # 🚨 应用衰减的探索噪声
            noise = self.noise.sample() * self.epsilon
            action += noise
            action = np.clip(action, -1, 1)
        
        # 记录动作用于可视化
        self.recent_actions.append(action.copy())
        
        # 将连续动作离散化为方向类别
        dx, dy = action
        angle = math.atan2(dy, dx)
        direction = int((angle + math.pi) / (math.pi / 4)) % 8
        self.action_counts[direction] += 1
        
        return action
    
    def decay_epsilon(self):
        """衰减探索率"""
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
    
    def replay(self, minibatch):
        """从外部传入的batch进行训练"""
        if minibatch is None or len(minibatch) == 0:
            return 0.0, 0.0
            
        batch_size = len(minibatch)
        
        # 数据处理
        states_batch = torch.FloatTensor([experience[0] for experience in minibatch]).to(device)
        actions_batch = torch.FloatTensor([experience[1] for experience in minibatch]).to(device)
        rewards_batch = torch.FloatTensor([experience[2] for experience in minibatch]).to(device)
        next_states_batch = torch.FloatTensor([experience[3] for experience in minibatch]).to(device)
        dones_batch = torch.FloatTensor([experience[4] for experience in minibatch]).to(device)
        
        # 🚨 根据agent_index提取对应的reward和done
        rewards_batch = rewards_batch[:, self.agent_index].unsqueeze(1)
        dones_batch = dones_batch[:, self.agent_index].unsqueeze(1)
        
        # Reshape for multi-agent
        states_batch = states_batch.view(batch_size, -1)
        actions_batch = actions_batch.view(batch_size, -1)
        next_states_batch = next_states_batch.view(batch_size, -1)
        
        # Update critic
        with torch.no_grad():
            next_actions = []
            for i in range(self.num_agents):
                next_agent_state = next_states_batch[:, i*self.state_size:(i+1)*self.state_size]
                next_agent_action = self.actor_target(next_agent_state)
                next_actions.append(next_agent_action)
            next_actions_full = torch.cat(next_actions, dim=1)
            target_q = self.critic_target(next_states_batch, next_actions_full)
            target_q = rewards_batch + self.gamma * target_q * (1 - dones_batch)
        
        current_q = self.critic(states_batch, actions_batch)
        critic_loss = F.mse_loss(current_q, target_q.detach())
        
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.critic_optimizer.step()
        
        # Update actor
        current_actions = []
        for i in range(self.num_agents):
            agent_state = states_batch[:, i*self.state_size:(i+1)*self.state_size]
            if i == self.agent_index:
                agent_action = self.actor(agent_state)
            else:
                agent_action = actions_batch[:, i*self.action_size:(i+1)*self.action_size]
            current_actions.append(agent_action)
        current_actions_full = torch.cat(current_actions, dim=1)
        
        actor_loss = -self.critic(states_batch, current_actions_full).mean()
        
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
        self.actor_optimizer.step()
        
        # 记录Q值
        with torch.no_grad():
            avg_q = current_q.mean().item()
            self.q_values.append(avg_q)
        
        # Soft update target networks
        self.soft_update(self.actor, self.actor_target, self.tau)
        self.soft_update(self.critic, self.critic_target, self.tau)
        
        # Store losses
        self.actor_losses.append(actor_loss.item())
        self.critic_losses.append(critic_loss.item())
        
        return actor_loss.item(), critic_loss.item()
    
    def soft_update(self, local_model, target_model, tau):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

    def save_model(self, filename):
        """Save the model weights"""
        torch.save({
            'actor_state_dict': self.actor.state_dict(),
            'actor_target_state_dict': self.actor_target.state_dict(),
            'critic_state_dict': self.critic.state_dict(),
            'critic_target_state_dict': self.critic_target.state_dict(),
            'actor_optimizer_state_dict': self.actor_optimizer.state_dict(),
            'critic_optimizer_state_dict': self.critic_optimizer.state_dict(),
            'actor_losses': self.actor_losses,
            'critic_losses': self.critic_losses,
            'episode_rewards': self.episode_rewards,
            'average_rewards': self.average_rewards,
            'q_values': self.q_values,
            'action_counts': self.action_counts,
            'epsilon': self.epsilon,  # 保存探索率
        }, filename)

    def load_model(self, filename):
        """Load the model weights"""
        checkpoint = torch.load(filename)
        self.actor.load_state_dict(checkpoint['actor_state_dict'])
        self.actor_target.load_state_dict(checkpoint['actor_target_state_dict'])
        self.critic.load_state_dict(checkpoint['critic_state_dict'])
        self.critic_target.load_state_dict(checkpoint['critic_target_state_dict'])
        self.actor_optimizer.load_state_dict(checkpoint['actor_optimizer_state_dict'])
        self.critic_optimizer.load_state_dict(checkpoint['critic_optimizer_state_dict'])
        self.actor_losses = checkpoint.get('actor_losses', [])
        self.critic_losses = checkpoint.get('critic_losses', [])
        self.episode_rewards = checkpoint.get('episode_rewards', [])
        self.average_rewards = checkpoint.get('average_rewards', [])
        self.q_values = checkpoint.get('q_values', [])
        self.action_counts = checkpoint.get('action_counts', np.zeros(8))
        self.epsilon = checkpoint.get('epsilon', 1.0)  

def create_simulation_data():
    """Create simulation data"""
    agents = [
        {'pos': [-1.0, 0.6], 'type': 'adversary', 'target_landmark': None, 'score': 0},
        {'pos': [0.3, -0.8], 'type': 'cooperator', 'target_landmark': 0, 'score': 0},
        {'pos': [0.8, 0.2], 'type': 'cooperator', 'target_landmark': 1, 'score': 0}
    ]
    landmarks = [
        {'pos': [-1.2, -1.0], 'occupied': False, 'value': 10},
        {'pos': [1.1, 1.0], 'occupied': False, 'value': 10}
    ]
    return agents, landmarks

def get_random_position():
    """Generate random position within world bounds"""
    WORLD_BOUNDS = 1.4
    x = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    y = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    return [x, y]

def get_agent_state(agent, agents, landmarks):
    """Get state for a single agent with boundary awareness"""
    state = []
    WORLD_BOUNDS = 1.4
    
    # Agent's own position
    state.extend(agent['pos'])
    
    # Target position
    if agent['type'] == 'adversary':
        min_dist = float('inf')
        target_pos = [0, 0]
        for other_agent in agents:
            if other_agent['type'] == 'cooperator':
                dist = calculate_distance(agent['pos'], other_agent['pos'])
                if dist < min_dist:
                    min_dist = dist
                    target_pos = other_agent['pos']
        state.extend(target_pos)
    else:
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        state.extend(target_pos)
    
    # Boundary distance information
    state.extend([
        WORLD_BOUNDS - agent['pos'][0],  # Right boundary distance
        agent['pos'][0] + WORLD_BOUNDS,  # Left boundary distance
        WORLD_BOUNDS - agent['pos'][1],  # Upper boundary distance
        agent['pos'][1] + WORLD_BOUNDS   # Lower boundary distance
    ])
    
    return np.array(state, dtype=np.float32)

def get_full_state(agents, landmarks):
    """Get full state for all agents"""
    full_state = []
    for agent in agents:
        agent_state = get_agent_state(agent, agents, landmarks)
        full_state.extend(agent_state)
    return np.array(full_state, dtype=np.float32)

def calculate_distance(pos1, pos2):
    """Calculate distance between two positions"""
    return math.sqrt((pos1[0] - pos2[0]) ** 2 + (pos1[1] - pos2[1]) ** 2)

def world_to_screen(pos):
    """Convert world coordinates to screen coordinates"""
    x = int(pos[0] * SCALE + CENTER_X)
    y = int(pos[1] * SCALE + CENTER_Y)
    return x, y

def draw_grid():
    """Draw grid"""
    grid_right_boundary = WIDTH - INFO_PANEL_WIDTH - 10

    # Draw dense grid lines
    dense_grid_range = 40
    for i in range(-dense_grid_range, dense_grid_range + 1):
        x = CENTER_X + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (x, 50), (x, HEIGHT - 50), 1)
        y = CENTER_Y + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (50, y), (grid_right_boundary, y), 1)

    # Draw main grid lines
    main_grid_range = 4
    for i in range(-main_grid_range, main_grid_range + 1):
        x = CENTER_X + i * SCALE
        pygame.draw.line(screen, GRAY, (x, 50), (x, HEIGHT - 50), 2)
        y = CENTER_Y + i * SCALE
        pygame.draw.line(screen, GRAY, (50, y), (grid_right_boundary, y), 2)

    # Draw axes
    pygame.draw.line(screen, BLACK, (CENTER_X, 50), (CENTER_X, HEIGHT - 50), 3)
    pygame.draw.line(screen, BLACK, (50, CENTER_Y), (grid_right_boundary, CENTER_Y), 3)

    # Draw coordinate labels
    for i in range(-main_grid_range, main_grid_range + 1):
        if i != 0:
            x = CENTER_X + i * SCALE
            label_value = i * 10
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (x - 8, CENTER_Y + 12))

            y = CENTER_Y + i * SCALE
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (CENTER_X + 12, y - 8))

    # Draw origin label
    origin_label = font_small.render("0", True, BLACK)
    screen.blit(origin_label, (CENTER_X + 5, CENTER_Y + 12))

def draw_landmark(pos, index, is_highlighted=False, is_occupied=False):
    """Draw landmark"""
    x, y = world_to_screen(pos)

    if is_occupied:
        color = PURPLE
    elif is_highlighted:
        color = YELLOW
    else:
        color = GREEN

    pygame.draw.circle(screen, color, (x, y), LANDMARK_RADIUS)
    pygame.draw.circle(screen, WHITE, (x, y), LANDMARK_RADIUS // 2)

    text = font_small.render(f"LM{index + 1}", True, BLACK)
    screen.blit(text, (x - 12, y - LANDMARK_RADIUS - 12))

def draw_agent(pos, is_adversary, agent_id, target_distance=None, is_success=False, is_danger=False):
    """Draw agent"""
    x, y = world_to_screen(pos)

    if is_success:
        color = PURPLE
    elif is_danger:
        color = ORANGE
    else:
        color = DARK_RED if is_adversary else BLUE

    radius = AGENT_RADIUS + 2 if is_adversary else AGENT_RADIUS
    pygame.draw.circle(screen, color, (x, y), radius)
    pygame.draw.circle(screen, WHITE, (x, y), radius, 2)

    # Agent label
    agent_type = "Adv" if is_adversary else f"C{agent_id}"
    text = font_small.render(agent_type, True, BLACK)
    screen.blit(text, (x - 8, y - radius - 10))

def draw_danger_zone(agent_pos, adversary_pos):
    """Draw danger zone"""
    if calculate_distance(agent_pos, adversary_pos) < DANGER_THRESHOLD:
        x1, y1 = world_to_screen(agent_pos)
        x2, y2 = world_to_screen(adversary_pos)
        pygame.draw.line(screen, ORANGE, (x1, y1), (x2, y2), 2)

def apply_continuous_action(pos, action, speed, agent_type):
    """Apply continuous action to agent position"""
    dx, dy = action
    move_magnitude = math.sqrt(dx**2 + dy**2)
    
    if move_magnitude > 0:
        # Normalize and scale by speed
        dx = dx / move_magnitude * speed
        dy = dy / move_magnitude * speed
    else:
        dx, dy = 0, 0
    
    new_pos = [pos[0] + dx, pos[1] + dy]
    
    # Ensure new position is within bounds
    WORLD_BOUNDS = 1.4
    new_pos[0] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[0]))
    new_pos[1] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[1]))
    
    return new_pos

def calculate_rewards(agents, landmarks, capture_occurred):
    """🚨 增强的奖励函数，防止卡边界"""
    rewards = [0, 0, 0]
    WORLD_BOUNDS = 1.4
    
    adversary = agents[0]
    for i, coop in enumerate(agents[1:], 1):
        dist = calculate_distance(adversary['pos'], coop['pos'])
        
        if dist < 1.0:
            proximity_reward = (1.0 - dist) * 2.0
            rewards[0] += proximity_reward
        
        if capture_occurred and dist < CAPTURE_THRESHOLD:
            rewards[0] += 15.0
    
    for i, agent in enumerate(agents[1:], 1):
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        target_dist = calculate_distance(agent['pos'], target_pos)
        
        if target_dist < 1.0:
            progress_reward = (1.0 - target_dist) * 3.0
            rewards[i] += progress_reward
        
        if target_dist < TARGET_THRESHOLD:
            rewards[i] += 20.0
        
        dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
        if dist_to_adv < 0.4:
            danger_penalty = (0.4 - dist_to_adv) * 8.0
            rewards[i] -= danger_penalty
        
        pos = agent['pos']
        boundary_penalty = 0
        if abs(pos[0]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[0])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
        if abs(pos[1]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[1])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
            
        rewards[i] -= boundary_penalty
        
        if capture_occurred and dist_to_adv < CAPTURE_THRESHOLD:
            rewards[i] -= 15.0
    
    adv_pos = agents[0]['pos']
    adv_boundary_penalty = 0
    if abs(adv_pos[0]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[0])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    if abs(adv_pos[1]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[1])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    rewards[0] -= adv_boundary_penalty
    
    return rewards

def draw_maddpg_panel(step, rewards, total_rewards, game_status, maddpg_agents,
                     success_count, danger_count, capture_count, episode, shared_memory_size):
    """Draw MADDPG information panel"""
    panel_x = WIDTH - INFO_PANEL_WIDTH - INFO_PANEL_MARGIN
    panel_y = INFO_PANEL_MARGIN

    # Panel background
    pygame.draw.rect(screen, WHITE, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT))
    pygame.draw.rect(screen, BLACK, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT), 2)

    # Title
    title = font_large.render("MADDPG Pursuit Evasion", True, BLACK)
    screen.blit(title, (panel_x + 10, panel_y + 10))

    # Episode and step information
    episode_text = font_medium.render(f"Episode: {episode}", True, BLACK)
    screen.blit(episode_text, (panel_x + 10, panel_y + 50))

    step_text = font_medium.render(f"Step: {step}/1000", True, BLACK)
    screen.blit(step_text, (panel_x + 150, panel_y + 50))

    # Game status
    status_text = font_medium.render(f"Status: {game_status}", True,
                                     (0, 150, 0) if "Leading" in game_status else
                                     ORANGE if "Danger" in game_status or "Captured" in game_status else
                                     (0, 150, 0) if "Success" in game_status else BLACK)
    screen.blit(status_text, (panel_x + 10, panel_y + 80))

    # MADDPG Agent Information
    maddpg_y = panel_y + 110
    maddpg_title = font_medium.render("MADDPG Agents Info:", True, DARK_RED)
    screen.blit(maddpg_title, (panel_x + 10, maddpg_y))

    for i, agent in enumerate(maddpg_agents):
        agent_y = maddpg_y + 25 + i * 60
        agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
        agent_title = font_small.render(f"{agent_type}:", True, DARK_RED if i == 0 else BLUE)
        screen.blit(agent_title, (panel_x + 20, agent_y))
        
        memory_text = font_small.render(f"Shared Memory: {shared_memory_size}", True, BLACK)
        screen.blit(memory_text, (panel_x + 40, agent_y + 15))
        
        if agent.actor_losses:
            avg_actor_loss = np.mean(agent.actor_losses[-50:])
            actor_loss_text = font_small.render(f"Actor Loss: {avg_actor_loss:.4f}", True, BLACK)
            screen.blit(actor_loss_text, (panel_x + 40, agent_y + 30))

    # Statistics
    stats_y = maddpg_y + 200
    stats_title = font_medium.render("Statistics:", True, BLACK)
    screen.blit(stats_title, (panel_x + 10, stats_y))

    success_text = font_small.render(f"Success: {success_count}", True, (0, 150, 0))
    screen.blit(success_text, (panel_x + 20, stats_y + 30))

    danger_count_text = font_small.render(f"Danger: {danger_count}", True, ORANGE)
    screen.blit(danger_count_text, (panel_x + 20, stats_y + 50))

    capture_text = font_small.render(f"Captures: {capture_count}", True, RED)
    screen.blit(capture_text, (panel_x + 20, stats_y + 70))

    # Reward information
    rewards_y = stats_y + 110
    rewards_title = font_medium.render("Rewards:", True, BLACK)
    screen.blit(rewards_title, (panel_x + 10, rewards_y))

    agent_names = ["Adversary (MADDPG)", "Cooperator1 (MADDPG)", "Cooperator2 (MADDPG)"]
    for i, (name, reward, total) in enumerate(zip(agent_names, rewards, total_rewards)):
        color = DARK_RED if i == 0 else BLUE
        text = f"{name}: {reward:+.2f}"
        reward_text = font_small.render(text, True, color)
        screen.blit(reward_text, (panel_x + 20, rewards_y + 30 + i * 20))

        total_text = font_small.render(f"Total: {total:+.2f}", True, color)
        screen.blit(total_text, (panel_x + 180, rewards_y + 30 + i * 20))

    # Victory condition
    victory_y = rewards_y + 110
    adv_abs = abs(total_rewards[0])
    coop_total = total_rewards[1] + total_rewards[2]
    condition_text = font_medium.render("Victory Condition:", True, BLACK)
    screen.blit(condition_text, (panel_x + 10, victory_y))

    condition_details = font_small.render("Coop Total > Adv Abs", True, BLACK)
    screen.blit(condition_details, (panel_x + 20, victory_y + 30))

    condition_math = font_small.render(f"{coop_total:.2f} > {adv_abs:.2f}", True,
                                       (0, 150, 0) if coop_total > adv_abs else RED)
    screen.blit(condition_math, (panel_x + 20, victory_y + 50))

def plot_training_progress(maddpg_agents, episode):
    """Plot training progress with only 4 essential plots"""
    plt.figure(figsize=(16, 12))
    
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1']  # 红，青，蓝
    
    # Plot 1: Losses (Critic)
    plt.subplot(2, 2, 1)
    for i, agent in enumerate(maddpg_agents):
        agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
        
        if agent.critic_losses:
            window_size = max(1, len(agent.critic_losses) // 50)
            if window_size > 0:
                smoothed_losses = []
                for j in range(len(agent.critic_losses)):
                    start_idx = max(0, j - window_size + 1)
                    end_idx = j + 1
                    avg = np.mean(agent.critic_losses[start_idx:end_idx])
                    smoothed_losses.append(avg)
                plt.plot(smoothed_losses, label=f'{agent_type} Critic', color=colors[i], linestyle='-', alpha=0.8)

    plt.title('Critic Losses')
    plt.xlabel('Training Step')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Plot 2: Episode Rewards 
    plt.subplot(2, 2, 2)
    for i, agent in enumerate(maddpg_agents):
        if agent.episode_rewards:
            agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
            
            if len(agent.episode_rewards) > 10:
                window_size = min(10, len(agent.episode_rewards))
                moving_avg = []
                for j in range(len(agent.episode_rewards)):
                    start_idx = max(0, j - window_size + 1)
                    end_idx = j + 1
                    avg = np.mean(agent.episode_rewards[start_idx:end_idx])
                    moving_avg.append(avg)
                
                plt.plot(moving_avg, label=f'{agent_type} (MA)', color=colors[i], linewidth=2)
            else:
                plt.plot(agent.episode_rewards, label=agent_type, color=colors[i], linewidth=2)

    plt.title('Average Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Plot 3: Q Values
    plt.subplot(2, 2, 3)
    for i, agent in enumerate(maddpg_agents):
        if hasattr(agent, 'q_values') and agent.q_values:
            agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
            
            q_values = agent.q_values
            window_size = max(1, len(q_values) // 100)
            if window_size > 0:
                smoothed_q = []
                for j in range(len(q_values)):
                    start_idx = max(0, j - window_size + 1)
                    end_idx = j + 1
                    avg = np.mean(q_values[start_idx:end_idx])
                    smoothed_q.append(avg)
                plt.plot(smoothed_q[-1000:], label=agent_type, color=colors[i], alpha=0.8)
            else:
                plt.plot(q_values[-1000:], label=agent_type, color=colors[i], alpha=0.8)
    
    plt.title('Q Values (Recent 1000 steps)')
    plt.xlabel('Training Step')
    plt.ylabel('Average Q Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Plot 4: Action Distribution
    plt.subplot(2, 2, 4)
    
    directions = ['→', '↗', '↑', '↖', '←', '↙', '↓', '↘']
    
    bar_width = 0.25
    x_pos = np.arange(len(directions))
    
    for i, agent in enumerate(maddpg_agents):
        if hasattr(agent, 'action_counts') and np.sum(agent.action_counts) > 0:
            agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
            total_actions = np.sum(agent.action_counts)
            if total_actions > 0:
                percentages = (agent.action_counts / total_actions) * 100
                plt.bar(x_pos + i * bar_width, percentages, bar_width, 
                       label=agent_type, color=colors[i], alpha=0.8)
    
    plt.title('Action Distribution by Direction')
    plt.xlabel('Movement Direction')
    plt.ylabel('Percentage (%)')
    plt.xticks(x_pos + bar_width, directions)
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'maddpg_training_progress_episode_{episode}.png', dpi=150, bbox_inches='tight')
    plt.close()
    
    print(f"📊 MADDPG training visualization updated - 4 essential plots saved")

def check_training_progress(maddpg_agents, episode):
    """检查训练进度"""
    progress_indicators = []
    
    for i, agent in enumerate(maddpg_agents):
        if len(agent.episode_rewards) > 10:
            recent_rewards = agent.episode_rewards[-10:]
            avg_recent = np.mean(recent_rewards)
            avg_previous = np.mean(agent.episode_rewards[-20:-10]) if len(agent.episode_rewards) > 20 else avg_recent
            
            if avg_recent > avg_previous:
                progress_indicators.append(f"Agent{i}✓")
            else:
                progress_indicators.append(f"Agent{i}↓")
        
        if hasattr(agent, 'q_values') and len(agent.q_values) > 100:
            recent_q = agent.q_values[-100:]
            q_std = np.std(recent_q)
            if q_std < 5.0:  
                progress_indicators.append(f"Agent{i}_Q_stable")
    
    print(f"Episode {episode} Progress: {', '.join(progress_indicators)}")

def main():
    print("✅ Pygame initialized successfully")

    # Create simulation data
    agents, landmarks = create_simulation_data()

    # Initialize MADDPG agents
    maddpg_agents = []
    for i in range(NUM_AGENTS):
        agent = MADDPGAgent(STATE_SIZE, ACTION_SIZE, NUM_AGENTS, i)
        maddpg_agents.append(agent)

    shared_memory = deque(maxlen=MEMORY_SIZE)

    # Initialize TensorBoard
    writer = SummaryWriter('runs/maddpg_pursuit_evasion')
    print("📊 TensorBoard logging enabled")

    print("📦 Environment configured")
    print(f"   Agents: {NUM_AGENTS} (All using MADDPG)")
    print(f"   Landmarks: {len(landmarks)}")
    print(f"   State size: {STATE_SIZE}, Action size: {ACTION_SIZE}")

    print("\n🤖 MADDPG Configuration:")
    print(f"   Learning Rate: {LEARNING_RATE}")
    print(f"   Discount Factor: {GAMMA}")
    print(f"   Batch Size: {BATCH_SIZE}")
    print(f"   Memory Size: {MEMORY_SIZE}")
    print(f"   Train Every: {TRAIN_EVERY} steps")

    print("\n🎯 Game Rules:")
    print("  🔴 Adversary (MADDPG): Learns optimal chasing strategy")
    print("  🔵 Cooperators (MADDPG): Learn to reach landmarks while avoiding adversary")
    print("  🏆 Victory: Cooperator total > |Adversary total|")
    print("  ⚠️  Press 'S' to save model, 'L' to load model")

    print("\n🎮 Starting MADDPG training...")
    print("💡 Press ESC to exit")
    print("-" * 50)

    running = True
    clock = pygame.time.Clock()

    # Training parameters
    max_episodes = 500
    max_steps = 1000
    episode = 0

    # World boundaries
    WORLD_BOUNDS = 1.4

    while running and episode < max_episodes:
        # Reset environment for new episode
        agents, landmarks = create_simulation_data()
        total_rewards = [0, 0, 0]
        episode_rewards = [0, 0, 0]
        step = 0
        episode_start_time = time.time()
        success_count = 0
        danger_count = 0
        capture_count = 0
        
        last_positions = [agent['pos'].copy() for agent in agents]

        for step in range(max_steps):
            # Process events
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_ESCAPE:
                        running = False
                    elif event.key == pygame.K_s:
                        # Save models
                        for i, agent in enumerate(maddpg_agents):
                            agent.save_model(f'maddpg_agent_{i}_episode_{episode}.pth')
                        print(f"💾 Models saved at episode {episode}")
                    elif event.key == pygame.K_l:
                        # Load models
                        try:
                            for i, agent in enumerate(maddpg_agents):
                                agent.load_model(f'maddpg_agent_{i}.pth')
                            print("📂 Models loaded successfully")
                        except:
                            print("❌ No models found to load")

            if not running:
                break

            # Get current full state
            current_full_state = get_full_state(agents, landmarks)
            
            # Get actions from all agents
            actions = []
            for i, agent in enumerate(agents):
                agent_state = get_agent_state(agent, agents, landmarks)
                action = maddpg_agents[i].act(agent_state, add_noise=True)
                actions.append(action)
            
            # Apply actions
            capture_occurred = False
            for i, agent in enumerate(agents):
                speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                agent['pos'] = apply_continuous_action(agent['pos'], actions[i], speed, agent['type'])
                
                # Check for capture (adversary only)
                if agent['type'] == 'adversary':
                    for j, other_agent in enumerate(agents):
                        if other_agent['type'] == 'cooperator':
                            dist = calculate_distance(agent['pos'], other_agent['pos'])
                            if dist < CAPTURE_THRESHOLD:
                                capture_occurred = True
                                capture_count += 1
                                other_agent['pos'] = get_random_position()

            # Check for success (cooperators only)
            for agent in agents:
                if agent['type'] == 'cooperator':
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    if calculate_distance(agent['pos'], target_pos) < TARGET_THRESHOLD:
                        success_count += 1
                        agent['pos'] = get_random_position()

            if step % 100 == 0 and step > 200:  
                for i, agent in enumerate(agents):
                    if random.random() < 0.2:  # 
                        random_action = np.random.uniform(-1, 1, 2)
                        speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                        agent['pos'] = apply_continuous_action(agent['pos'], random_action, speed, agent['type'])
                        print(f"🔄 Step {step}: Forced exploration for agent {i}")

            if step > 100 and step % 50 == 0:
                current_positions = [agent['pos'].copy() for agent in agents]
                position_changes = [calculate_distance(current_pos, last_pos) 
                                  for current_pos, last_pos in zip(current_positions, last_positions)]
                
                max_change = max(position_changes)
                all_near_boundary = all(
                    abs(pos[0]) > WORLD_BOUNDS * 0.8 or abs(pos[1]) > WORLD_BOUNDS * 0.8 
                    for pos in current_positions
                )
                
                if max_change < 0.02 and all_near_boundary:
                    print(f"🚨 Step {step}: Detected stuck agents, performing reset...")
                    for i in range(NUM_AGENTS):
                        agents[i]['pos'] = get_random_position()
                
                last_positions = current_positions

            # Calculate rewards
            rewards = calculate_rewards(agents, landmarks, capture_occurred)
            
            # Accumulate rewards
            for i in range(len(rewards)):
                total_rewards[i] += rewards[i]
                episode_rewards[i] += rewards[i]
                agents[i]['score'] += rewards[i]

            # Get next state
            next_full_state = get_full_state(agents, landmarks)
            
            # Check if episode should end
            done = (step == max_steps - 1)
            
            shared_memory.append((
                current_full_state.copy(), 
                np.array(actions, dtype=np.float32), 
                np.array(rewards, dtype=np.float32), 
                next_full_state.copy(), 
                np.array([done] * NUM_AGENTS, dtype=np.float32)
            ))

            if step % TRAIN_EVERY == 0 and len(shared_memory) > BATCH_SIZE:
                minibatch = random.sample(shared_memory, BATCH_SIZE)
                
                for i in range(NUM_AGENTS):
                    actor_loss, critic_loss = maddpg_agents[i].replay(minibatch)
                    
                    maddpg_agents[i].decay_epsilon()
                    
                    if actor_loss > 0:  
                        writer.add_scalar(f'Agent_{i}/Actor_Loss', actor_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Critic_Loss', critic_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Step_Reward', rewards[i], episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Epsilon', maddpg_agents[i].epsilon, episode * max_steps + step)

            # Log team rewards to TensorBoard
            writer.add_scalar('Team/Adversary_Reward', rewards[0], episode * max_steps + step)
            writer.add_scalar('Team/Cooperator_Team_Reward', rewards[1] + rewards[2], episode * max_steps + step)
            writer.add_scalar('Statistics/Captures', capture_count, episode * max_steps + step)
            writer.add_scalar('Statistics/Successes', success_count, episode * max_steps + step)
            writer.add_scalar('Training/Shared_Memory_Size', len(shared_memory), episode * max_steps + step)

            # Determine game status for display
            adv_abs = abs(total_rewards[0])
            coop_total = total_rewards[1] + total_rewards[2]

            if coop_total > adv_abs and coop_total > 15:
                game_status = "Cooperators Leading!"
            elif step >= max_steps - 50:
                game_status = "Ending Soon"
            elif capture_occurred:
                game_status = "Adversary Capture!"
            else:
                game_status = f"Training - Episode {episode}"

            # Visualization
            screen.fill(BACKGROUND)
            draw_grid()

            # Draw landmarks
            for i, landmark in enumerate(landmarks):
                is_highlighted = any(agent['target_landmark'] == i for agent in agents if agent['type'] == 'cooperator')
                is_occupied = any(calculate_distance(agent['pos'], landmark['pos']) < TARGET_THRESHOLD
                                  for agent in agents if agent['type'] == 'cooperator')
                draw_landmark(landmark['pos'], i, is_highlighted, is_occupied)

            # Draw danger zones
            for agent in agents[1:]:
                draw_danger_zone(agent['pos'], agents[0]['pos'])

            # Draw agents
            for i, agent in enumerate(agents):
                is_adversary = agent['type'] == 'adversary'

                target_distance = None
                is_success = False
                is_danger = False

                if not is_adversary:
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    target_distance = calculate_distance(agent['pos'], target_pos)
                    is_success = target_distance < TARGET_THRESHOLD

                    dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
                    if dist_to_adv < DANGER_THRESHOLD * 0.8:
                        is_danger = True

                draw_agent(agent['pos'], is_adversary, i, target_distance, is_success, is_danger)

            # Draw MADDPG panel
            draw_maddpg_panel(step + 1, rewards, total_rewards, game_status, maddpg_agents,
                             success_count, danger_count, capture_count, episode, len(shared_memory))

            pygame.display.flip()
            clock.tick(30)

            # Console output every 50 steps
            if (step + 1) % 50 == 0:
                print(f"Episode {episode}, Step {step + 1}:")
                print(f"  Adversary Reward: {rewards[0]:+.2f} (Total: {total_rewards[0]:+.2f})")
                print(f"  Cooperator1 Reward: {rewards[1]:+.2f} (Total: {total_rewards[1]:+.2f})")
                print(f"  Cooperator2 Reward: {rewards[2]:+.2f} (Total: {total_rewards[2]:+.2f})")
                print(f"  Captures: {capture_count}, Successes: {success_count}")
                print(f"  Shared Memory: {len(shared_memory)}/{MEMORY_SIZE}")

        # End of episode
        for i, agent in enumerate(maddpg_agents):
            agent.episode_rewards.append(episode_rewards[i])
            # Calculate average episode rewards
            if len(agent.episode_rewards) > 0:
                window_size = min(10, len(agent.episode_rewards))
                avg_reward = np.mean(agent.episode_rewards[-window_size:])
                agent.average_rewards.append(avg_reward)
            
            # Log episode rewards to TensorBoard
            writer.add_scalar(f'Agent_{i}/Episode_Reward', episode_rewards[i], episode)
            writer.add_scalar(f'Agent_{i}/Average_Reward', agent.average_rewards[-1] if agent.average_rewards else 0, episode)

        print(f"\n🎯 Episode {episode} completed:")
        print(f"   Adversary Total Reward: {episode_rewards[0]:.2f}")
        print(f"   Cooperator1 Total Reward: {episode_rewards[1]:.2f}")
        print(f"   Cooperator2 Total Reward: {episode_rewards[2]:.2f}")
        print(f"   Captures: {capture_count}, Successes: {success_count}")
        print(f"   Shared Memory Size: {len(shared_memory)}")
        print(f"   Avg Epsilon: {np.mean([agent.epsilon for agent in maddpg_agents]):.3f}")
        print("-" * 40)

        check_training_progress(maddpg_agents, episode)
        
        # Plot training progress
        # plot_training_progress(maddpg_agents, episode)
        
        episode_duration = time.time() - episode_start_time
        print(f"📈 Episode {episode+1}/{max_episodes} completed in {episode_duration:.2f}s")
        
        episode += 1

    # Save final models
    for i, agent in enumerate(maddpg_agents):
        agent.save_model(f'maddpg_agent_{i}_final.pth')

    # Final training plot
    plot_training_progress(maddpg_agents, episode)

    # Close TensorBoard writer
    writer.close()

    pygame.quit()
    print("✅ MADDPG training completed!")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
        pygame.quit()
        sys.exit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ============================================================
# Multi-Agent Environment - Pursuit Evasion Game with MADDPG
# ============================================================
# 2025-11-08 21:32:51.088 Python[34606:11059186] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# 🔧 Using configuration mode: --f=/users/zhengguangyuan/library/jupyter/runtime/kernel-v35e719eb73623f2ef583cddcd48ac15229b4db472.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 92
#      89     TRAIN_EVERY = 2
#      91 else:
# ---> 92     raise ValueError(f"❌ Unknown mode '{MODE}'. Use 'original' or 'optimized'.")
#      94 # Device configuration
#      95 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# ValueError: ❌ Unknown mode '--f=/users/zhengguangyuan/library/jupyter/runtime/kernel-v35e719eb73623f2ef583cddcd48ac15229b4db472.json'. Use 'original' or 'optimized'.

# %%
import pygame
import numpy as np
import time
import math
import sys
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
import os


import matplotlib
matplotlib.use('Agg')

print("=" * 60)
print("Multi-Agent Environment - Pursuit Evasion Game with MADDPG")
print("===== HYPERPARAMETER ADJUSTED VERSION ====")
print("=" * 60)

# Initialize pygame
pygame.init()

# Set up window
WIDTH, HEIGHT = 1200, 800
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Multi-Agent Environment - Pursuit Evasion Game with MADDPG [ADJUSTED PARAMS]")

# Color definitions
BACKGROUND = (240, 240, 240)
RED = (255, 80, 80)  # Adversary
BLUE = (80, 80, 255)  # Cooperator
GREEN = (80, 180, 80)  # Landmark
YELLOW = (255, 200, 0)  # Highlight
PURPLE = (180, 80, 200)  # Interaction effect
ORANGE = (255, 150, 50)  # Warning
BLACK = (40, 40, 40)
GRAY = (200, 200, 200)
LIGHT_GRAY = (220, 220, 220)  # For finer grid
WHITE = (255, 255, 255)
DARK_RED = (180, 0, 0)  # Adversary agent highlight

# Fonts
font_large = pygame.font.Font(None, 32)
font_medium = pygame.font.Font(None, 24)
font_small = pygame.font.Font(None, 18)

# Environment parameters
SCALE = 180
CENTER_X = WIDTH // 3
CENTER_Y = HEIGHT // 2

# Size parameters
AGENT_RADIUS = 8
LANDMARK_RADIUS = 6
DANGER_THRESHOLD = 0.4
TARGET_THRESHOLD = 0.08
CAPTURE_THRESHOLD = 0.15

# UI parameters
INFO_PANEL_WIDTH = 400
INFO_PANEL_HEIGHT = 600
INFO_PANEL_MARGIN = 20
MINIMAP_HEIGHT = 150

# Movement speeds
COOPERATOR_SPEED = 0.018
ADVERSARY_SPEED = COOPERATOR_SPEED * 1.8

# MADDPG Parameters - 🚨 
STATE_SIZE = 8 
ACTION_SIZE = 2  
BATCH_SIZE = 64  
LEARNING_RATE = 0.003  
GAMMA = 0.90  
TAU = 0.01  
MEMORY_SIZE = 50000  
TRAIN_EVERY = 4  

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# MADDPG Network Definitions
class Actor(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=128):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)
        self.tanh = nn.Tanh()
        
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.tanh(self.fc3(x))

class Critic(nn.Module):
    def __init__(self, full_state_size, full_action_size, hidden_size=128):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(full_state_size + full_action_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, 1)
        
    def forward(self, full_state, full_action):
        x = torch.cat([full_state, full_action], dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


class OUNoise:
    def __init__(self, size, mu=0.0, theta=0.1, sigma=0.1):  
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.reset()
        
    def reset(self):
        self.state = np.copy(self.mu)
        
    def sample(self):
        dx = self.theta * (self.mu - self.state) + self.sigma * np.random.randn(len(self.state))
        self.state += dx
        return self.state

# MADDPG Agent class
class MADDPGAgent:
    def __init__(self, state_size, action_size, num_agents, agent_index):
        self.state_size = state_size
        self.action_size = action_size
        self.num_agents = num_agents
        self.agent_index = agent_index
        
        # Actor networks
        self.actor = Actor(state_size, action_size).to(device)
        self.actor_target = Actor(state_size, action_size).to(device)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=LEARNING_RATE)
        
        # Critic networks
        full_state_size = state_size * num_agents
        full_action_size = action_size * num_agents
        self.critic = Critic(full_state_size, full_action_size).to(device)
        self.critic_target = Critic(full_state_size, full_action_size).to(device)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=LEARNING_RATE)
        
        # Initialize target networks with same weights
        self.soft_update(self.actor, self.actor_target, 1.0)
        self.soft_update(self.critic, self.critic_target, 1.0)
        
        # Training parameters
        self.gamma = GAMMA
        self.tau = TAU
        self.noise = OUNoise(action_size)

        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.min_epsilon = 0.1
        
        # Training statistics
        self.actor_losses = []
        self.critic_losses = []
        self.episode_rewards = []
        self.average_rewards = []
        self.q_values = []
        self.recent_actions = deque(maxlen=1000)
        self.action_counts = np.zeros(8)
        
    def act(self, state, add_noise=True):
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        action = self.actor(state_tensor).squeeze(0).detach().cpu().numpy()
        
        if add_noise:
            noise = self.noise.sample() * self.epsilon
            action += noise
            action = np.clip(action, -1, 1)
        
        self.recent_actions.append(action.copy())
        
       
        dx, dy = action
        angle = math.atan2(dy, dx)
        direction = int((angle + math.pi) / (math.pi / 4)) % 8
        self.action_counts[direction] += 1
        
        return action
    
    def decay_epsilon(self):
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
    
    def replay(self, minibatch):
        if minibatch is None or len(minibatch) == 0:
            return 0.0, 0.0
            
        batch_size = len(minibatch)
        
        states_batch = torch.FloatTensor([experience[0] for experience in minibatch]).to(device)
        actions_batch = torch.FloatTensor([experience[1] for experience in minibatch]).to(device)
        rewards_batch = torch.FloatTensor([experience[2] for experience in minibatch]).to(device)
        next_states_batch = torch.FloatTensor([experience[3] for experience in minibatch]).to(device)
        dones_batch = torch.FloatTensor([experience[4] for experience in minibatch]).to(device)
        
        rewards_batch = rewards_batch[:, self.agent_index].unsqueeze(1)
        dones_batch = dones_batch[:, self.agent_index].unsqueeze(1)
        
        # Reshape for multi-agent
        states_batch = states_batch.view(batch_size, -1)
        actions_batch = actions_batch.view(batch_size, -1)
        next_states_batch = next_states_batch.view(batch_size, -1)
        
        # Update critic
        with torch.no_grad():
            next_actions = []
            for i in range(self.num_agents):
                next_agent_state = next_states_batch[:, i*self.state_size:(i+1)*self.state_size]
                next_agent_action = self.actor_target(next_agent_state)
                next_actions.append(next_agent_action)
            next_actions_full = torch.cat(next_actions, dim=1)
            target_q = self.critic_target(next_states_batch, next_actions_full)
            target_q = rewards_batch + self.gamma * target_q * (1 - dones_batch)
        
        current_q = self.critic(states_batch, actions_batch)
        critic_loss = F.mse_loss(current_q, target_q.detach())
        
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.critic_optimizer.step()
        
        # Update actor
        current_actions = []
        for i in range(self.num_agents):
            agent_state = states_batch[:, i*self.state_size:(i+1)*self.state_size]
            if i == self.agent_index:
                agent_action = self.actor(agent_state)
            else:
                agent_action = actions_batch[:, i*self.action_size:(i+1)*self.action_size].detach()
            current_actions.append(agent_action)
        current_actions_full = torch.cat(current_actions, dim=1)
        
        actor_loss = -self.critic(states_batch, current_actions_full).mean()
        
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
        self.actor_optimizer.step()

        with torch.no_grad():
            avg_q = current_q.mean().item()
            self.q_values.append(avg_q)
        
        # Soft update target networks
        self.soft_update(self.actor, self.actor_target, self.tau)
        self.soft_update(self.critic, self.critic_target, self.tau)
        
        # Store losses
        self.actor_losses.append(actor_loss.item())
        self.critic_losses.append(critic_loss.item())
        
        return actor_loss.item(), critic_loss.item()
    
    def soft_update(self, local_model, target_model, tau):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

    def save_model(self, filename):
        """Save the model weights"""
        torch.save({
            'actor_state_dict': self.actor.state_dict(),
            'actor_target_state_dict': self.actor_target.state_dict(),
            'critic_state_dict': self.critic.state_dict(),
            'critic_target_state_dict': self.critic_target.state_dict(),
            'actor_optimizer_state_dict': self.actor_optimizer.state_dict(),
            'critic_optimizer_state_dict': self.critic_optimizer.state_dict(),
            'actor_losses': self.actor_losses,
            'critic_losses': self.critic_losses,
            'episode_rewards': self.episode_rewards,
            'average_rewards': self.average_rewards,
            'q_values': self.q_values,
            'action_counts': self.action_counts,
            'epsilon': self.epsilon, 
        }, filename)

    def load_model(self, filename):
        """Load the model weights"""
        if not os.path.exists(filename):
            print(f"❌ Error: Model file not found at {filename}")
            return
            
        try:
            checkpoint = torch.load(filename, map_location=device)
            self.actor.load_state_dict(checkpoint['actor_state_dict'])
            self.actor_target.load_state_dict(checkpoint['actor_target_state_dict'])
            self.critic.load_state_dict(checkpoint['critic_state_dict'])
            self.critic_target.load_state_dict(checkpoint['critic_target_state_dict'])
            self.actor_optimizer.load_state_dict(checkpoint['actor_optimizer_state_dict'])
            self.critic_optimizer.load_state_dict(checkpoint['critic_optimizer_state_dict'])
            self.actor_losses = checkpoint.get('actor_losses', [])
            self.critic_losses = checkpoint.get('critic_losses', [])
            self.episode_rewards = checkpoint.get('episode_rewards', [])
            self.average_rewards = checkpoint.get('average_rewards', [])
            self.q_values = checkpoint.get('q_values', [])
            self.action_counts = checkpoint.get('action_counts', np.zeros(8))
            self.epsilon = checkpoint.get('epsilon', 1.0)
            print(f"📂 Model loaded successfully from {filename}")
        except Exception as e:
            print(f"❌ Error loading model from {filename}: {e}")

def create_simulation_data():
    """Create simulation data"""
    agents = [
        {'pos': [-1.0, 0.6], 'type': 'adversary', 'target_landmark': None, 'score': 0},
        {'pos': [0.3, -0.8], 'type': 'cooperator', 'target_landmark': 0, 'score': 0},
        {'pos': [0.8, 0.2], 'type': 'cooperator', 'target_landmark': 1, 'score': 0}
    ]
    landmarks = [
        {'pos': [-1.2, -1.0], 'occupied': False, 'value': 10},
        {'pos': [1.1, 1.0], 'occupied': False, 'value': 10}
    ]
    return agents, landmarks

def get_random_position():
    """Generate random position within world bounds"""
    WORLD_BOUNDS = 1.4
    x = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    y = np.random.uniform(-WORLD_BOUNDS, WORLD_BOUNDS)
    return [x, y]

def get_agent_state(agent, agents, landmarks):
    """Get state for a single agent with boundary awareness"""
    state = []
    WORLD_BOUNDS = 1.4
    
    # Agent's own position
    state.extend(agent['pos'])
    
    # Target position
    if agent['type'] == 'adversary':
        min_dist = float('inf')
        target_pos = [0, 0]
        for other_agent in agents:
            if other_agent['type'] == 'cooperator':
                dist = calculate_distance(agent['pos'], other_agent['pos'])
                if dist < min_dist:
                    min_dist = dist
                    target_pos = other_agent['pos']
        state.extend(target_pos)
    else:
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        state.extend(target_pos)
    
    # Boundary distance information
    state.extend([
        WORLD_BOUNDS - agent['pos'][0],  # Right boundary distance
        agent['pos'][0] + WORLD_BOUNDS,  # Left boundary distance
        WORLD_BOUNDS - agent['pos'][1],  # Upper boundary distance
        agent['pos'][1] + WORLD_BOUNDS   # Lower boundary distance
    ])
    
    return np.array(state, dtype=np.float32)

def get_full_state(agents, landmarks):
    """Get full state for all agents"""
    full_state = []
    for agent in agents:
        agent_state = get_agent_state(agent, agents, landmarks)
        full_state.extend(agent_state)
    return np.array(full_state, dtype=np.float32)

def calculate_distance(pos1, pos2):
    """Calculate distance between two positions"""
    return math.sqrt((pos1[0] - pos2[0]) ** 2 + (pos1[1] - pos2[1]) ** 2)

def world_to_screen(pos):
    """Convert world coordinates to screen coordinates"""
    x = int(pos[0] * SCALE + CENTER_X)
    y = int(pos[1] * SCALE + CENTER_Y)
    return x, y

def draw_grid():
    """Draw grid"""
    grid_right_boundary = WIDTH - INFO_PANEL_WIDTH - 10

    # Draw dense grid lines
    dense_grid_range = 40
    for i in range(-dense_grid_range, dense_grid_range + 1):
        x = CENTER_X + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (x, 50), (x, HEIGHT - 50), 1)
        y = CENTER_Y + i * (SCALE / 10)
        pygame.draw.line(screen, LIGHT_GRAY, (50, y), (grid_right_boundary, y), 1)

    # Draw main grid lines
    main_grid_range = 4
    for i in range(-main_grid_range, main_grid_range + 1):
        x = CENTER_X + i * SCALE
        pygame.draw.line(screen, GRAY, (x, 50), (x, HEIGHT - 50), 2)
        y = CENTER_Y + i * SCALE
        pygame.draw.line(screen, GRAY, (50, y), (grid_right_boundary, y), 2)

    # Draw axes
    pygame.draw.line(screen, BLACK, (CENTER_X, 50), (CENTER_X, HEIGHT - 50), 3)
    pygame.draw.line(screen, BLACK, (50, CENTER_Y), (grid_right_boundary, CENTER_Y), 3)

    # Draw coordinate labels
    for i in range(-main_grid_range, main_grid_range + 1):
        if i != 0:
            x = CENTER_X + i * SCALE
            label_value = i * 10
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (x - 8, CENTER_Y + 12))

            y = CENTER_Y + i * SCALE
            label = font_small.render(str(label_value), True, BLACK)
            screen.blit(label, (CENTER_X + 12, y - 8))

    # Draw origin label
    origin_label = font_small.render("0", True, BLACK)
    screen.blit(origin_label, (CENTER_X + 5, CENTER_Y + 12))

def draw_landmark(pos, index, is_highlighted=False, is_occupied=False):
    """Draw landmark"""
    x, y = world_to_screen(pos)

    if is_occupied:
        color = PURPLE
    elif is_highlighted:
        color = YELLOW
    else:
        color = GREEN

    pygame.draw.circle(screen, color, (x, y), LANDMARK_RADIUS)
    pygame.draw.circle(screen, WHITE, (x, y), LANDMARK_RADIUS // 2)

    text = font_small.render(f"LM{index + 1}", True, BLACK)
    screen.blit(text, (x - 12, y - LANDMARK_RADIUS - 12))

def draw_agent(pos, is_adversary, agent_id, target_distance=None, is_success=False, is_danger=False):
    """Draw agent"""
    x, y = world_to_screen(pos)

    if is_success:
        color = PURPLE
    elif is_danger:
        color = ORANGE
    else:
        color = DARK_RED if is_adversary else BLUE

    radius = AGENT_RADIUS + 2 if is_adversary else AGENT_RADIUS
    pygame.draw.circle(screen, color, (x, y), radius)
    pygame.draw.circle(screen, WHITE, (x, y), radius, 2)

    # Agent label
    agent_type = "Adv" if is_adversary else f"C{agent_id}"
    text = font_small.render(agent_type, True, BLACK)
    screen.blit(text, (x - 8, y - radius - 10))

def draw_danger_zone(agent_pos, adversary_pos):
    """Draw danger zone"""
    if calculate_distance(agent_pos, adversary_pos) < DANGER_THRESHOLD:
        x1, y1 = world_to_screen(agent_pos)
        x2, y2 = world_to_screen(adversary_pos)
        pygame.draw.line(screen, ORANGE, (x1, y1), (x2, y2), 2)

def apply_continuous_action(pos, action, speed, agent_type):
    """Apply continuous action to agent position"""
    dx, dy = action
    move_magnitude = math.sqrt(dx**2 + dy**2)
    
    if move_magnitude > 0:
        # Normalize and scale by speed
        dx = dx / move_magnitude * speed
        dy = dy / move_magnitude * speed
    else:
        dx, dy = 0, 0
    
    new_pos = [pos[0] + dx, pos[1] + dy]
    
    # Ensure new position is within bounds
    WORLD_BOUNDS = 1.4
    new_pos[0] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[0]))
    new_pos[1] = max(-WORLD_BOUNDS, min(WORLD_BOUNDS, new_pos[1]))
    
    return new_pos

def calculate_rewards(agents, landmarks, capture_occurred):
    """🚨 增强的奖励函数，防止卡边界"""
    rewards = [0, 0, 0]
    WORLD_BOUNDS = 1.4
    
    adversary = agents[0]
    for i, coop in enumerate(agents[1:], 1):
        dist = calculate_distance(adversary['pos'], coop['pos'])
        
        if dist < 1.0:
            proximity_reward = (1.0 - dist) * 2.0
            rewards[0] += proximity_reward
        
        if capture_occurred and dist < CAPTURE_THRESHOLD:
            rewards[0] += 15.0
    
    for i, agent in enumerate(agents[1:], 1):
        target_idx = agent['target_landmark']
        target_pos = landmarks[target_idx]['pos']
        target_dist = calculate_distance(agent['pos'], target_pos)
        
        if target_dist < 1.0:
            progress_reward = (1.0 - target_dist) * 3.0
            rewards[i] += progress_reward
        
        if target_dist < TARGET_THRESHOLD:
            rewards[i] += 20.0
        
        dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
        if dist_to_adv < 0.4:
            danger_penalty = (0.4 - dist_to_adv) * 8.0
            rewards[i] -= danger_penalty
        
        pos = agent['pos']
        boundary_penalty = 0
        if abs(pos[0]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[0])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
        if abs(pos[1]) > WORLD_BOUNDS * 0.7:
            boundary_distance = WORLD_BOUNDS - abs(pos[1])
            boundary_penalty += (0.3 - boundary_distance) * 5.0
            
        rewards[i] -= boundary_penalty
        
        if capture_occurred and dist_to_adv < CAPTURE_THRESHOLD:
            rewards[i] -= 15.0
    
    adv_pos = agents[0]['pos']
    adv_boundary_penalty = 0
    if abs(adv_pos[0]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[0])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    if abs(adv_pos[1]) > WORLD_BOUNDS * 0.7:
        boundary_distance = WORLD_BOUNDS - abs(adv_pos[1])
        adv_boundary_penalty += (0.3 - boundary_distance) * 3.0
    rewards[0] -= adv_boundary_penalty
    
    return rewards

def draw_maddpg_panel(step, rewards, total_rewards, game_status, maddpg_agents,
                     success_count, danger_count, capture_count, episode, shared_memory_size):
    """Draw MADDPG information panel"""
    panel_x = WIDTH - INFO_PANEL_WIDTH - INFO_PANEL_MARGIN
    panel_y = INFO_PANEL_MARGIN

    # Panel background
    pygame.draw.rect(screen, WHITE, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT))
    pygame.draw.rect(screen, BLACK, (panel_x, panel_y, INFO_PANEL_WIDTH, INFO_PANEL_HEIGHT), 2)

    # Title
    title = font_large.render("MADDPG Pursuit Evasion", True, BLACK)
    screen.blit(title, (panel_x + 10, panel_y + 10))

    # Episode and step information
    episode_text = font_medium.render(f"Episode: {episode}", True, BLACK)
    screen.blit(episode_text, (panel_x + 10, panel_y + 50))

    step_text = font_medium.render(f"Step: {step}/1000", True, BLACK)
    screen.blit(step_text, (panel_x + 150, panel_y + 50))

    # Game status
    status_text = font_medium.render(f"Status: {game_status}", True,
                                     (0, 150, 0) if "Leading" in game_status else
                                     ORANGE if "Danger" in game_status or "Captured" in game_status else
                                     (0, 150, 0) if "Success" in game_status else BLACK)
    screen.blit(status_text, (panel_x + 10, panel_y + 80))

    # MADDPG Agent Information
    maddpg_y = panel_y + 110
    maddpg_title = font_medium.render("MADDPG Agents Info:", True, DARK_RED)
    screen.blit(maddpg_title, (panel_x + 10, maddpg_y))

    for i, agent in enumerate(maddpg_agents):
        agent_y = maddpg_y + 25 + i * 60
        agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
        agent_title = font_small.render(f"{agent_type}:", True, DARK_RED if i == 0 else BLUE)
        screen.blit(agent_title, (panel_x + 20, agent_y))
        
        memory_text = font_small.render(f"Shared Memory: {shared_memory_size}", True, BLACK)
        screen.blit(memory_text, (panel_x + 40, agent_y + 15))
        
        if agent.actor_losses:
            avg_actor_loss = np.mean(agent.actor_losses[-50:])
            actor_loss_text = font_small.render(f"Actor Loss: {avg_actor_loss:.4f}", True, BLACK)
            screen.blit(actor_loss_text, (panel_x + 40, agent_y + 30))

    # Statistics
    stats_y = maddpg_y + 200
    stats_title = font_medium.render("Statistics:", True, BLACK)
    screen.blit(stats_title, (panel_x + 10, stats_y))

    success_text = font_small.render(f"Success: {success_count}", True, (0, 150, 0))
    screen.blit(success_text, (panel_x + 20, stats_y + 30))

    danger_count_text = font_small.render(f"Danger: {danger_count}", True, ORANGE)
    screen.blit(danger_count_text, (panel_x + 20, stats_y + 50))

    capture_text = font_small.render(f"Captures: {capture_count}", True, RED)
    screen.blit(capture_text, (panel_x + 20, stats_y + 70))

    # Reward information
    rewards_y = stats_y + 110
    rewards_title = font_medium.render("Rewards:", True, BLACK)
    screen.blit(rewards_title, (panel_x + 10, rewards_y))

    agent_names = ["Adversary (MADDPG)", "Cooperator1 (MADDPG)", "Cooperator2 (MADDPG)"]
    for i, (name, reward, total) in enumerate(zip(agent_names, rewards, total_rewards)):
        color = DARK_RED if i == 0 else BLUE
        text = f"{name}: {reward:+.2f}"
        reward_text = font_small.render(text, True, color)
        screen.blit(reward_text, (panel_x + 20, rewards_y + 30 + i * 20))

        total_text = font_small.render(f"Total: {total:+.2f}", True, color)
        screen.blit(total_text, (panel_x + 180, rewards_y + 30 + i * 20))

    # Victory condition
    victory_y = rewards_y + 110
    adv_abs = abs(total_rewards[0])
    coop_total = total_rewards[1] + total_rewards[2]
    condition_text = font_medium.render("Victory Condition:", True, BLACK)
    screen.blit(condition_text, (panel_x + 10, victory_y))

    condition_details = font_small.render("Coop Total > Adv Abs", True, BLACK)
    screen.blit(condition_details, (panel_x + 20, victory_y + 30))

    condition_math = font_small.render(f"{coop_total:.2f} > {adv_abs:.2f}", True,
                                       (0, 150, 0) if coop_total > adv_abs else RED)
    screen.blit(condition_math, (panel_x + 20, victory_y + 50))

def plot_training_progress(maddpg_agents, episode):
    """Plot training progress with only 4 essential plots"""
    try:
        plt.figure(figsize=(16, 12))
        
        colors = ['#FF6B6B', '#4ECDC4', '#45B7D1']  # 红，青，蓝
        
        # Plot 1: Losses (Critic)
        plt.subplot(2, 2, 1)
        for i, agent in enumerate(maddpg_agents):
            agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
            
            if agent.critic_losses:
                window_size = max(1, len(agent.critic_losses) // 50)
                if window_size > 0:
                    smoothed_losses = []
                    for j in range(len(agent.critic_losses)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(agent.critic_losses[start_idx:end_idx])
                        smoothed_losses.append(avg)
                    plt.plot(smoothed_losses, label=f'{agent_type} Critic', color=colors[i], linestyle='-', alpha=0.8)

        plt.title('Critic Losses')
        plt.xlabel('Training Step')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 2: Episode Rewards 
        plt.subplot(2, 2, 2)
        for i, agent in enumerate(maddpg_agents):
            if agent.episode_rewards:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                
                if len(agent.episode_rewards) > 10:
                    window_size = min(10, len(agent.episode_rewards))
                    moving_avg = []
                    for j in range(len(agent.episode_rewards)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(agent.episode_rewards[start_idx:end_idx])
                        moving_avg.append(avg)
                    
                    plt.plot(moving_avg, label=f'{agent_type} (MA)', color=colors[i], linewidth=2)
                else:
                    plt.plot(agent.episode_rewards, label=agent_type, color=colors[i], linewidth=2)

        plt.title('Average Rewards')
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 3: Q Values
        plt.subplot(2, 2, 3)
        for i, agent in enumerate(maddpg_agents):
            if hasattr(agent, 'q_values') and agent.q_values:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                
                q_values = agent.q_values
                window_size = max(1, len(q_values) // 100)
                if window_size > 0:
                    smoothed_q = []
                    for j in range(len(q_values)):
                        start_idx = max(0, j - window_size + 1)
                        end_idx = j + 1
                        avg = np.mean(q_values[start_idx:end_idx])
                        smoothed_q.append(avg)
                    plt.plot(smoothed_q[-1000:], label=agent_type, color=colors[i], alpha=0.8)
                else:
                    plt.plot(q_values[-1000:], label=agent_type, color=colors[i], alpha=0.8)
        
        plt.title('Q Values (Recent 1000 steps)')
        plt.xlabel('Training Step')
        plt.ylabel('Average Q Value')
        plt.legend()
        plt.grid(True, alpha=0.3)
        
        # Plot 4: Action Distribution
        plt.subplot(2, 2, 4)
        
        directions = ['→', '↗', '↑', '↖', '←', '↙', '↓', '↘']
        
        bar_width = 0.25
        x_pos = np.arange(len(directions))
        
        for i, agent in enumerate(maddpg_agents):
            if hasattr(agent, 'action_counts') and np.sum(agent.action_counts) > 0:
                agent_type = "Adversary" if i == 0 else f"Cooperator{i}"
                total_actions = np.sum(agent.action_counts)
                if total_actions > 0:
                    percentages = (agent.action_counts / total_actions) * 100
                    plt.bar(x_pos + i * bar_width, percentages, bar_width, 
                           label=agent_type, color=colors[i], alpha=0.8)
        
        plt.title('Action Distribution by Direction')
        plt.xlabel('Movement Direction')
        plt.ylabel('Percentage (%)')
        plt.xticks(x_pos + bar_width, directions)
        plt.legend()
        plt.grid(True, alpha=0.3, axis='y')
        
        plt.tight_layout()
        # 🚨 修改了文件名以进行区分
        plt.savefig(f'maddpg_HYPER_ADJUSTED_episode_{episode}.png', dpi=150, bbox_inches='tight')
        plt.close()
        
        print(f"📊 MADDPG training visualization updated - 4 essential plots saved")
    except Exception as e:
        print(f"❌ Error during plotting: {e}")


def check_training_progress(maddpg_agents, episode):
    """检查训练进度"""
    progress_indicators = []
    
    for i, agent in enumerate(maddpg_agents):
        if len(agent.episode_rewards) > 10:
            recent_rewards = agent.episode_rewards[-10:]
            avg_recent = np.mean(recent_rewards)
            avg_previous = np.mean(agent.episode_rewards[-20:-10]) if len(agent.episode_rewards) > 20 else avg_recent
            
            if avg_recent > avg_previous:
                progress_indicators.append(f"Agent{i}✓")
            else:
                progress_indicators.append(f"Agent{i}↓")
        
        if hasattr(agent, 'q_values') and len(agent.q_values) > 100:
            recent_q = agent.q_values[-100:]
            q_std = np.std(recent_q)
            if q_std < 5.0:  
                progress_indicators.append(f"Agent{i}_Q_stable")
    
    print(f"Episode {episode} Progress: {', '.join(progress_indicators)}")

def main():
    print("✅ Pygame initialized successfully")

    # Create simulation data
    agents, landmarks = create_simulation_data()

    # Initialize MADDPG agents
    maddpg_agents = []
    for i in range(NUM_AGENTS):
        agent = MADDPGAgent(STATE_SIZE, ACTION_SIZE, NUM_AGENTS, i)
        maddpg_agents.append(agent)

    shared_memory = deque(maxlen=MEMORY_SIZE)

    # Initialize TensorBoard - 🚨 修改了日志目录
    writer = SummaryWriter('runs/maddpg_pursuit_evasion_ADJUSTED')
    print("📊 TensorBoard logging enabled (Adjusted Params)")

    print("📦 Environment configured")
    print(f"   Agents: {NUM_AGENTS} (All using MADDPG)")
    print(f"   Landmarks: {len(landmarks)}")
    print(f"   State size: {STATE_SIZE}, Action size: {ACTION_SIZE}")

    print("\n🤖 MADDPG Configuration (ADJUSTED):")
    print(f"   Learning Rate: {LEARNING_RATE} (Original: 0.0003)")
    print(f"   Discount Factor: {GAMMA} (Original: 0.99)")
    print(f"   Batch Size: {BATCH_SIZE} (Original: 256)")
    print(f"   Tau: {TAU} (Original: 0.005)")
    print(f"   Memory Size: {MEMORY_SIZE}")
    print(f"   Train Every: {TRAIN_EVERY} steps")

    print("\n🎯 Game Rules:")
    print("  🔴 Adversary (MADDPG): Learns optimal chasing strategy")
    print("  🔵 Cooperators (MADDPG): Learn to reach landmarks while avoiding adversary")
    print("  🏆 Victory: Cooperator total > |Adversary total|")
    print("  ⚠️  Press 'S' to save model, 'L' to load model")

    print("\n🎮 Starting MADDPG training...")
    print("💡 Press ESC to exit")
    print("-" * 50)

    running = True
    clock = pygame.time.Clock()

    # Training parameters
    max_episodes = 500
    max_steps = 1000
    episode = 0

    # World boundaries
    WORLD_BOUNDS = 1.4

    while running and episode < max_episodes:
        # Reset environment for new episode
        agents, landmarks = create_simulation_data()
        total_rewards = [0, 0, 0]
        episode_rewards = [0, 0, 0]
        step = 0
        episode_start_time = time.time()
        success_count = 0
        danger_count = 0
        capture_count = 0
        
        last_positions = [agent['pos'].copy() for agent in agents]

        for step in range(max_steps):
            # Process events
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False
                elif event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_ESCAPE:
                        running = False
                    elif event.key == pygame.K_s:
                        # Save models - 🚨 修改了文件名
                        for i, agent in enumerate(maddpg_agents):
                            agent.save_model(f'maddpg_HYPER_ADJUSTED_agent_{i}_episode_{episode}.pth')
                        print(f"💾 Models saved at episode {episode} (Adjusted)")
                    elif event.key == pygame.K_l:
                        # Load models
                        for i, agent in enumerate(maddpg_agents):
                            # 尝试加载一个标准名称的模型
                            agent.load_model(f'maddpg_agent_{i}.pth') 

            if not running:
                break

            # Get current full state
            current_full_state = get_full_state(agents, landmarks)
            
            # Get actions from all agents
            actions = []
            for i, agent in enumerate(agents):
                agent_state = get_agent_state(agent, agents, landmarks)
                action = maddpg_agents[i].act(agent_state, add_noise=True)
                actions.append(action)
            
            # Apply actions
            capture_occurred = False
            for i, agent in enumerate(agents):
                speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                agent['pos'] = apply_continuous_action(agent['pos'], actions[i], speed, agent['type'])
                
                # Check for capture (adversary only)
                if agent['type'] == 'adversary':
                    for j, other_agent in enumerate(agents):
                        if other_agent['type'] == 'cooperator':
                            dist = calculate_distance(agent['pos'], other_agent['pos'])
                            if dist < CAPTURE_THRESHOLD:
                                capture_occurred = True
                                capture_count += 1
                                other_agent['pos'] = get_random_position()

            # Check for success (cooperators only)
            for agent in agents:
                if agent['type'] == 'cooperator':
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    if calculate_distance(agent['pos'], target_pos) < TARGET_THRESHOLD:
                        success_count += 1
                        agent['pos'] = get_random_position()

            if step % 100 == 0 and step > 200:  
                for i, agent in enumerate(agents):
                    if random.random() < 0.2:  # 
                        random_action = np.random.uniform(-1, 1, 2)
                        speed = ADVERSARY_SPEED if agent['type'] == 'adversary' else COOPERATOR_SPEED
                        agent['pos'] = apply_continuous_action(agent['pos'], random_action, speed, agent['type'])
                        print(f"🔄 Step {step}: Forced exploration for agent {i}")

            if step > 100 and step % 50 == 0:
                current_positions = [agent['pos'].copy() for agent in agents]
                position_changes = [calculate_distance(current_pos, last_pos) 
                                  for current_pos, last_pos in zip(current_positions, last_positions)]
                
                max_change = max(position_changes)
                all_near_boundary = all(
                    abs(pos[0]) > WORLD_BOUNDS * 0.8 or abs(pos[1]) > WORLD_BOUNDS * 0.8 
                    for pos in current_positions
                )
                
                if max_change < 0.02 and all_near_boundary:
                    print(f"🚨 Step {step}: Detected stuck agents, performing reset...")
                    for i in range(NUM_AGENTS):
                        agents[i]['pos'] = get_random_position()
                
                last_positions = current_positions

            # Calculate rewards
            rewards = calculate_rewards(agents, landmarks, capture_occurred)
            
            # Accumulate rewards
            for i in range(len(rewards)):
                total_rewards[i] += rewards[i]
                episode_rewards[i] += rewards[i]
                agents[i]['score'] += rewards[i]

            # Get next state
            next_full_state = get_full_state(agents, landmarks)
            
            # Check if episode should end
            done = (step == max_steps - 1)
            
            shared_memory.append((
                current_full_state.copy(), 
                np.array(actions, dtype=np.float32), 
                np.array(rewards, dtype=np.float32), 
                next_full_state.copy(), 
                np.array([done] * NUM_AGENTS, dtype=np.float32)
            ))

            if step % TRAIN_EVERY == 0 and len(shared_memory) > BATCH_SIZE:
                minibatch = random.sample(shared_memory, BATCH_SIZE)
                
                for i in range(NUM_AGENTS):
                    actor_loss, critic_loss = maddpg_agents[i].replay(minibatch)
                    
                    maddpg_agents[i].decay_epsilon()
                    
                    if actor_loss != 0 or critic_loss != 0:
                        writer.add_scalar(f'Agent_{i}/Actor_Loss', actor_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Critic_Loss', critic_loss, episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Step_Reward', rewards[i], episode * max_steps + step)
                        writer.add_scalar(f'Agent_{i}/Epsilon', maddpg_agents[i].epsilon, episode * max_steps + step)

            # Log team rewards to TensorBoard
            writer.add_scalar('Team/Adversary_Reward', rewards[0], episode * max_steps + step)
            writer.add_scalar('Team/Cooperator_Team_Reward', rewards[1] + rewards[2], episode * max_steps + step)
            writer.add_scalar('Statistics/Captures', capture_count, episode * max_steps + step)
            writer.add_scalar('Statistics/Successes', success_count, episode * max_steps + step)
            writer.add_scalar('Training/Shared_Memory_Size', len(shared_memory), episode * max_steps + step)

            # Determine game status for display
            adv_abs = abs(total_rewards[0])
            coop_total = total_rewards[1] + total_rewards[2]

            if coop_total > adv_abs and coop_total > 15:
                game_status = "Cooperators Leading!"
            elif step >= max_steps - 50:
                game_status = "Ending Soon"
            elif capture_occurred:
                game_status = "Adversary Capture!"
            else:
                game_status = f"Training - Episode {episode}"

            # Visualization
            screen.fill(BACKGROUND)
            draw_grid()

            # Draw landmarks
            for i, landmark in enumerate(landmarks):
                is_highlighted = any(agent['target_landmark'] == i for agent in agents if agent['type'] == 'cooperator')
                is_occupied = any(calculate_distance(agent['pos'], landmark['pos']) < TARGET_THRESHOLD
                                  for agent in agents if agent['type'] == 'cooperator')
                draw_landmark(landmark['pos'], i, is_highlighted, is_occupied)

            # Draw danger zones
            for agent in agents[1:]:
                draw_danger_zone(agent['pos'], agents[0]['pos'])

            # Draw agents
            for i, agent in enumerate(agents):
                is_adversary = agent['type'] == 'adversary'

                target_distance = None
                is_success = False
                is_danger = False

                if not is_adversary:
                    target_idx = agent['target_landmark']
                    target_pos = landmarks[target_idx]['pos']
                    target_distance = calculate_distance(agent['pos'], target_pos)
                    is_success = target_distance < TARGET_THRESHOLD

                    dist_to_adv = calculate_distance(agent['pos'], agents[0]['pos'])
                    if dist_to_adv < DANGER_THRESHOLD * 0.8:
                        is_danger = True

                draw_agent(agent['pos'], is_adversary, i, target_distance, is_success, is_danger)

            # Draw MADDPG panel
            draw_maddpg_panel(step + 1, rewards, total_rewards, game_status, maddpg_agents,
                             success_count, danger_count, capture_count, episode, len(shared_memory))

            pygame.display.flip()
            clock.tick(30)

            # Console output every 50 steps
            if (step + 1) % 50 == 0:
                print(f"Episode {episode}, Step {step + 1}:")
                print(f"  Adversary Reward: {rewards[0]:+.2f} (Total: {total_rewards[0]:+.2f})")
                print(f"  Cooperator1 Reward: {rewards[1]:+.2f} (Total: {total_rewards[1]:+.2f})")
                print(f"  Cooperator2 Reward: {rewards[2]:+.2f} (Total: {total_rewards[2]:+.2f})")
                print(f"  Captures: {capture_count}, Successes: {success_count}")
                print(f"  Shared Memory: {len(shared_memory)}/{MEMORY_SIZE}")

        # End of episode
        for i, agent in enumerate(maddpg_agents):
            agent.episode_rewards.append(episode_rewards[i])
            # Calculate average episode rewards
            if len(agent.episode_rewards) > 0:
                window_size = min(10, len(agent.episode_rewards))
                avg_reward = np.mean(agent.episode_rewards[-window_size:])
                agent.average_rewards.append(avg_reward)
            
            # Log episode rewards to TensorBoard
            writer.add_scalar(f'Agent_{i}/Episode_Reward', episode_rewards[i], episode)
            writer.add_scalar(f'Agent_{i}/Average_Reward', agent.average_rewards[-1] if agent.average_rewards else 0, episode)

        print(f"\n🎯 Episode {episode} completed:")
        print(f"   Adversary Total Reward: {episode_rewards[0]:.2f}")
        print(f"   Cooperator1 Total Reward: {episode_rewards[1]:.2f}")
        print(f"   Cooperator2 Total Reward: {episode_rewards[2]:.2f}")
        print(f"   Captures: {capture_count}, Successes: {success_count}")
        print(f"   Shared Memory Size: {len(shared_memory)}")
        print(f"   Avg Epsilon: {np.mean([agent.epsilon for agent in maddpg_agents]):.3f}")
        print("-" * 40)

        check_training_progress(maddpg_agents, episode)
        
        # Plot training progress
        plot_training_progress(maddpg_agents, episode)
        
        episode_duration = time.time() - episode_start_time
        print(f"📈 Episode {episode+1}/{max_episodes} completed in {episode_duration:.2f}s")
        
        episode += 1

    # Save final models - 🚨 修改了文件名
    for i, agent in enumerate(maddpg_agents):
        agent.save_model(f'maddpg_HYPER_ADJUSTED_agent_{i}_final.pth')

    # Final training plot
    plot_training_progress(maddpg_agents, episode)

    # Close TensorBoard writer
    writer.close()

    pygame.quit()
    print("✅ MADDPG training completed! (Adjusted Params)")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
        pygame.quit()
        sys.exit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ============================================================
# Multi-Agent Environment - Pursuit Evasion Game with MADDPG
# ===== HYPERPARAMETER ADJUSTED VERSION ====
# ============================================================
# Using device: cpu
# ✅ Pygame initialized successfully
# 📊 TensorBoard logging enabled (Adjusted Params)
# 📦 Environment configured
#    Agents: 3 (All using MADDPG)
#    Landmarks: 2
#    State size: 8, Action size: 2
#
# 🤖 MADDPG Configuration (ADJUSTED):
#    Learning Rate: 0.003 (Original: 0.0003)
#    Discount Factor: 0.9 (Original: 0.99)
#    Batch Size: 64 (Original: 256)
#    Tau: 0.01 (Original: 0.005)
#    Memory Size: 50000
#    Train Every: 4 steps
#
# 🎯 Game Rules:
#   🔴 Adversary (MADDPG): Learns optimal chasing strategy
#   🔵 Cooperators (MADDPG): Learn to reach landmarks while avoiding adversary
#   🏆 Victory: Cooperator total > |Adversary total|
#   ⚠️  Press 'S' to save model, 'L' to load model
#
# 🎮 Starting MADDPG training...
# 💡 Press ESC to exit
# --------------------------------------------------
# 2025-11-08 22:44:42.830 Python[36255:11107662] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Episode 0, Step 50:
#   Adversary Reward: -1.61 (Total: -39.41)
#   Cooperator1 Reward: +0.18 (Total: +0.42)
#   Cooperator2 Reward: -0.54 (Total: +4.17)
#   Captures: 0, Successes: 0
#   Shared Memory: 50/50000
# /var/folders/85/7nsv8rcs6mb_w6f6k4pm15dh0000gn/T/ipykernel_36255/316958281.py:208: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
#   states_batch = torch.FloatTensor([experience[0] for experience in minibatch]).to(device)
# Episode 0, Step 100:
#   Adversary Reward: -0.90 (Total: -83.29)
#   Cooperator1 Reward: -0.63 (Total: +25.30)
#   Cooperator2 Reward: -0.88 (Total: -13.33)
#   Captures: 0, Successes: 0
#   Shared Memory: 100/50000
# Episode 0, Step 150:
#   Adversary Reward: -0.90 (Total: -128.29)
#   Cooperator1 Reward: -1.50 (Total: -45.64)
#   Cooperator2 Reward: -1.50 (Total: -83.66)
#   Captures: 0, Successes: 0
#   Shared Memory: 150/50000
# Episode 0, Step 200:
#   Adversary Reward: -1.80 (Total: -188.91)
#   Cooperator1 Reward: -1.50 (Total: -120.64)
#   Cooperator2 Reward: -1.22 (Total: -156.57)
#   Captures: 0, Successes: 0
#   Shared Memory: 200/50000
# Episode 0, Step 250:
#   Adversary Reward: -0.67 (Total: -268.78)
#   Cooperator1 Reward: -3.00 (Total: -234.42)
#   Cooperator2 Reward: -3.00 (Total: -281.96)
#   Captures: 0, Successes: 0
#   Shared Memory: 250/50000
# Episode 0, Step 300:
#   Adversary Reward: -0.90 (Total: -313.48)
#   Cooperator1 Reward: -3.00 (Total: -384.42)
#   Cooperator2 Reward: -3.00 (Total: -431.96)
#   Captures: 0, Successes: 0
#   Shared Memory: 300/50000
# Episode 0, Step 350:
#   Adversary Reward: +2.04 (Total: -296.69)
#   Cooperator1 Reward: -4.93 (Total: -545.12)
#   Cooperator2 Reward: -4.93 (Total: -592.66)
#   Captures: 0, Successes: 0
#   Shared Memory: 350/50000
# Episode 0, Step 400:
#   Adversary Reward: -0.54 (Total: -368.76)
#   Cooperator1 Reward: -1.50 (Total: -565.26)
#   Cooperator2 Reward: -1.50 (Total: -617.58)
#   Captures: 2, Successes: 0
#   Shared Memory: 400/50000
# 🔄 Step 400: Forced exploration for agent 1
# Episode 0, Step 450:
#   Adversary Reward: -1.80 (Total: -359.07)
#   Cooperator1 Reward: +0.00 (Total: -643.81)
#   Cooperator2 Reward: +0.00 (Total: -714.85)
#   Captures: 4, Successes: 0
#   Shared Memory: 450/50000
# Episode 0, Step 500:
#   Adversary Reward: -1.80 (Total: -449.07)
#   Cooperator1 Reward: +0.00 (Total: -643.81)
#   Cooperator2 Reward: +0.00 (Total: -714.85)
#   Captures: 4, Successes: 0
#   Shared Memory: 500/50000
# 🔄 Step 500: Forced exploration for agent 1
# Episode 0, Step 550:
#   Adversary Reward: -1.11 (Total: -531.01)
#   Cooperator1 Reward: -1.06 (Total: -650.66)
#   Cooperator2 Reward: +2.11 (Total: -671.84)
#   Captures: 4, Successes: 0
#   Shared Memory: 550/50000
# Episode 0, Step 600:
#   Adversary Reward: -1.80 (Total: -599.10)
#   Cooperator1 Reward: -0.40 (Total: -713.68)
#   Cooperator2 Reward: -0.43 (Total: -579.50)
#   Captures: 4, Successes: 0
#   Shared Memory: 600/50000
# Episode 0, Step 650:
#   Adversary Reward: +0.48 (Total: -636.22)
#   Cooperator1 Reward: +0.00 (Total: -711.75)
#   Cooperator2 Reward: -1.50 (Total: -637.17)
#   Captures: 4, Successes: 0
#   Shared Memory: 650/50000
# Episode 0, Step 700:
#   Adversary Reward: +0.66 (Total: -597.36)
#   Cooperator1 Reward: +0.00 (Total: -711.75)
#   Cooperator2 Reward: -1.50 (Total: -712.17)
#   Captures: 4, Successes: 0
#   Shared Memory: 700/50000
# Episode 0, Step 750:
#   Adversary Reward: -0.18 (Total: -578.27)
#   Cooperator1 Reward: +0.86 (Total: -750.55)
#   Cooperator2 Reward: -2.54 (Total: -794.08)
#   Captures: 5, Successes: 0
#   Shared Memory: 750/50000
# Episode 0, Step 800:
#   Adversary Reward: +0.17 (Total: -577.55)
#   Cooperator1 Reward: -1.50 (Total: -751.11)
#   Cooperator2 Reward: +0.00 (Total: -890.83)
#   Captures: 6, Successes: 0
#   Shared Memory: 800/50000
# 🔄 Step 800: Forced exploration for agent 2
# Episode 0, Step 850:
#   Adversary Reward: -0.90 (Total: -615.88)
#   Cooperator1 Reward: -1.50 (Total: -826.11)
#   Cooperator2 Reward: +0.00 (Total: -890.83)
#   Captures: 6, Successes: 0
#   Shared Memory: 850/50000
# Episode 0, Step 900:
#   Adversary Reward: -0.90 (Total: -658.73)
#   Cooperator1 Reward: -3.00 (Total: -927.88)
#   Cooperator2 Reward: +0.00 (Total: -890.83)
#   Captures: 6, Successes: 0
#   Shared Memory: 900/50000
# 🔄 Step 900: Forced exploration for agent 0
# Episode 0, Step 950:
#   Adversary Reward: +0.67 (Total: -679.00)
#   Cooperator1 Reward: -3.00 (Total: -1077.88)
#   Cooperator2 Reward: -2.71 (Total: -923.74)
#   Captures: 6, Successes: 0
#   Shared Memory: 950/50000
# Episode 0, Step 1000:
#   Adversary Reward: -1.17 (Total: -684.92)
#   Cooperator1 Reward: -1.50 (Total: -1196.59)
#   Cooperator2 Reward: +0.91 (Total: -967.51)
#   Captures: 8, Successes: 0
#   Shared Memory: 1000/50000
#
# 🎯 Episode 0 completed:
#    Adversary Total Reward: -684.92
#    Cooperator1 Total Reward: -1196.59
#    Cooperator2 Total Reward: -967.51
#    Captures: 8, Successes: 0
#    Shared Memory Size: 1000
#    Avg Epsilon: 0.309
# ----------------------------------------
# Episode 0 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 1/500 completed in 37.22s
# Episode 1, Step 50:
#   Adversary Reward: +1.70 (Total: +40.63)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.20 (Total: +27.95)
#   Captures: 0, Successes: 0
#   Shared Memory: 1050/50000
# Episode 1, Step 100:
#   Adversary Reward: +0.08 (Total: +90.54)
#   Cooperator1 Reward: +0.56 (Total: +0.56)
#   Cooperator2 Reward: -1.50 (Total: +1.93)
#   Captures: 0, Successes: 0
#   Shared Memory: 1100/50000
# Episode 1, Step 150:
#   Adversary Reward: +0.03 (Total: +120.42)
#   Cooperator1 Reward: -1.43 (Total: -39.99)
#   Cooperator2 Reward: +0.00 (Total: -63.97)
#   Captures: 1, Successes: 0
#   Shared Memory: 1150/50000
# Episode 1, Step 200:
#   Adversary Reward: +0.50 (Total: +143.59)
#   Cooperator1 Reward: -3.84 (Total: -204.64)
#   Cooperator2 Reward: +0.03 (Total: -54.97)
#   Captures: 1, Successes: 0
#   Shared Memory: 1200/50000
# Episode 1, Step 250:
#   Adversary Reward: +1.13 (Total: +170.98)
#   Cooperator1 Reward: -3.00 (Total: -358.28)
#   Cooperator2 Reward: -1.81 (Total: -60.08)
#   Captures: 1, Successes: 0
#   Shared Memory: 1250/50000
# Episode 1, Step 300:
#   Adversary Reward: -0.27 (Total: +192.13)
#   Cooperator1 Reward: -3.00 (Total: -508.28)
#   Cooperator2 Reward: +0.00 (Total: -107.39)
#   Captures: 2, Successes: 0
#   Shared Memory: 1300/50000
# 🔄 Step 300: Forced exploration for agent 0
# 🔄 Step 300: Forced exploration for agent 2
# Episode 1, Step 350:
#   Adversary Reward: -0.53 (Total: +171.64)
#   Cooperator1 Reward: -3.00 (Total: -658.28)
#   Cooperator2 Reward: -0.64 (Total: -108.17)
#   Captures: 2, Successes: 0
#   Shared Memory: 1350/50000
# Episode 1, Step 400:
#   Adversary Reward: -0.90 (Total: +133.30)
#   Cooperator1 Reward: -3.00 (Total: -808.28)
#   Cooperator2 Reward: -1.50 (Total: -177.83)
#   Captures: 2, Successes: 0
#   Shared Memory: 1400/50000
# 🔄 Step 400: Forced exploration for agent 0
# Episode 1, Step 450:
#   Adversary Reward: -0.90 (Total: +88.39)
#   Cooperator1 Reward: -3.00 (Total: -958.28)
#   Cooperator2 Reward: -2.63 (Total: -260.66)
#   Captures: 2, Successes: 0
#   Shared Memory: 1450/50000
# Episode 1, Step 500:
#   Adversary Reward: +1.80 (Total: +116.74)
#   Cooperator1 Reward: -3.00 (Total: -1108.28)
#   Cooperator2 Reward: -3.00 (Total: -409.79)
#   Captures: 2, Successes: 0
#   Shared Memory: 1500/50000
# Episode 1, Step 550:
#   Adversary Reward: +1.20 (Total: +188.56)
#   Cooperator1 Reward: -3.00 (Total: -1258.28)
#   Cooperator2 Reward: -3.00 (Total: -559.79)
#   Captures: 2, Successes: 0
#   Shared Memory: 1550/50000
# Episode 1, Step 600:
#   Adversary Reward: +1.80 (Total: +273.81)
#   Cooperator1 Reward: -3.02 (Total: -1416.24)
#   Cooperator2 Reward: -3.02 (Total: -717.76)
#   Captures: 2, Successes: 0
#   Shared Memory: 1600/50000
# 🔄 Step 600: Forced exploration for agent 1
# Episode 1, Step 650:
#   Adversary Reward: +1.15 (Total: +356.28)
#   Cooperator1 Reward: -3.00 (Total: -1570.58)
#   Cooperator2 Reward: -3.00 (Total: -872.18)
#   Captures: 2, Successes: 0
#   Shared Memory: 1650/50000
# Episode 1, Step 700:
#   Adversary Reward: -0.54 (Total: +375.72)
#   Cooperator1 Reward: -3.00 (Total: -1720.58)
#   Cooperator2 Reward: -3.00 (Total: -1022.18)
#   Captures: 2, Successes: 0
#   Shared Memory: 1700/50000
# Episode 1, Step 750:
#   Adversary Reward: -0.90 (Total: +332.26)
#   Cooperator1 Reward: -3.00 (Total: -1870.58)
#   Cooperator2 Reward: -3.00 (Total: -1172.18)
#   Captures: 2, Successes: 0
#   Shared Memory: 1750/50000
# Episode 1, Step 800:
#   Adversary Reward: -0.90 (Total: +287.26)
#   Cooperator1 Reward: -3.00 (Total: -2020.58)
#   Cooperator2 Reward: -3.00 (Total: -1322.18)
#   Captures: 2, Successes: 0
#   Shared Memory: 1800/50000
# Episode 1, Step 850:
#   Adversary Reward: -0.48 (Total: +243.57)
#   Cooperator1 Reward: -3.00 (Total: -2170.58)
#   Cooperator2 Reward: -3.00 (Total: -1472.18)
#   Captures: 2, Successes: 0
#   Shared Memory: 1850/50000
# Episode 1, Step 900:
#   Adversary Reward: -0.90 (Total: +264.31)
#   Cooperator1 Reward: +0.00 (Total: -2287.14)
#   Cooperator2 Reward: +0.16 (Total: -1586.26)
#   Captures: 4, Successes: 0
#   Shared Memory: 1900/50000
# Episode 1, Step 950:
#   Adversary Reward: +0.42 (Total: +251.16)
#   Cooperator1 Reward: -0.47 (Total: -2285.18)
#   Cooperator2 Reward: -1.50 (Total: -1640.36)
#   Captures: 4, Successes: 0
#   Shared Memory: 1950/50000
# Episode 1, Step 1000:
#   Adversary Reward: -0.50 (Total: +232.00)
#   Cooperator1 Reward: -1.50 (Total: -2364.32)
#   Cooperator2 Reward: -1.50 (Total: -1715.36)
#   Captures: 5, Successes: 0
#   Shared Memory: 2000/50000
#
# 🎯 Episode 1 completed:
#    Adversary Total Reward: 232.00
#    Cooperator1 Total Reward: -2364.32
#    Cooperator2 Total Reward: -1715.36
#    Captures: 5, Successes: 0
#    Shared Memory Size: 2000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 1 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 2/500 completed in 35.31s
# Episode 2, Step 50:
#   Adversary Reward: -0.43 (Total: -14.41)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +25.94)
#   Captures: 0, Successes: 0
#   Shared Memory: 2050/50000
# Episode 2, Step 100:
#   Adversary Reward: +0.40 (Total: -12.79)
#   Cooperator1 Reward: +0.60 (Total: +0.60)
#   Cooperator2 Reward: -1.50 (Total: +2.45)
#   Captures: 0, Successes: 0
#   Shared Memory: 2100/50000
# Episode 2, Step 150:
#   Adversary Reward: +1.66 (Total: +44.37)
#   Cooperator1 Reward: -1.52 (Total: -38.47)
#   Cooperator2 Reward: -3.83 (Total: -143.94)
#   Captures: 1, Successes: 0
#   Shared Memory: 2150/50000
# Episode 2, Step 200:
#   Adversary Reward: +1.92 (Total: +139.53)
#   Cooperator1 Reward: -3.95 (Total: -221.29)
#   Cooperator2 Reward: -3.95 (Total: -351.18)
#   Captures: 1, Successes: 0
#   Shared Memory: 2200/50000
# Episode 2, Step 250:
#   Adversary Reward: +1.94 (Total: +237.06)
#   Cooperator1 Reward: -4.15 (Total: -431.59)
#   Cooperator2 Reward: -4.15 (Total: -561.47)
#   Captures: 1, Successes: 0
#   Shared Memory: 2250/50000
# Episode 2, Step 300:
#   Adversary Reward: +1.88 (Total: +333.88)
#   Cooperator1 Reward: -3.67 (Total: -636.07)
#   Cooperator2 Reward: -3.67 (Total: -765.95)
#   Captures: 1, Successes: 0
#   Shared Memory: 2300/50000
# 🔄 Step 300: Forced exploration for agent 1
# Episode 2, Step 350:
#   Adversary Reward: -0.14 (Total: +369.68)
#   Cooperator1 Reward: +0.44 (Total: -743.75)
#   Cooperator2 Reward: +0.00 (Total: -875.11)
#   Captures: 3, Successes: 0
#   Shared Memory: 2350/50000
# Episode 2, Step 400:
#   Adversary Reward: +0.28 (Total: +414.58)
#   Cooperator1 Reward: +0.00 (Total: -824.91)
#   Cooperator2 Reward: +0.40 (Total: -873.13)
#   Captures: 4, Successes: 0
#   Shared Memory: 2400/50000
# 🔄 Step 400: Forced exploration for agent 2
# Episode 2, Step 450:
#   Adversary Reward: -0.90 (Total: +407.51)
#   Cooperator1 Reward: +0.00 (Total: -824.91)
#   Cooperator2 Reward: +0.00 (Total: -899.38)
#   Captures: 5, Successes: 0
#   Shared Memory: 2450/50000
# Episode 2, Step 500:
#   Adversary Reward: -0.90 (Total: +362.51)
#   Cooperator1 Reward: -1.50 (Total: -840.86)
#   Cooperator2 Reward: +0.00 (Total: -899.38)
#   Captures: 5, Successes: 0
#   Shared Memory: 2500/50000
# Episode 2, Step 550:
#   Adversary Reward: +0.92 (Total: +352.01)
#   Cooperator1 Reward: -2.59 (Total: -923.00)
#   Cooperator2 Reward: -0.79 (Total: -910.54)
#   Captures: 5, Successes: 0
#   Shared Memory: 2550/50000
# Episode 2, Step 600:
#   Adversary Reward: +1.94 (Total: +428.34)
#   Cooperator1 Reward: -4.09 (Total: -1086.12)
#   Cooperator2 Reward: -4.09 (Total: -1042.51)
#   Captures: 5, Successes: 0
#   Shared Memory: 2600/50000
# Episode 2, Step 650:
#   Adversary Reward: +1.85 (Total: +522.39)
#   Cooperator1 Reward: -3.44 (Total: -1268.53)
#   Cooperator2 Reward: -3.44 (Total: -1224.91)
#   Captures: 5, Successes: 0
#   Shared Memory: 2650/50000
# Episode 2, Step 700:
#   Adversary Reward: +1.86 (Total: +616.55)
#   Cooperator1 Reward: -3.51 (Total: -1451.80)
#   Cooperator2 Reward: -3.51 (Total: -1408.19)
#   Captures: 5, Successes: 0
#   Shared Memory: 2700/50000
# 🔄 Step 700: Forced exploration for agent 0
# Episode 2, Step 750:
#   Adversary Reward: -0.48 (Total: +632.64)
#   Cooperator1 Reward: +0.00 (Total: -1541.54)
#   Cooperator2 Reward: -0.96 (Total: -1487.63)
#   Captures: 7, Successes: 0
#   Shared Memory: 2750/50000
# Episode 2, Step 800:
#   Adversary Reward: -0.46 (Total: +612.11)
#   Cooperator1 Reward: -1.50 (Total: -1559.06)
#   Cooperator2 Reward: -1.50 (Total: -1560.64)
#   Captures: 7, Successes: 0
#   Shared Memory: 2800/50000
# Episode 2, Step 850:
#   Adversary Reward: -0.07 (Total: +592.01)
#   Cooperator1 Reward: -1.50 (Total: -1634.06)
#   Cooperator2 Reward: +1.22 (Total: -1612.59)
#   Captures: 8, Successes: 0
#   Shared Memory: 2850/50000
# Episode 2, Step 900:
#   Adversary Reward: +0.64 (Total: +614.79)
#   Cooperator1 Reward: -3.13 (Total: -1748.74)
#   Cooperator2 Reward: -0.02 (Total: -1564.76)
#   Captures: 8, Successes: 0
#   Shared Memory: 2900/50000
# Episode 2, Step 950:
#   Adversary Reward: +0.36 (Total: +614.18)
#   Cooperator1 Reward: -0.21 (Total: -1765.82)
#   Cooperator2 Reward: -1.72 (Total: -1626.95)
#   Captures: 9, Successes: 0
#   Shared Memory: 2950/50000
# Episode 2, Step 1000:
#   Adversary Reward: -0.11 (Total: +640.79)
#   Cooperator1 Reward: -1.22 (Total: -1825.57)
#   Cooperator2 Reward: -0.55 (Total: -1703.57)
#   Captures: 10, Successes: 0
#   Shared Memory: 3000/50000
#
# 🎯 Episode 2 completed:
#    Adversary Total Reward: 640.79
#    Cooperator1 Total Reward: -1825.57
#    Cooperator2 Total Reward: -1703.57
#    Captures: 10, Successes: 0
#    Shared Memory Size: 3000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 2 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 3/500 completed in 35.68s
# Episode 3, Step 50:
#   Adversary Reward: -0.66 (Total: -15.90)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.15 (Total: +26.17)
#   Captures: 0, Successes: 0
#   Shared Memory: 3050/50000
# Episode 3, Step 100:
#   Adversary Reward: +0.25 (Total: -29.78)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.50 (Total: +2.35)
#   Captures: 0, Successes: 0
#   Shared Memory: 3100/50000
# Episode 3, Step 150:
#   Adversary Reward: +0.01 (Total: +22.51)
#   Cooperator1 Reward: -2.11 (Total: -38.99)
#   Cooperator2 Reward: +1.51 (Total: -98.85)
#   Captures: 1, Successes: 0
#   Shared Memory: 3150/50000
# Episode 3, Step 200:
#   Adversary Reward: -0.90 (Total: +4.87)
#   Cooperator1 Reward: +0.43 (Total: -90.98)
#   Cooperator2 Reward: +1.36 (Total: -34.87)
#   Captures: 2, Successes: 0
#   Shared Memory: 3200/50000
# Episode 3, Step 250:
#   Adversary Reward: -0.19 (Total: -29.46)
#   Cooperator1 Reward: -1.50 (Total: -137.42)
#   Cooperator2 Reward: -1.50 (Total: -70.65)
#   Captures: 2, Successes: 0
#   Shared Memory: 3250/50000
# Episode 3, Step 300:
#   Adversary Reward: +0.42 (Total: +4.98)
#   Cooperator1 Reward: -2.00 (Total: -213.97)
#   Cooperator2 Reward: +0.00 (Total: -155.10)
#   Captures: 3, Successes: 0
#   Shared Memory: 3300/50000
# Episode 3, Step 350:
#   Adversary Reward: +0.20 (Total: +25.53)
#   Cooperator1 Reward: +0.57 (Total: -291.11)
#   Cooperator2 Reward: +0.00 (Total: -155.10)
#   Captures: 4, Successes: 0
#   Shared Memory: 3350/50000
# Episode 3, Step 400:
#   Adversary Reward: -0.30 (Total: +37.03)
#   Cooperator1 Reward: +1.94 (Total: -333.07)
#   Cooperator2 Reward: -1.50 (Total: -176.99)
#   Captures: 5, Successes: 0
#   Shared Memory: 3400/50000
# 🔄 Step 400: Forced exploration for agent 0
# Episode 3, Step 450:
#   Adversary Reward: -0.22 (Total: +32.34)
#   Cooperator1 Reward: -0.21 (Total: -254.30)
#   Cooperator2 Reward: -1.50 (Total: -271.82)
#   Captures: 6, Successes: 0
#   Shared Memory: 3450/50000
# Episode 3, Step 500:
#   Adversary Reward: -0.53 (Total: +15.24)
#   Cooperator1 Reward: -1.50 (Total: -307.22)
#   Cooperator2 Reward: +0.16 (Total: -347.25)
#   Captures: 7, Successes: 0
#   Shared Memory: 3500/50000
# 🔄 Step 500: Forced exploration for agent 0
# Episode 3, Step 550:
#   Adversary Reward: +0.90 (Total: -10.45)
#   Cooperator1 Reward: -1.60 (Total: -382.32)
#   Cooperator2 Reward: +0.00 (Total: -344.93)
#   Captures: 7, Successes: 0
#   Shared Memory: 3550/50000
# Episode 3, Step 600:
#   Adversary Reward: +0.15 (Total: +4.28)
#   Cooperator1 Reward: +0.44 (Total: -474.34)
#   Cooperator2 Reward: +0.00 (Total: -344.93)
#   Captures: 8, Successes: 0
#   Shared Memory: 3600/50000
# 🔄 Step 600: Forced exploration for agent 1
# Episode 3, Step 650:
#   Adversary Reward: -0.08 (Total: -11.35)
#   Cooperator1 Reward: -1.50 (Total: -529.90)
#   Cooperator2 Reward: -1.50 (Total: -383.10)
#   Captures: 8, Successes: 0
#   Shared Memory: 3650/50000
# Episode 3, Step 700:
#   Adversary Reward: +1.43 (Total: +21.08)
#   Cooperator1 Reward: -1.50 (Total: -604.90)
#   Cooperator2 Reward: -4.30 (Total: -510.27)
#   Captures: 8, Successes: 0
#   Shared Memory: 3700/50000
# 🔄 Step 700: Forced exploration for agent 0
# Episode 3, Step 750:
#   Adversary Reward: +1.98 (Total: +111.77)
#   Cooperator1 Reward: -4.42 (Total: -754.23)
#   Cooperator2 Reward: -4.42 (Total: -717.99)
#   Captures: 8, Successes: 0
#   Shared Memory: 3750/50000
# Episode 3, Step 800:
#   Adversary Reward: +2.00 (Total: +211.72)
#   Cooperator1 Reward: -4.58 (Total: -983.85)
#   Cooperator2 Reward: -4.58 (Total: -947.61)
#   Captures: 8, Successes: 0
#   Shared Memory: 3800/50000
# 🚨 Step 800: Detected stuck agents, performing reset...
# Episode 3, Step 850:
#   Adversary Reward: +0.15 (Total: +246.03)
#   Cooperator1 Reward: -0.42 (Total: -907.05)
#   Cooperator2 Reward: +0.00 (Total: -951.10)
#   Captures: 8, Successes: 0
#   Shared Memory: 3850/50000
# Episode 3, Step 900:
#   Adversary Reward: -0.55 (Total: +239.88)
#   Cooperator1 Reward: -1.50 (Total: -966.51)
#   Cooperator2 Reward: +1.23 (Total: -945.38)
#   Captures: 9, Successes: 0
#   Shared Memory: 3900/50000
# 🔄 Step 900: Forced exploration for agent 2
# Episode 3, Step 950:
#   Adversary Reward: -0.02 (Total: +216.87)
#   Cooperator1 Reward: -1.50 (Total: -1041.51)
#   Cooperator2 Reward: -1.24 (Total: -930.40)
#   Captures: 9, Successes: 0
#   Shared Memory: 3950/50000
# Episode 3, Step 1000:
#   Adversary Reward: +0.42 (Total: +215.03)
#   Cooperator1 Reward: -0.08 (Total: -1121.33)
#   Cooperator2 Reward: -1.64 (Total: -1005.19)
#   Captures: 10, Successes: 0
#   Shared Memory: 4000/50000
#
# 🎯 Episode 3 completed:
#    Adversary Total Reward: 215.03
#    Cooperator1 Total Reward: -1121.33
#    Cooperator2 Total Reward: -1005.19
#    Captures: 10, Successes: 0
#    Shared Memory Size: 4000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 3 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 4/500 completed in 35.31s
# Episode 4, Step 50:
#   Adversary Reward: -0.80 (Total: -17.28)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +25.91)
#   Captures: 0, Successes: 0
#   Shared Memory: 4050/50000
# Episode 4, Step 100:
#   Adversary Reward: +0.29 (Total: -29.78)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.50 (Total: +2.81)
#   Captures: 0, Successes: 0
#   Shared Memory: 4100/50000
# Episode 4, Step 150:
#   Adversary Reward: +0.30 (Total: +8.33)
#   Cooperator1 Reward: -1.54 (Total: -37.33)
#   Cooperator2 Reward: +0.30 (Total: -77.27)
#   Captures: 1, Successes: 0
#   Shared Memory: 4150/50000
# Episode 4, Step 200:
#   Adversary Reward: -0.58 (Total: +12.30)
#   Cooperator1 Reward: +0.41 (Total: -161.95)
#   Cooperator2 Reward: -1.50 (Total: -127.91)
#   Captures: 2, Successes: 0
#   Shared Memory: 4200/50000
# Episode 4, Step 250:
#   Adversary Reward: -0.18 (Total: -21.60)
#   Cooperator1 Reward: -1.50 (Total: -214.91)
#   Cooperator2 Reward: -1.50 (Total: -202.91)
#   Captures: 2, Successes: 0
#   Shared Memory: 4250/50000
# Episode 4, Step 300:
#   Adversary Reward: +1.29 (Total: -2.98)
#   Cooperator1 Reward: -1.50 (Total: -289.91)
#   Cooperator2 Reward: -0.28 (Total: -271.09)
#   Captures: 3, Successes: 0
#   Shared Memory: 4300/50000
# 🔄 Step 300: Forced exploration for agent 0
# Episode 4, Step 350:
#   Adversary Reward: +0.40 (Total: +35.22)
#   Cooperator1 Reward: -4.60 (Total: -418.65)
#   Cooperator2 Reward: -1.50 (Total: -288.04)
#   Captures: 4, Successes: 0
#   Shared Memory: 4350/50000
# Episode 4, Step 400:
#   Adversary Reward: +1.57 (Total: +71.44)
#   Cooperator1 Reward: -3.00 (Total: -620.22)
#   Cooperator2 Reward: -1.50 (Total: -363.04)
#   Captures: 4, Successes: 0
#   Shared Memory: 4400/50000
# 🔄 Step 400: Forced exploration for agent 0
# 🔄 Step 400: Forced exploration for agent 2
# Episode 4, Step 450:
#   Adversary Reward: +1.82 (Total: +153.09)
#   Cooperator1 Reward: -3.16 (Total: -777.25)
#   Cooperator2 Reward: -3.16 (Total: -489.68)
#   Captures: 5, Successes: 0
#   Shared Memory: 4450/50000
# Episode 4, Step 500:
#   Adversary Reward: +1.80 (Total: +243.81)
#   Cooperator1 Reward: -3.00 (Total: -934.76)
#   Cooperator2 Reward: -3.00 (Total: -647.18)
#   Captures: 5, Successes: 0
#   Shared Memory: 4500/50000
# 🚨 Step 500: Detected stuck agents, performing reset...
# Episode 4, Step 550:
#   Adversary Reward: +1.73 (Total: +271.23)
#   Cooperator1 Reward: -2.16 (Total: -1008.35)
#   Cooperator2 Reward: -2.37 (Total: -676.05)
#   Captures: 5, Successes: 0
#   Shared Memory: 4550/50000
# Episode 4, Step 600:
#   Adversary Reward: -0.28 (Total: +336.77)
#   Cooperator1 Reward: +0.42 (Total: -1156.11)
#   Cooperator2 Reward: +0.00 (Total: -823.77)
#   Captures: 7, Successes: 0
#   Shared Memory: 4600/50000
# 🔄 Step 600: Forced exploration for agent 1
# Episode 4, Step 650:
#   Adversary Reward: -0.36 (Total: +313.21)
#   Cooperator1 Reward: -1.50 (Total: -1205.00)
#   Cooperator2 Reward: +0.31 (Total: -821.60)
#   Captures: 7, Successes: 0
#   Shared Memory: 4650/50000
# Episode 4, Step 700:
#   Adversary Reward: +1.22 (Total: +328.80)
#   Cooperator1 Reward: -1.71 (Total: -1280.36)
#   Cooperator2 Reward: -1.56 (Total: -869.01)
#   Captures: 7, Successes: 0
#   Shared Memory: 4700/50000
# 🔄 Step 700: Forced exploration for agent 2
# Episode 4, Step 750:
#   Adversary Reward: +0.47 (Total: +377.34)
#   Cooperator1 Reward: +0.00 (Total: -1337.03)
#   Cooperator2 Reward: -4.03 (Total: -1012.06)
#   Captures: 8, Successes: 0
#   Shared Memory: 4750/50000
# Episode 4, Step 800:
#   Adversary Reward: -0.48 (Total: +351.80)
#   Cooperator1 Reward: +0.00 (Total: -1337.03)
#   Cooperator2 Reward: -1.50 (Total: -1126.94)
#   Captures: 9, Successes: 0
#   Shared Memory: 4800/50000
# 🔄 Step 800: Forced exploration for agent 2
# Episode 4, Step 850:
#   Adversary Reward: +0.99 (Total: +343.32)
#   Cooperator1 Reward: +0.34 (Total: -1335.68)
#   Cooperator2 Reward: -1.03 (Total: -1200.89)
#   Captures: 9, Successes: 0
#   Shared Memory: 4850/50000
# Episode 4, Step 900:
#   Adversary Reward: +0.91 (Total: +392.80)
#   Cooperator1 Reward: -1.50 (Total: -1386.86)
#   Cooperator2 Reward: -3.33 (Total: -1332.38)
#   Captures: 10, Successes: 0
#   Shared Memory: 4900/50000
# Episode 4, Step 950:
#   Adversary Reward: +0.28 (Total: +464.35)
#   Cooperator1 Reward: -4.19 (Total: -1482.25)
#   Cooperator2 Reward: -0.49 (Total: -1523.38)
#   Captures: 11, Successes: 0
#   Shared Memory: 4950/50000
# Episode 4, Step 1000:
#   Adversary Reward: +0.10 (Total: +458.97)
#   Cooperator1 Reward: +0.00 (Total: -1509.73)
#   Cooperator2 Reward: +0.00 (Total: -1524.57)
#   Captures: 12, Successes: 0
#   Shared Memory: 5000/50000
#
# 🎯 Episode 4 completed:
#    Adversary Total Reward: 458.97
#    Cooperator1 Total Reward: -1509.73
#    Cooperator2 Total Reward: -1524.57
#    Captures: 12, Successes: 0
#    Shared Memory Size: 5000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 4 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 5/500 completed in 35.19s
# Episode 5, Step 50:
#   Adversary Reward: +0.00 (Total: +0.00)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +26.31)
#   Captures: 0, Successes: 0
#   Shared Memory: 5050/50000
# Episode 5, Step 100:
#   Adversary Reward: +0.43 (Total: +16.65)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.50 (Total: +2.74)
#   Captures: 0, Successes: 0
#   Shared Memory: 5100/50000
# Episode 5, Step 150:
#   Adversary Reward: +0.05 (Total: +58.63)
#   Cooperator1 Reward: -1.59 (Total: -36.93)
#   Cooperator2 Reward: +0.00 (Total: -75.10)
#   Captures: 1, Successes: 0
#   Shared Memory: 5150/50000
# Episode 5, Step 200:
#   Adversary Reward: +0.43 (Total: +78.33)
#   Cooperator1 Reward: -4.36 (Total: -195.28)
#   Cooperator2 Reward: +0.00 (Total: -75.10)
#   Captures: 1, Successes: 0
#   Shared Memory: 5200/50000
# Episode 5, Step 250:
#   Adversary Reward: +1.26 (Total: +109.05)
#   Cooperator1 Reward: -3.95 (Total: -408.16)
#   Cooperator2 Reward: +0.00 (Total: -75.10)
#   Captures: 1, Successes: 0
#   Shared Memory: 5250/50000
# Episode 5, Step 300:
#   Adversary Reward: +1.81 (Total: +202.62)
#   Cooperator1 Reward: -3.10 (Total: -594.03)
#   Cooperator2 Reward: -3.10 (Total: -164.67)
#   Captures: 1, Successes: 0
#   Shared Memory: 5300/50000
# Episode 5, Step 350:
#   Adversary Reward: +1.90 (Total: +295.83)
#   Cooperator1 Reward: -3.80 (Total: -769.71)
#   Cooperator2 Reward: -3.80 (Total: -340.35)
#   Captures: 1, Successes: 0
#   Shared Memory: 5350/50000
# Episode 5, Step 400:
#   Adversary Reward: +2.05 (Total: +394.41)
#   Cooperator1 Reward: -4.96 (Total: -988.41)
#   Cooperator2 Reward: -4.96 (Total: -559.05)
#   Captures: 1, Successes: 0
#   Shared Memory: 5400/50000
# Episode 5, Step 450:
#   Adversary Reward: +1.98 (Total: +494.81)
#   Cooperator1 Reward: -4.47 (Total: -1221.59)
#   Cooperator2 Reward: -4.47 (Total: -792.23)
#   Captures: 1, Successes: 0
#   Shared Memory: 5450/50000
# Episode 5, Step 500:
#   Adversary Reward: +1.94 (Total: +589.60)
#   Cooperator1 Reward: -4.11 (Total: -1409.91)
#   Cooperator2 Reward: -4.11 (Total: -980.55)
#   Captures: 1, Successes: 0
#   Shared Memory: 5500/50000
# 🔄 Step 500: Forced exploration for agent 1
# Episode 5, Step 550:
#   Adversary Reward: +1.87 (Total: +686.09)
#   Cooperator1 Reward: -3.55 (Total: -1611.83)
#   Cooperator2 Reward: -3.55 (Total: -1182.47)
#   Captures: 1, Successes: 0
#   Shared Memory: 5550/50000
# Episode 5, Step 600:
#   Adversary Reward: +0.07 (Total: +717.82)
#   Cooperator1 Reward: +0.00 (Total: -1705.38)
#   Cooperator2 Reward: -1.50 (Total: -1318.02)
#   Captures: 3, Successes: 0
#   Shared Memory: 5600/50000
# Episode 5, Step 650:
#   Adversary Reward: +1.22 (Total: +733.15)
#   Cooperator1 Reward: -1.50 (Total: -1745.10)
#   Cooperator2 Reward: -3.10 (Total: -1419.72)
#   Captures: 3, Successes: 0
#   Shared Memory: 5650/50000
# Episode 5, Step 700:
#   Adversary Reward: +1.91 (Total: +803.24)
#   Cooperator1 Reward: -2.77 (Total: -1827.80)
#   Cooperator2 Reward: -4.70 (Total: -1638.22)
#   Captures: 3, Successes: 0
#   Shared Memory: 5700/50000
# 🔄 Step 700: Forced exploration for agent 0
# Episode 5, Step 750:
#   Adversary Reward: +0.48 (Total: +832.68)
#   Cooperator1 Reward: +0.00 (Total: -1836.68)
#   Cooperator2 Reward: -3.97 (Total: -1846.08)
#   Captures: 4, Successes: 0
#   Shared Memory: 5750/50000
# Episode 5, Step 800:
#   Adversary Reward: +0.43 (Total: +855.96)
#   Cooperator1 Reward: +0.00 (Total: -1836.68)
#   Cooperator2 Reward: -4.39 (Total: -2049.86)
#   Captures: 4, Successes: 0
#   Shared Memory: 5800/50000
# 🔄 Step 800: Forced exploration for agent 0
# 🔄 Step 800: Forced exploration for agent 1
# Episode 5, Step 850:
#   Adversary Reward: +1.81 (Total: +900.25)
#   Cooperator1 Reward: -1.13 (Total: -1839.15)
#   Cooperator2 Reward: -3.79 (Total: -2262.50)
#   Captures: 4, Successes: 0
#   Shared Memory: 5850/50000
# Episode 5, Step 900:
#   Adversary Reward: +1.19 (Total: +948.72)
#   Cooperator1 Reward: +0.28 (Total: -1841.03)
#   Cooperator2 Reward: -3.47 (Total: -2437.68)
#   Captures: 5, Successes: 1
#   Shared Memory: 5900/50000
# Episode 5, Step 950:
#   Adversary Reward: +1.35 (Total: +1021.36)
#   Cooperator1 Reward: +0.00 (Total: -1876.01)
#   Cooperator2 Reward: -3.42 (Total: -2602.98)
#   Captures: 6, Successes: 1
#   Shared Memory: 5950/50000
# Episode 5, Step 1000:
#   Adversary Reward: +0.50 (Total: +1078.05)
#   Cooperator1 Reward: +1.89 (Total: -1851.42)
#   Cooperator2 Reward: -3.81 (Total: -2779.20)
#   Captures: 7, Successes: 1
#   Shared Memory: 6000/50000
#
# 🎯 Episode 5 completed:
#    Adversary Total Reward: 1078.05
#    Cooperator1 Total Reward: -1851.42
#    Cooperator2 Total Reward: -2779.20
#    Captures: 7, Successes: 1
#    Shared Memory Size: 6000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 5 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 6/500 completed in 34.96s
# Episode 6, Step 50:
#   Adversary Reward: +0.19 (Total: +0.88)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.15 (Total: +26.19)
#   Captures: 0, Successes: 0
#   Shared Memory: 6050/50000
# Episode 6, Step 100:
#   Adversary Reward: +0.49 (Total: +10.74)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.78 (Total: -0.15)
#   Captures: 0, Successes: 0
#   Shared Memory: 6100/50000
# Episode 6, Step 150:
#   Adversary Reward: +0.39 (Total: +53.89)
#   Cooperator1 Reward: -1.53 (Total: -38.21)
#   Cooperator2 Reward: -1.50 (Total: -102.80)
#   Captures: 1, Successes: 0
#   Shared Memory: 6150/50000
# Episode 6, Step 200:
#   Adversary Reward: +1.54 (Total: +102.10)
#   Cooperator1 Reward: -4.22 (Total: -214.00)
#   Cooperator2 Reward: -1.09 (Total: -175.79)
#   Captures: 1, Successes: 0
#   Shared Memory: 6200/50000
# Episode 6, Step 250:
#   Adversary Reward: +1.95 (Total: +194.95)
#   Cooperator1 Reward: -4.18 (Total: -421.57)
#   Cooperator2 Reward: -4.18 (Total: -339.35)
#   Captures: 1, Successes: 0
#   Shared Memory: 6250/50000
# Episode 6, Step 300:
#   Adversary Reward: +1.79 (Total: +288.06)
#   Cooperator1 Reward: -3.00 (Total: -596.77)
#   Cooperator2 Reward: -3.00 (Total: -514.54)
#   Captures: 1, Successes: 0
#   Shared Memory: 6300/50000
# Episode 6, Step 350:
#   Adversary Reward: +1.80 (Total: +363.95)
#   Cooperator1 Reward: -3.00 (Total: -746.77)
#   Cooperator2 Reward: -3.00 (Total: -664.54)
#   Captures: 1, Successes: 0
#   Shared Memory: 6350/50000
# 🚨 Step 350: Detected stuck agents, performing reset...
# Episode 6, Step 400:
#   Adversary Reward: -0.17 (Total: +364.49)
#   Cooperator1 Reward: +0.34 (Total: -695.46)
#   Cooperator2 Reward: -2.62 (Total: -747.26)
#   Captures: 1, Successes: 0
#   Shared Memory: 6400/50000
# 🔄 Step 400: Forced exploration for agent 1
# 🔄 Step 400: Forced exploration for agent 2
# Episode 6, Step 450:
#   Adversary Reward: +0.55 (Total: +370.18)
#   Cooperator1 Reward: -1.50 (Total: -752.80)
#   Cooperator2 Reward: -3.37 (Total: -905.70)
#   Captures: 1, Successes: 0
#   Shared Memory: 6450/50000
# Episode 6, Step 500:
#   Adversary Reward: +1.64 (Total: +424.63)
#   Cooperator1 Reward: -1.51 (Total: -825.26)
#   Cooperator2 Reward: -4.54 (Total: -1109.73)
#   Captures: 1, Successes: 0
#   Shared Memory: 6500/50000
# 🔄 Step 500: Forced exploration for agent 1
# 🔄 Step 500: Forced exploration for agent 2
# Episode 6, Step 550:
#   Adversary Reward: +1.87 (Total: +519.28)
#   Cooperator1 Reward: -3.54 (Total: -1005.31)
#   Cooperator2 Reward: -3.54 (Total: -1320.90)
#   Captures: 1, Successes: 0
#   Shared Memory: 6550/50000
# Episode 6, Step 600:
#   Adversary Reward: +2.04 (Total: +616.48)
#   Cooperator1 Reward: -4.95 (Total: -1212.88)
#   Cooperator2 Reward: -4.95 (Total: -1528.48)
#   Captures: 1, Successes: 0
#   Shared Memory: 6600/50000
# Episode 6, Step 650:
#   Adversary Reward: +1.81 (Total: +712.92)
#   Cooperator1 Reward: -3.11 (Total: -1414.42)
#   Cooperator2 Reward: -3.11 (Total: -1730.02)
#   Captures: 1, Successes: 0
#   Shared Memory: 6650/50000
# Episode 6, Step 700:
#   Adversary Reward: +2.03 (Total: +806.40)
#   Cooperator1 Reward: -4.84 (Total: -1592.74)
#   Cooperator2 Reward: -4.84 (Total: -1908.33)
#   Captures: 1, Successes: 0
#   Shared Memory: 6700/50000
# Episode 6, Step 750:
#   Adversary Reward: +0.47 (Total: +847.46)
#   Cooperator1 Reward: +0.00 (Total: -1677.94)
#   Cooperator2 Reward: -1.83 (Total: -1987.39)
#   Captures: 4, Successes: 0
#   Shared Memory: 6750/50000
# Episode 6, Step 800:
#   Adversary Reward: +0.78 (Total: +861.78)
#   Cooperator1 Reward: +0.00 (Total: -1677.94)
#   Cooperator2 Reward: -3.06 (Total: -2127.33)
#   Captures: 4, Successes: 0
#   Shared Memory: 6800/50000
# Episode 6, Step 850:
#   Adversary Reward: +1.93 (Total: +932.19)
#   Cooperator1 Reward: -2.65 (Total: -1694.60)
#   Cooperator2 Reward: -4.22 (Total: -2319.76)
#   Captures: 4, Successes: 0
#   Shared Memory: 6850/50000
# Episode 6, Step 900:
#   Adversary Reward: +1.81 (Total: +1027.33)
#   Cooperator1 Reward: -3.09 (Total: -1877.72)
#   Cooperator2 Reward: -3.09 (Total: -2513.36)
#   Captures: 4, Successes: 0
#   Shared Memory: 6900/50000
# Episode 6, Step 950:
#   Adversary Reward: +1.82 (Total: +1104.39)
#   Cooperator1 Reward: -3.13 (Total: -2028.43)
#   Cooperator2 Reward: -3.13 (Total: -2664.06)
#   Captures: 4, Successes: 0
#   Shared Memory: 6950/50000
# 🚨 Step 950: Detected stuck agents, performing reset...
# Episode 6, Step 1000:
#   Adversary Reward: +0.52 (Total: +1140.94)
#   Cooperator1 Reward: -3.61 (Total: -2195.32)
#   Cooperator2 Reward: -0.73 (Total: -2665.95)
#   Captures: 4, Successes: 0
#   Shared Memory: 7000/50000
#
# 🎯 Episode 6 completed:
#    Adversary Total Reward: 1140.94
#    Cooperator1 Total Reward: -2195.32
#    Cooperator2 Total Reward: -2665.95
#    Captures: 4, Successes: 0
#    Shared Memory Size: 7000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 6 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 7/500 completed in 35.06s
# Episode 7, Step 50:
#   Adversary Reward: -0.46 (Total: +1.41)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.15 (Total: +26.18)
#   Captures: 0, Successes: 0
#   Shared Memory: 7050/50000
# Episode 7, Step 100:
#   Adversary Reward: +0.31 (Total: -12.01)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.50 (Total: +1.99)
#   Captures: 0, Successes: 0
#   Shared Memory: 7100/50000
# Episode 7, Step 150:
#   Adversary Reward: +0.87 (Total: +23.88)
#   Cooperator1 Reward: -1.53 (Total: -38.02)
#   Cooperator2 Reward: -1.73 (Total: -77.48)
#   Captures: 1, Successes: 0
#   Shared Memory: 7150/50000
# Episode 7, Step 200:
#   Adversary Reward: +1.88 (Total: +108.81)
#   Cooperator1 Reward: -3.61 (Total: -193.28)
#   Cooperator2 Reward: -3.61 (Total: -237.09)
#   Captures: 1, Successes: 0
#   Shared Memory: 7200/50000
# Episode 7, Step 250:
#   Adversary Reward: +1.90 (Total: +201.83)
#   Cooperator1 Reward: -3.80 (Total: -367.45)
#   Cooperator2 Reward: -3.80 (Total: -411.26)
#   Captures: 1, Successes: 0
#   Shared Memory: 7250/50000
# Episode 7, Step 300:
#   Adversary Reward: +1.92 (Total: +297.28)
#   Cooperator1 Reward: -3.97 (Total: -561.01)
#   Cooperator2 Reward: -3.97 (Total: -604.82)
#   Captures: 1, Successes: 0
#   Shared Memory: 7300/50000
# Episode 7, Step 350:
#   Adversary Reward: +1.80 (Total: +392.07)
#   Cooperator1 Reward: -3.00 (Total: -749.37)
#   Cooperator2 Reward: -3.00 (Total: -793.18)
#   Captures: 1, Successes: 0
#   Shared Memory: 7350/50000
# Episode 7, Step 400:
#   Adversary Reward: +1.93 (Total: +483.35)
#   Cooperator1 Reward: -4.03 (Total: -914.95)
#   Cooperator2 Reward: -4.03 (Total: -958.76)
#   Captures: 1, Successes: 0
#   Shared Memory: 7400/50000
# Episode 7, Step 450:
#   Adversary Reward: +1.81 (Total: +570.16)
#   Cooperator1 Reward: -3.05 (Total: -1083.03)
#   Cooperator2 Reward: -3.05 (Total: -1126.84)
#   Captures: 1, Successes: 0
#   Shared Memory: 7450/50000
# Episode 7, Step 500:
#   Adversary Reward: +2.03 (Total: +668.77)
#   Cooperator1 Reward: -4.84 (Total: -1301.91)
#   Cooperator2 Reward: -4.84 (Total: -1345.72)
#   Captures: 1, Successes: 0
#   Shared Memory: 7500/50000
# Episode 7, Step 550:
#   Adversary Reward: +1.87 (Total: +766.68)
#   Cooperator1 Reward: -3.59 (Total: -1515.18)
#   Cooperator2 Reward: -3.59 (Total: -1558.99)
#   Captures: 1, Successes: 0
#   Shared Memory: 7550/50000
# Episode 7, Step 600:
#   Adversary Reward: +1.86 (Total: +858.39)
#   Cooperator1 Reward: -3.48 (Total: -1678.90)
#   Cooperator2 Reward: -3.48 (Total: -1722.71)
#   Captures: 1, Successes: 0
#   Shared Memory: 7600/50000
# 🚨 Step 600: Detected stuck agents, performing reset...
# Episode 7, Step 650:
#   Adversary Reward: +0.36 (Total: +885.21)
#   Cooperator1 Reward: +0.00 (Total: -1678.90)
#   Cooperator2 Reward: -0.26 (Total: -1720.55)
#   Captures: 1, Successes: 0
#   Shared Memory: 7650/50000
# Episode 7, Step 700:
#   Adversary Reward: +0.16 (Total: +906.80)
#   Cooperator1 Reward: -0.84 (Total: -1682.21)
#   Cooperator2 Reward: -1.50 (Total: -1784.01)
#   Captures: 1, Successes: 0
#   Shared Memory: 7700/50000
# 🔄 Step 700: Forced exploration for agent 0
# 🔄 Step 700: Forced exploration for agent 2
# Episode 7, Step 750:
#   Adversary Reward: +1.96 (Total: +979.44)
#   Cooperator1 Reward: -4.27 (Total: -1799.93)
#   Cooperator2 Reward: -4.27 (Total: -1933.51)
#   Captures: 1, Successes: 0
#   Shared Memory: 7750/50000
# Episode 7, Step 800:
#   Adversary Reward: +1.80 (Total: +1057.37)
#   Cooperator1 Reward: -3.00 (Total: -1960.86)
#   Cooperator2 Reward: -3.00 (Total: -2094.45)
#   Captures: 1, Successes: 0
#   Shared Memory: 7800/50000
# 🔄 Step 800: Forced exploration for agent 0
# Episode 7, Step 850:
#   Adversary Reward: +1.94 (Total: +1156.04)
#   Cooperator1 Reward: -4.09 (Total: -2179.47)
#   Cooperator2 Reward: -4.09 (Total: -2313.06)
#   Captures: 1, Successes: 0
#   Shared Memory: 7850/50000
# Episode 7, Step 900:
#   Adversary Reward: +1.96 (Total: +1254.08)
#   Cooperator1 Reward: -4.32 (Total: -2393.81)
#   Cooperator2 Reward: -4.32 (Total: -2527.39)
#   Captures: 1, Successes: 0
#   Shared Memory: 7900/50000
# Episode 7, Step 950:
#   Adversary Reward: +1.90 (Total: +1350.81)
#   Cooperator1 Reward: -3.84 (Total: -2597.65)
#   Cooperator2 Reward: -3.84 (Total: -2731.24)
#   Captures: 1, Successes: 0
#   Shared Memory: 7950/50000
# Episode 7, Step 1000:
#   Adversary Reward: +1.87 (Total: +1445.50)
#   Cooperator1 Reward: -3.56 (Total: -2785.18)
#   Cooperator2 Reward: -3.56 (Total: -2918.77)
#   Captures: 1, Successes: 0
#   Shared Memory: 8000/50000
#
# 🎯 Episode 7 completed:
#    Adversary Total Reward: 1445.50
#    Cooperator1 Total Reward: -2785.18
#    Cooperator2 Total Reward: -2918.77
#    Captures: 1, Successes: 0
#    Shared Memory Size: 8000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 7 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 8/500 completed in 34.97s
# Episode 8, Step 50:
#   Adversary Reward: -0.79 (Total: +5.63)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +26.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 8050/50000
# Episode 8, Step 100:
#   Adversary Reward: +0.42 (Total: -4.32)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -1.50 (Total: +2.14)
#   Captures: 0, Successes: 0
#   Shared Memory: 8100/50000
# Episode 8, Step 150:
#   Adversary Reward: +0.20 (Total: +37.35)
#   Cooperator1 Reward: -1.66 (Total: -36.81)
#   Cooperator2 Reward: +1.06 (Total: -49.04)
#   Captures: 1, Successes: 0
#   Shared Memory: 8150/50000
# Episode 8, Step 200:
#   Adversary Reward: +0.52 (Total: +61.29)
#   Cooperator1 Reward: -3.60 (Total: -197.23)
#   Cooperator2 Reward: -1.39 (Total: -74.95)
#   Captures: 1, Successes: 0
#   Shared Memory: 8200/50000
# Episode 8, Step 250:
#   Adversary Reward: +1.04 (Total: +94.83)
#   Cooperator1 Reward: -4.02 (Total: -380.78)
#   Cooperator2 Reward: -1.50 (Total: -149.84)
#   Captures: 1, Successes: 0
#   Shared Memory: 8250/50000
# Episode 8, Step 300:
#   Adversary Reward: +0.54 (Total: +163.36)
#   Cooperator1 Reward: -3.47 (Total: -569.96)
#   Cooperator2 Reward: +1.23 (Total: -208.68)
#   Captures: 2, Successes: 0
#   Shared Memory: 8300/50000
# 🔄 Step 300: Forced exploration for agent 0
# 🔄 Step 300: Forced exploration for agent 1
# 🔄 Step 300: Forced exploration for agent 2
# Episode 8, Step 350:
#   Adversary Reward: +0.39 (Total: +188.73)
#   Cooperator1 Reward: -4.66 (Total: -757.24)
#   Cooperator2 Reward: +0.69 (Total: -145.22)
#   Captures: 2, Successes: 0
#   Shared Memory: 8350/50000
# Episode 8, Step 400:
#   Adversary Reward: +0.10 (Total: +173.97)
#   Cooperator1 Reward: +0.00 (Total: -779.73)
#   Cooperator2 Reward: -1.50 (Total: -197.16)
#   Captures: 3, Successes: 0
#   Shared Memory: 8400/50000
# Episode 8, Step 450:
#   Adversary Reward: +0.52 (Total: +184.21)
#   Cooperator1 Reward: +0.00 (Total: -779.73)
#   Cooperator2 Reward: +0.00 (Total: -253.68)
#   Captures: 4, Successes: 0
#   Shared Memory: 8450/50000
# Episode 8, Step 500:
#   Adversary Reward: +0.40 (Total: +183.09)
#   Cooperator1 Reward: -0.81 (Total: -779.16)
#   Cooperator2 Reward: -1.50 (Total: -288.50)
#   Captures: 4, Successes: 0
#   Shared Memory: 8500/50000
# Episode 8, Step 550:
#   Adversary Reward: -0.44 (Total: +167.33)
#   Cooperator1 Reward: -0.35 (Total: -763.66)
#   Cooperator2 Reward: -1.50 (Total: -363.50)
#   Captures: 5, Successes: 0
#   Shared Memory: 8550/50000
# Episode 8, Step 600:
#   Adversary Reward: +0.40 (Total: +165.78)
#   Cooperator1 Reward: -1.50 (Total: -821.29)
#   Cooperator2 Reward: -3.07 (Total: -446.40)
#   Captures: 5, Successes: 0
#   Shared Memory: 8600/50000
# 🔄 Step 600: Forced exploration for agent 0
# Episode 8, Step 650:
#   Adversary Reward: +1.26 (Total: +202.59)
#   Cooperator1 Reward: -1.50 (Total: -896.29)
#   Cooperator2 Reward: -3.93 (Total: -641.21)
#   Captures: 5, Successes: 0
#   Shared Memory: 8650/50000
# Episode 8, Step 700:
#   Adversary Reward: +1.82 (Total: +286.13)
#   Cooperator1 Reward: -3.17 (Total: -1003.90)
#   Cooperator2 Reward: -3.17 (Total: -822.22)
#   Captures: 5, Successes: 0
#   Shared Memory: 8700/50000
# 🔄 Step 700: Forced exploration for agent 1
# Episode 8, Step 750:
#   Adversary Reward: +2.03 (Total: +381.12)
#   Cooperator1 Reward: -4.86 (Total: -1193.79)
#   Cooperator2 Reward: -4.86 (Total: -1012.11)
#   Captures: 5, Successes: 0
#   Shared Memory: 8750/50000
# Episode 8, Step 800:
#   Adversary Reward: -0.20 (Total: +376.84)
#   Cooperator1 Reward: -1.08 (Total: -1225.49)
#   Cooperator2 Reward: +0.00 (Total: -1034.33)
#   Captures: 7, Successes: 0
#   Shared Memory: 8800/50000
# 🔄 Step 800: Forced exploration for agent 0
# Episode 8, Step 850:
#   Adversary Reward: +0.81 (Total: +392.61)
#   Cooperator1 Reward: -3.55 (Total: -1324.22)
#   Cooperator2 Reward: -1.50 (Total: -1057.19)
#   Captures: 7, Successes: 0
#   Shared Memory: 8850/50000
# Episode 8, Step 900:
#   Adversary Reward: -0.13 (Total: +363.41)
#   Cooperator1 Reward: +0.00 (Total: -1333.04)
#   Cooperator2 Reward: -1.50 (Total: -1132.19)
#   Captures: 8, Successes: 0
#   Shared Memory: 8900/50000
# Episode 8, Step 950:
#   Adversary Reward: +0.52 (Total: +374.28)
#   Cooperator1 Reward: +0.00 (Total: -1333.04)
#   Cooperator2 Reward: -3.67 (Total: -1230.38)
#   Captures: 8, Successes: 0
#   Shared Memory: 8950/50000
# Episode 8, Step 1000:
#   Adversary Reward: +0.91 (Total: +401.13)
#   Cooperator1 Reward: +0.00 (Total: -1333.04)
#   Cooperator2 Reward: -4.10 (Total: -1429.93)
#   Captures: 8, Successes: 0
#   Shared Memory: 9000/50000
#
# 🎯 Episode 8 completed:
#    Adversary Total Reward: 401.13
#    Cooperator1 Total Reward: -1333.04
#    Cooperator2 Total Reward: -1429.93
#    Captures: 8, Successes: 0
#    Shared Memory Size: 9000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 8 Progress: Agent0_Q_stable, Agent1_Q_stable, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 9/500 completed in 34.98s
# Episode 9, Step 50:
#   Adversary Reward: +0.26 (Total: +2.39)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +26.10)
#   Captures: 0, Successes: 0
#   Shared Memory: 9050/50000
# Episode 9, Step 100:
#   Adversary Reward: +0.65 (Total: +9.19)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -2.50 (Total: -5.51)
#   Captures: 0, Successes: 0
#   Shared Memory: 9100/50000
# Episode 9, Step 150:
#   Adversary Reward: +0.26 (Total: +53.63)
#   Cooperator1 Reward: -1.58 (Total: -36.54)
#   Cooperator2 Reward: -1.51 (Total: -133.68)
#   Captures: 1, Successes: 0
#   Shared Memory: 9150/50000
# Episode 9, Step 200:
#   Adversary Reward: +0.47 (Total: +75.76)
#   Cooperator1 Reward: -4.03 (Total: -213.17)
#   Cooperator2 Reward: -1.50 (Total: -205.86)
#   Captures: 1, Successes: 0
#   Shared Memory: 9200/50000
# Episode 9, Step 250:
#   Adversary Reward: +0.59 (Total: +102.46)
#   Cooperator1 Reward: -3.09 (Total: -389.62)
#   Cooperator2 Reward: -1.50 (Total: -280.86)
#   Captures: 1, Successes: 0
#   Shared Memory: 9250/50000
# Episode 9, Step 300:
#   Adversary Reward: +1.12 (Total: +137.87)
#   Cooperator1 Reward: -3.86 (Total: -564.42)
#   Cooperator2 Reward: -1.50 (Total: -355.86)
#   Captures: 1, Successes: 0
#   Shared Memory: 9300/50000
# Episode 9, Step 350:
#   Adversary Reward: +1.87 (Total: +217.01)
#   Cooperator1 Reward: -3.55 (Total: -736.05)
#   Cooperator2 Reward: -3.55 (Total: -453.50)
#   Captures: 1, Successes: 0
#   Shared Memory: 9350/50000
# Episode 9, Step 400:
#   Adversary Reward: +1.85 (Total: +310.44)
#   Cooperator1 Reward: -3.40 (Total: -913.51)
#   Cooperator2 Reward: -3.40 (Total: -630.96)
#   Captures: 1, Successes: 0
#   Shared Memory: 9400/50000
# 🔄 Step 400: Forced exploration for agent 2
# 🚨 Step 400: Detected stuck agents, performing reset...
# Episode 9, Step 450:
#   Adversary Reward: -0.18 (Total: +372.51)
#   Cooperator1 Reward: +0.00 (Total: -963.76)
#   Cooperator2 Reward: +0.00 (Total: -630.96)
#   Captures: 3, Successes: 0
#   Shared Memory: 9450/50000
# Episode 9, Step 500:
#   Adversary Reward: +0.00 (Total: +377.64)
#   Cooperator1 Reward: +0.00 (Total: -963.76)
#   Cooperator2 Reward: +0.59 (Total: -641.90)
#   Captures: 4, Successes: 0
#   Shared Memory: 9500/50000
# 🔄 Step 500: Forced exploration for agent 1
# Episode 9, Step 550:
#   Adversary Reward: +0.51 (Total: +409.36)
#   Cooperator1 Reward: +0.00 (Total: -963.76)
#   Cooperator2 Reward: +0.10 (Total: -613.41)
#   Captures: 4, Successes: 0
#   Shared Memory: 9550/50000
# Episode 9, Step 600:
#   Adversary Reward: +1.39 (Total: +442.86)
#   Cooperator1 Reward: -1.77 (Total: -971.86)
#   Cooperator2 Reward: -1.50 (Total: -645.10)
# ...
# 🚨 Step 900: Detected stuck agents, performing reset...
# Episode 496, Step 950:
#   Adversary Reward: +1.61 (Total: +1663.25)
#   Cooperator1 Reward: -1.66 (Total: -1906.84)
#   Cooperator2 Reward: +0.00 (Total: -1634.22)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 496, Step 1000:
#   Adversary Reward: +1.56 (Total: +1740.40)
#   Cooperator1 Reward: -1.29 (Total: -1965.18)
#   Cooperator2 Reward: +0.00 (Total: -1634.22)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
#
# 🎯 Episode 496 completed:
#    Adversary Total Reward: 1740.40
#    Cooperator1 Total Reward: -1965.18
#    Cooperator2 Total Reward: -1634.22
#    Captures: 1, Successes: 0
#    Shared Memory Size: 50000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 496 Progress: Agent0✓, Agent0_Q_stable, Agent1↓, Agent1_Q_stable, Agent2✓, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 497/500 completed in 95.09s
# Episode 497, Step 50:
#   Adversary Reward: +1.72 (Total: +40.71)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.14 (Total: +26.05)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 100:
#   Adversary Reward: +1.89 (Total: +130.92)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: -2.14 (Total: -32.21)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 150:
#   Adversary Reward: +2.82 (Total: +252.17)
#   Cooperator1 Reward: -1.60 (Total: -38.31)
#   Cooperator2 Reward: -2.40 (Total: -142.05)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 200:
#   Adversary Reward: +2.30 (Total: +373.46)
#   Cooperator1 Reward: -3.00 (Total: -174.69)
#   Cooperator2 Reward: -3.00 (Total: -285.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 250:
#   Adversary Reward: +2.29 (Total: +488.11)
#   Cooperator1 Reward: -3.00 (Total: -324.69)
#   Cooperator2 Reward: -3.00 (Total: -435.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 300:
#   Adversary Reward: +2.29 (Total: +602.88)
#   Cooperator1 Reward: -3.00 (Total: -474.69)
#   Cooperator2 Reward: -3.00 (Total: -585.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 350:
#   Adversary Reward: +2.28 (Total: +717.38)
#   Cooperator1 Reward: -3.00 (Total: -624.69)
#   Cooperator2 Reward: -3.00 (Total: -735.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 400:
#   Adversary Reward: +2.30 (Total: +831.90)
#   Cooperator1 Reward: -3.00 (Total: -774.69)
#   Cooperator2 Reward: -3.00 (Total: -885.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 400: Forced exploration for agent 0
# Episode 497, Step 450:
#   Adversary Reward: +2.29 (Total: +946.54)
#   Cooperator1 Reward: -3.00 (Total: -924.69)
#   Cooperator2 Reward: -3.00 (Total: -1035.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 500:
#   Adversary Reward: +2.29 (Total: +1061.38)
#   Cooperator1 Reward: -3.00 (Total: -1074.69)
#   Cooperator2 Reward: -3.00 (Total: -1185.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 500: Forced exploration for agent 0
# Episode 497, Step 550:
#   Adversary Reward: +2.27 (Total: +1175.24)
#   Cooperator1 Reward: -3.00 (Total: -1224.69)
#   Cooperator2 Reward: -3.00 (Total: -1335.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 600:
#   Adversary Reward: +2.23 (Total: +1287.42)
#   Cooperator1 Reward: -3.00 (Total: -1374.69)
#   Cooperator2 Reward: -3.00 (Total: -1485.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 600: Forced exploration for agent 2
# Episode 497, Step 650:
#   Adversary Reward: +2.30 (Total: +1401.20)
#   Cooperator1 Reward: -3.00 (Total: -1524.69)
#   Cooperator2 Reward: -3.00 (Total: -1635.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 700:
#   Adversary Reward: +2.30 (Total: +1516.06)
#   Cooperator1 Reward: -3.00 (Total: -1675.23)
#   Cooperator2 Reward: -3.00 (Total: -1785.58)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 750:
#   Adversary Reward: +2.29 (Total: +1630.93)
#   Cooperator1 Reward: -3.00 (Total: -1825.68)
#   Cooperator2 Reward: -3.00 (Total: -1936.03)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 800:
#   Adversary Reward: +2.30 (Total: +1745.72)
#   Cooperator1 Reward: -3.00 (Total: -1976.64)
#   Cooperator2 Reward: -3.00 (Total: -2086.98)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 800: Forced exploration for agent 1
# 🚨 Step 800: Detected stuck agents, performing reset...
# Episode 497, Step 850:
#   Adversary Reward: +1.52 (Total: +1816.92)
#   Cooperator1 Reward: -2.01 (Total: -2062.23)
#   Cooperator2 Reward: +0.00 (Total: -2084.73)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 900:
#   Adversary Reward: +1.23 (Total: +1886.13)
#   Cooperator1 Reward: -3.00 (Total: -2192.56)
#   Cooperator2 Reward: -0.58 (Total: -2084.75)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 950:
#   Adversary Reward: +2.31 (Total: +1974.55)
#   Cooperator1 Reward: -3.00 (Total: -2342.56)
#   Cooperator2 Reward: -1.50 (Total: -2153.48)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 497, Step 1000:
#   Adversary Reward: +2.27 (Total: +2094.78)
#   Cooperator1 Reward: -3.00 (Total: -2492.56)
#   Cooperator2 Reward: -3.00 (Total: -2253.87)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
#
# 🎯 Episode 497 completed:
#    Adversary Total Reward: 2094.78
#    Cooperator1 Total Reward: -2492.56
#    Cooperator2 Total Reward: -2253.87
#    Captures: 0, Successes: 0
#    Shared Memory Size: 50000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 497 Progress: Agent0✓, Agent0_Q_stable, Agent1↓, Agent1_Q_stable, Agent2✓, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 498/500 completed in 93.33s
# Episode 498, Step 50:
#   Adversary Reward: +1.75 (Total: +40.86)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +0.15 (Total: +26.34)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 100:
#   Adversary Reward: +1.25 (Total: +100.76)
#   Cooperator1 Reward: +0.00 (Total: +0.00)
#   Cooperator2 Reward: +1.86 (Total: +84.38)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 150:
#   Adversary Reward: +1.45 (Total: +174.29)
#   Cooperator1 Reward: -2.19 (Total: -49.83)
#   Cooperator2 Reward: -1.50 (Total: +62.30)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 200:
#   Adversary Reward: +2.06 (Total: +252.03)
#   Cooperator1 Reward: -3.00 (Total: -189.34)
#   Cooperator2 Reward: -1.50 (Total: -12.70)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 250:
#   Adversary Reward: +2.25 (Total: +374.69)
#   Cooperator1 Reward: -3.00 (Total: -339.34)
#   Cooperator2 Reward: -2.15 (Total: -104.00)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 300:
#   Adversary Reward: +2.30 (Total: +491.62)
#   Cooperator1 Reward: -3.00 (Total: -489.34)
#   Cooperator2 Reward: -3.00 (Total: -245.55)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 350:
#   Adversary Reward: +2.29 (Total: +605.97)
#   Cooperator1 Reward: -3.00 (Total: -639.34)
#   Cooperator2 Reward: -3.00 (Total: -395.55)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 400:
#   Adversary Reward: +2.28 (Total: +719.98)
#   Cooperator1 Reward: -3.05 (Total: -789.88)
#   Cooperator2 Reward: -3.05 (Total: -546.09)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 450:
#   Adversary Reward: +2.28 (Total: +834.08)
#   Cooperator1 Reward: -3.00 (Total: -940.36)
#   Cooperator2 Reward: -3.00 (Total: -696.57)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 500:
#   Adversary Reward: +2.28 (Total: +948.45)
#   Cooperator1 Reward: -3.00 (Total: -1090.36)
#   Cooperator2 Reward: -3.00 (Total: -846.57)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 500: Forced exploration for agent 2
# Episode 498, Step 550:
#   Adversary Reward: +2.28 (Total: +1062.87)
#   Cooperator1 Reward: -3.00 (Total: -1240.36)
#   Cooperator2 Reward: -3.00 (Total: -996.52)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 600:
#   Adversary Reward: +2.29 (Total: +1177.42)
#   Cooperator1 Reward: -3.00 (Total: -1390.36)
#   Cooperator2 Reward: -3.00 (Total: -1146.52)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 650:
#   Adversary Reward: +2.25 (Total: +1290.77)
#   Cooperator1 Reward: -3.05 (Total: -1540.76)
#   Cooperator2 Reward: -3.05 (Total: -1296.93)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# 🚨 Step 650: Detected stuck agents, performing reset...
# Episode 498, Step 700:
#   Adversary Reward: +2.89 (Total: +1364.02)
#   Cooperator1 Reward: -0.28 (Total: -1541.74)
#   Cooperator2 Reward: -1.29 (Total: -1267.18)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 750:
#   Adversary Reward: +2.47 (Total: +1505.39)
#   Cooperator1 Reward: -1.74 (Total: -1613.33)
#   Cooperator2 Reward: -1.76 (Total: -1352.64)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 800:
#   Adversary Reward: +3.12 (Total: +1641.06)
#   Cooperator1 Reward: -2.75 (Total: -1724.78)
#   Cooperator2 Reward: -2.79 (Total: -1465.36)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 850:
#   Adversary Reward: +2.28 (Total: +1766.42)
#   Cooperator1 Reward: -3.00 (Total: -1875.90)
#   Cooperator2 Reward: -3.00 (Total: -1616.57)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 900:
#   Adversary Reward: +2.29 (Total: +1880.04)
#   Cooperator1 Reward: -3.06 (Total: -2029.26)
#   Cooperator2 Reward: -3.06 (Total: -1769.93)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 900: Forced exploration for agent 2
# Episode 498, Step 950:
#   Adversary Reward: +2.29 (Total: +1994.24)
#   Cooperator1 Reward: -3.09 (Total: -2185.26)
#   Cooperator2 Reward: -3.09 (Total: -1925.93)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 498, Step 1000:
#   Adversary Reward: +2.30 (Total: +2108.98)
#   Cooperator1 Reward: -3.00 (Total: -2335.98)
#   Cooperator2 Reward: -3.00 (Total: -2076.65)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
#
# 🎯 Episode 498 completed:
#    Adversary Total Reward: 2108.98
#    Cooperator1 Total Reward: -2335.98
#    Cooperator2 Total Reward: -2076.65
#    Captures: 1, Successes: 0
#    Shared Memory Size: 50000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 498 Progress: Agent0✓, Agent0_Q_stable, Agent1↓, Agent1_Q_stable, Agent2✓, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 499/500 completed in 113.57s
# Episode 499, Step 50:
#   Adversary Reward: +1.72 (Total: +40.79)
#   Cooperator1 Reward: +0.00 (Total: -7.95)
#   Cooperator2 Reward: +0.16 (Total: +26.82)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 100:
#   Adversary Reward: +1.84 (Total: +125.63)
#   Cooperator1 Reward: +0.00 (Total: -7.95)
#   Cooperator2 Reward: -1.50 (Total: +3.12)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 150:
#   Adversary Reward: +2.90 (Total: +256.67)
#   Cooperator1 Reward: -1.63 (Total: -55.99)
#   Cooperator2 Reward: -1.81 (Total: -75.56)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 200:
#   Adversary Reward: +2.32 (Total: +379.96)
#   Cooperator1 Reward: -3.00 (Total: -190.49)
#   Cooperator2 Reward: -3.00 (Total: -210.89)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 250:
#   Adversary Reward: +2.30 (Total: +495.20)
#   Cooperator1 Reward: -3.00 (Total: -340.49)
#   Cooperator2 Reward: -3.00 (Total: -360.89)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 300:
#   Adversary Reward: +2.30 (Total: +610.05)
#   Cooperator1 Reward: -3.00 (Total: -490.49)
#   Cooperator2 Reward: -3.00 (Total: -510.89)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 350:
#   Adversary Reward: +2.27 (Total: +724.32)
#   Cooperator1 Reward: -3.00 (Total: -640.53)
#   Cooperator2 Reward: -3.00 (Total: -660.92)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# 🚨 Step 350: Detected stuck agents, performing reset...
# Episode 499, Step 400:
#   Adversary Reward: +1.13 (Total: +789.59)
#   Cooperator1 Reward: -3.00 (Total: -733.56)
#   Cooperator2 Reward: +0.00 (Total: -658.46)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 450:
#   Adversary Reward: +1.13 (Total: +846.60)
#   Cooperator1 Reward: -3.00 (Total: -883.56)
#   Cooperator2 Reward: +0.00 (Total: -658.46)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 500:
#   Adversary Reward: +2.36 (Total: +929.07)
#   Cooperator1 Reward: -3.00 (Total: -1033.56)
#   Cooperator2 Reward: -0.56 (Total: -661.85)
#   Captures: 0, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 550:
#   Adversary Reward: +1.11 (Total: +1000.53)
#   Cooperator1 Reward: -3.00 (Total: -1183.57)
#   Cooperator2 Reward: +0.00 (Total: -676.34)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 600:
#   Adversary Reward: +1.41 (Total: +1057.96)
#   Cooperator1 Reward: -3.00 (Total: -1333.57)
#   Cooperator2 Reward: +0.00 (Total: -676.34)
#   Captures: 1, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 600: Forced exploration for agent 0
# Episode 499, Step 650:
#   Adversary Reward: +1.17 (Total: +1154.19)
#   Cooperator1 Reward: -3.00 (Total: -1483.57)
#   Cooperator2 Reward: +0.00 (Total: -691.92)
#   Captures: 2, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 700:
#   Adversary Reward: +1.42 (Total: +1213.77)
#   Cooperator1 Reward: -3.00 (Total: -1633.57)
#   Cooperator2 Reward: +0.00 (Total: -691.92)
#   Captures: 2, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 750:
#   Adversary Reward: +1.16 (Total: +1318.70)
#   Cooperator1 Reward: -3.00 (Total: -1783.57)
#   Cooperator2 Reward: +0.00 (Total: -714.45)
#   Captures: 3, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 800:
#   Adversary Reward: +1.14 (Total: +1375.96)
#   Cooperator1 Reward: -3.00 (Total: -1933.57)
#   Cooperator2 Reward: +0.00 (Total: -714.45)
#   Captures: 3, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 850:
#   Adversary Reward: +1.12 (Total: +1432.79)
#   Cooperator1 Reward: -3.00 (Total: -2083.57)
#   Cooperator2 Reward: +0.00 (Total: -714.45)
#   Captures: 3, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 900:
#   Adversary Reward: +2.85 (Total: +1531.14)
#   Cooperator1 Reward: -3.00 (Total: -2233.57)
#   Cooperator2 Reward: -1.54 (Total: -729.50)
#   Captures: 3, Successes: 0
#   Shared Memory: 50000/50000
# 🔄 Step 900: Forced exploration for agent 2
# Episode 499, Step 950:
#   Adversary Reward: +1.14 (Total: +1634.13)
#   Cooperator1 Reward: -3.00 (Total: -2383.57)
#   Cooperator2 Reward: +0.00 (Total: -748.66)
#   Captures: 5, Successes: 0
#   Shared Memory: 50000/50000
# Episode 499, Step 1000:
#   Adversary Reward: +1.14 (Total: +1691.12)
#   Cooperator1 Reward: -3.00 (Total: -2533.57)
#   Cooperator2 Reward: -1.50 (Total: -770.09)
#   Captures: 5, Successes: 0
#   Shared Memory: 50000/50000
#
# 🎯 Episode 499 completed:
#    Adversary Total Reward: 1691.12
#    Cooperator1 Total Reward: -2533.57
#    Cooperator2 Total Reward: -770.09
#    Captures: 5, Successes: 0
#    Shared Memory Size: 50000
#    Avg Epsilon: 0.100
# ----------------------------------------
# Episode 499 Progress: Agent0✓, Agent0_Q_stable, Agent1↓, Agent1_Q_stable, Agent2✓, Agent2_Q_stable
# 📊 MADDPG training visualization updated - 4 essential plots saved
# 📈 Episode 500/500 completed in 93.54s
# 📊 MADDPG training visualization updated - 4 essential plots saved
# ✅ MADDPG training completed! (Adjusted Params)
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
